# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
import torch

print(torch.__version__)
print(torch.cuda.is_available())
print(torch.cuda.get_device_name())
# Out:
# 2.2.2+cu121
# True
# NVIDIA GeForce RTX 2080 Ti

# %% [markdown]
# ## Ret50

# %% [markdown]
# ## Ret50 分类FashionMNIST数据集

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter

class Bottleneck(nn.Module):
    def __init__(self, in_channels, channels, stride=1, use_1x1conv=False):
        super(Bottleneck,self).__init__()
        self.conv1 = nn.Conv2d(in_channels, channels, kernel_size=1, stride=1, bias=False)
        self.bn1 = nn.BatchNorm2d(channels)
        self.conv2 = nn.Conv2d(channels, channels, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(channels)
        self.conv3 = nn.Conv2d(channels, channels*4, kernel_size=1, stride=1, bias=False)
        self.bn3 = nn.BatchNorm2d(channels*4)

        if use_1x1conv:
            self.conv4 = nn.Conv2d(
                in_channels, channels*4, kernel_size=1, stride=stride
            )
        else:
            self.conv4 = None

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))

        if  self.conv4 == None:
            identity = x
        else:
            identity = self.conv4(x)

        out += identity
        return F.relu(out)

def bottleneck_block(in_channels, channels, num_bottlenecks, stride=1):
    blk = []
    for i in range(num_bottlenecks):
        if i == 0:
            blk.append(Bottleneck(in_channels, channels, stride=stride, use_1x1conv=True))
        else:
            blk.append(Bottleneck(channels*4, channels))
    return blk

def ResNet(block, layers, num_classes=10):
    def init_weights(self, m):
        if type(m) == nn.Linear or type(m) == nn.Conv2d:
            nn.init.kaiming_normal_(m.weight)
    b1 = nn.Sequential(nn.Conv2d(1, 64, kernel_size=7, stride=2, padding=3),
                       nn.BatchNorm2d(64), nn.ReLU(),
                       nn.MaxPool2d(kernel_size=3, stride=2, padding=1))

    b2 = nn.Sequential(*bottleneck_block(64, 64, layers[0], stride=1))
    b3 = nn.Sequential(*bottleneck_block(64*4, 128, layers[1], stride=2))
    b4 = nn.Sequential(*bottleneck_block(128*4, 256, layers[2], stride=2))
    b5 = nn.Sequential(*bottleneck_block(256*4, 512, layers[3], stride=2))

    resnet = nn.Sequential(
        b1, b2, b3, b4, b5,
        nn.AdaptiveAvgPool2d((1,1)),
        nn.Flatten(),
        nn.Linear(512*4, num_classes)
    )
    return resnet

def resnet50():
    return ResNet(Bottleneck, [3, 4, 6, 3])

def resnet101():
    return ResNet(Bottleneck, [3, 4, 23, 3])



def train_loss(net, train_iter, test_iter, epochs, loss, device, lr):
    net.to(device)
    writer = SummaryWriter()  # 创建 TensorBoard writer

    trainer = torch.optim.Adam(net.parameters(), lr=lr)
    for epoch in range(epochs):
        # 训练损失之和，训练准确率之和，样本数
        metric = d2l.Accumulator(3)
        net.train()
        timer, num_batches = d2l.Timer(), len(train_iter)
        for i, (X, y) in enumerate(train_iter):
            trainer.zero_grad()
            X, y = X.to(device), y.to(device)
            y_hat = net(X)
            l = loss(y_hat, y)
            l.backward()
            trainer.step()
            with torch.no_grad():
                metric.add(l * X.shape[0], d2l.accuracy(y_hat, y), X.shape[0])

            train_loss = metric[0] / metric[2]
            train_acc = metric[1] / metric[2]

            # 将训练损失和准确率写入 TensorBoard
            writer.add_scalar('Train/Loss', train_loss, epoch * num_batches + i)
            writer.add_scalar('Train/Accuracy', train_acc, epoch * num_batches + i)

            # 打印训练过程
            print(f'Epoch: {epoch+1}, Batch: {i+1}, Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}')

        test_acc = d2l.evaluate_accuracy_gpu(net, test_iter)
        writer.add_scalar('Test/Accuracy', test_acc, epoch)  # 将测试准确率写入 TensorBoard

        test_acc = d2l.evaluate_accuracy_gpu(net, test_iter)
        writer.add_scalar('Test/Accuracy', test_acc, epoch)  # 将测试准确率写入 TensorBoard

    print(f'train loss {train_loss:.3f}, train acc {train_acc:.3f}, test acc {test_acc:.3f}')
    torch.save(net.state_dict(), f".\\model\\ResNet-50_Dict_FashionMNIST-10_Epoch{epochs}_Accuracy{test_acc*100:.2f}%.pth")
    torch.save(net, f".\\model\\ResNet-50_FashionMNIST-10_Epoch{epochs}_Accuracy{test_acc*100:.2f}%.pth")
    writer.close()  # 关闭 TensorBoard writer
    
    
# 加载FashionMNIST
trans24 = transforms.Compose(
    [transforms.ToTensor()])#28*28
train_dataset = datasets.FashionMNIST(
    root=r'./', train=True, transform=trans24, download=True)
test_dataset = datasets.FashionMNIST(
    root=r'./', train=False, transform=trans24, download=True)

# 配置数据加载器
batch_size = 128
train_loader64 = DataLoader(dataset=train_dataset,
                          batch_size=batch_size, shuffle=True)
test_loader64 = DataLoader(dataset=test_dataset,
                         batch_size=batch_size, shuffle=True)
def resnet50():
    return ResNet(Bottleneck, [3, 4, 6, 3])

def resnet110():
    return ResNet(Bottleneck, [18, 18, 18, 18])
# 开始训练
epochs, lr = 20, 0.001#epochs,lr = 20, 0.001
device = torch.device("cuda:0")
loss = nn.CrossEntropyLoss()
resnet50 = resnet50()
train_loss(resnet50, test_loader64, test_loader64, epochs, loss, device, lr)
# tensorboard 运行
# (mytorch) PS F:\DeepLearn\resnet\runs> tensorboard --logdir=Apr10_17-45-21_NikeLee
# 其中 'Apr10_17-45-21_NikeLee'是文件夹名称
# Out:
# Epoch: 1, Batch: 1, Train Loss: 2.6636, Train Acc: 0.0781
# Epoch: 1, Batch: 2, Train Loss: 3.4807, Train Acc: 0.1016
# Epoch: 1, Batch: 3, Train Loss: 4.2097, Train Acc: 0.0911
# Epoch: 1, Batch: 4, Train Loss: 4.0664, Train Acc: 0.1191
# Epoch: 1, Batch: 5, Train Loss: 3.9043, Train Acc: 0.1484
# Epoch: 1, Batch: 6, Train Loss: 3.7906, Train Acc: 0.1771
# Epoch: 1, Batch: 7, Train Loss: 3.6019, Train Acc: 0.1875
# Epoch: 1, Batch: 8, Train Loss: 3.3676, Train Acc: 0.2168
# Epoch: 1, Batch: 9, Train Loss: 3.2054, Train Acc: 0.2370
# Epoch: 1, Batch: 10, Train Loss: 3.0426, Train Acc: 0.2594
# Epoch: 1, Batch: 11, Train Loss: 2.9297, Train Acc: 0.2812
# Epoch: 1, Batch: 12, Train Loss: 2.7861, Train Acc: 0.3047
# Epoch: 1, Batch: 13, Train Loss: 2.6925, Train Acc: 0.3233
# Epoch: 1, Batch: 14, Train Loss: 2.5843, Train Acc: 0.3449
# Epoch: 1, Batch: 15, Train Loss: 2.4970, Train Acc: 0.3635
# Epoch: 1, Batch: 16, Train Loss: 2.4036, Train Acc: 0.3804
# Epoch: 1, Batch: 17, Train Loss: 2.3289, Train Acc: 0.3874
# Epoch: 1, Batch: 18, Train Loss: 2.2469, Train Acc: 0.4028
# Epoch: 1, Batch: 19, Train Loss: 2.1977, Train Acc: 0.4042
# Epoch: 1, Batch: 20, Train Loss: 2.1385, Train Acc: 0.4156
# Epoch: 1, Batch: 21, Train Loss: 2.0744, Train Acc: 0.4323
# Epoch: 1, Batch: 22, Train Loss: 2.0197, Train Acc: 0.4439
# Epoch: 1, Batch: 23, Train Loss: 1.9646, Train Acc: 0.4552
# Epoch: 1, Batch: 24, Train Loss: 1.9231, Train Acc: 0.4593
# Epoch: 1, Batch: 25, Train Loss: 1.8865, Train Acc: 0.4672
# Epoch: 1, Batch: 26, Train Loss: 1.8444, Train Acc: 0.4742
# Epoch: 1, Batch: 27, Train Loss: 1.8063, Train Acc: 0.4841
# Epoch: 1, Batch: 28, Train Loss: 1.7675, Train Acc: 0.4925
# Epoch: 1, Batch: 29, Train Loss: 1.7307, Train Acc: 0.5011
# Epoch: 1, Batch: 30, Train Loss: 1.6952, Train Acc: 0.5094
# Epoch: 1, Batch: 31, Train Loss: 1.6704, Train Acc: 0.5144
# Epoch: 1, Batch: 32, Train Loss: 1.6390, Train Acc: 0.5212
# Epoch: 1, Batch: 33, Train Loss: 1.6122, Train Acc: 0.5251
# Epoch: 1, Batch: 34, Train Loss: 1.5913, Train Acc: 0.5292
# Epoch: 1, Batch: 35, Train Loss: 1.5687, Train Acc: 0.5335
# Epoch: 1, Batch: 36, Train Loss: 1.5475, Train Acc: 0.5382
# Epoch: 1, Batch: 37, Train Loss: 1.5259, Train Acc: 0.5427
# Epoch: 1, Batch: 38, Train Loss: 1.5061, Train Acc: 0.5461
# Epoch: 1, Batch: 39, Train Loss: 1.4918, Train Acc: 0.5483
# Epoch: 1, Batch: 40, Train Loss: 1.4706, Train Acc: 0.5537
# Epoch: 1, Batch: 41, Train Loss: 1.4512, Train Acc: 0.5579
# Epoch: 1, Batch: 42, Train Loss: 1.4349, Train Acc: 0.5618
# Epoch: 1, Batch: 43, Train Loss: 1.4175, Train Acc: 0.5665
# Epoch: 1, Batch: 44, Train Loss: 1.4021, Train Acc: 0.5707
# Epoch: 1, Batch: 45, Train Loss: 1.3870, Train Acc: 0.5741
# Epoch: 1, Batch: 46, Train Loss: 1.3725, Train Acc: 0.5774
# Epoch: 1, Batch: 47, Train Loss: 1.3570, Train Acc: 0.5814
# Epoch: 1, Batch: 48, Train Loss: 1.3426, Train Acc: 0.5850
# Epoch: 1, Batch: 49, Train Loss: 1.3332, Train Acc: 0.5869
# Epoch: 1, Batch: 50, Train Loss: 1.3227, Train Acc: 0.5891
# Epoch: 1, Batch: 51, Train Loss: 1.3111, Train Acc: 0.5916
# Epoch: 1, Batch: 52, Train Loss: 1.2979, Train Acc: 0.5945
# Epoch: 1, Batch: 53, Train Loss: 1.2855, Train Acc: 0.5976
# Epoch: 1, Batch: 54, Train Loss: 1.2726, Train Acc: 0.6008
# Epoch: 1, Batch: 55, Train Loss: 1.2639, Train Acc: 0.6030
# Epoch: 1, Batch: 56, Train Loss: 1.2521, Train Acc: 0.6060
# Epoch: 1, Batch: 57, Train Loss: 1.2393, Train Acc: 0.6095
# Epoch: 1, Batch: 58, Train Loss: 1.2300, Train Acc: 0.6119
# Epoch: 1, Batch: 59, Train Loss: 1.2226, Train Acc: 0.6131
# Epoch: 1, Batch: 60, Train Loss: 1.2129, Train Acc: 0.6158
# Epoch: 1, Batch: 61, Train Loss: 1.2034, Train Acc: 0.6174
# Epoch: 1, Batch: 62, Train Loss: 1.1948, Train Acc: 0.6192
# Epoch: 1, Batch: 63, Train Loss: 1.1852, Train Acc: 0.6213
# Epoch: 1, Batch: 64, Train Loss: 1.1781, Train Acc: 0.6227
# Epoch: 1, Batch: 65, Train Loss: 1.1710, Train Acc: 0.6248
# Epoch: 1, Batch: 66, Train Loss: 1.1642, Train Acc: 0.6264
# Epoch: 1, Batch: 67, Train Loss: 1.1591, Train Acc: 0.6279
# Epoch: 1, Batch: 68, Train Loss: 1.1505, Train Acc: 0.6306
# Epoch: 1, Batch: 69, Train Loss: 1.1429, Train Acc: 0.6329
# Epoch: 1, Batch: 70, Train Loss: 1.1351, Train Acc: 0.6353
# Epoch: 1, Batch: 71, Train Loss: 1.1280, Train Acc: 0.6372
# Epoch: 1, Batch: 72, Train Loss: 1.1193, Train Acc: 0.6395
# Epoch: 1, Batch: 73, Train Loss: 1.1127, Train Acc: 0.6412
# Epoch: 1, Batch: 74, Train Loss: 1.1052, Train Acc: 0.6431
# Epoch: 1, Batch: 75, Train Loss: 1.0982, Train Acc: 0.6449
# Epoch: 1, Batch: 76, Train Loss: 1.0927, Train Acc: 0.6464
# Epoch: 1, Batch: 77, Train Loss: 1.0864, Train Acc: 0.6479
# Epoch: 1, Batch: 78, Train Loss: 1.0832, Train Acc: 0.6491
# Epoch: 1, Batch: 79, Train Loss: 1.0833, Train Acc: 0.6491
# Epoch: 2, Batch: 1, Train Loss: 0.4670, Train Acc: 0.8516
# Epoch: 2, Batch: 2, Train Loss: 0.6341, Train Acc: 0.7773
# Epoch: 2, Batch: 3, Train Loss: 0.6578, Train Acc: 0.7500
# Epoch: 2, Batch: 4, Train Loss: 0.6044, Train Acc: 0.7793
# Epoch: 2, Batch: 5, Train Loss: 0.6260, Train Acc: 0.7656
# Epoch: 2, Batch: 6, Train Loss: 0.6273, Train Acc: 0.7708
# Epoch: 2, Batch: 7, Train Loss: 0.6334, Train Acc: 0.7679
# Epoch: 2, Batch: 8, Train Loss: 0.6171, Train Acc: 0.7725
# Epoch: 2, Batch: 9, Train Loss: 0.6136, Train Acc: 0.7760
# Epoch: 2, Batch: 10, Train Loss: 0.6072, Train Acc: 0.7758
# Epoch: 2, Batch: 11, Train Loss: 0.6162, Train Acc: 0.7720
# Epoch: 2, Batch: 12, Train Loss: 0.6105, Train Acc: 0.7734
# Epoch: 2, Batch: 13, Train Loss: 0.6078, Train Acc: 0.7764
# Epoch: 2, Batch: 14, Train Loss: 0.6140, Train Acc: 0.7751
# Epoch: 2, Batch: 15, Train Loss: 0.6119, Train Acc: 0.7776
# Epoch: 2, Batch: 16, Train Loss: 0.6113, Train Acc: 0.7788
# Epoch: 2, Batch: 17, Train Loss: 0.6061, Train Acc: 0.7794
# Epoch: 2, Batch: 18, Train Loss: 0.6022, Train Acc: 0.7804
# Epoch: 2, Batch: 19, Train Loss: 0.5955, Train Acc: 0.7829
# Epoch: 2, Batch: 20, Train Loss: 0.6022, Train Acc: 0.7816
# Epoch: 2, Batch: 21, Train Loss: 0.5987, Train Acc: 0.7827
# Epoch: 2, Batch: 22, Train Loss: 0.5996, Train Acc: 0.7816
# Epoch: 2, Batch: 23, Train Loss: 0.5936, Train Acc: 0.7833
# Epoch: 2, Batch: 24, Train Loss: 0.5896, Train Acc: 0.7855
# Epoch: 2, Batch: 25, Train Loss: 0.5889, Train Acc: 0.7856
# Epoch: 2, Batch: 26, Train Loss: 0.5949, Train Acc: 0.7840
# Epoch: 2, Batch: 27, Train Loss: 0.5931, Train Acc: 0.7844
# Epoch: 2, Batch: 28, Train Loss: 0.5950, Train Acc: 0.7846
# Epoch: 2, Batch: 29, Train Loss: 0.5933, Train Acc: 0.7848
# Epoch: 2, Batch: 30, Train Loss: 0.6004, Train Acc: 0.7828
# Epoch: 2, Batch: 31, Train Loss: 0.6008, Train Acc: 0.7810
# Epoch: 2, Batch: 32, Train Loss: 0.6011, Train Acc: 0.7822
# Epoch: 2, Batch: 33, Train Loss: 0.6042, Train Acc: 0.7822
# Epoch: 2, Batch: 34, Train Loss: 0.6022, Train Acc: 0.7829
# Epoch: 2, Batch: 35, Train Loss: 0.6040, Train Acc: 0.7826
# Epoch: 2, Batch: 36, Train Loss: 0.6089, Train Acc: 0.7815
# Epoch: 2, Batch: 37, Train Loss: 0.6046, Train Acc: 0.7838
# Epoch: 2, Batch: 38, Train Loss: 0.6043, Train Acc: 0.7839
# Epoch: 2, Batch: 39, Train Loss: 0.6047, Train Acc: 0.7835
# Epoch: 2, Batch: 40, Train Loss: 0.6017, Train Acc: 0.7850
# Epoch: 2, Batch: 41, Train Loss: 0.5983, Train Acc: 0.7866
# Epoch: 2, Batch: 42, Train Loss: 0.5996, Train Acc: 0.7863
# Epoch: 2, Batch: 43, Train Loss: 0.5994, Train Acc: 0.7865
# Epoch: 2, Batch: 44, Train Loss: 0.5964, Train Acc: 0.7875
# Epoch: 2, Batch: 45, Train Loss: 0.5931, Train Acc: 0.7891
# Epoch: 2, Batch: 46, Train Loss: 0.5929, Train Acc: 0.7886
# Epoch: 2, Batch: 47, Train Loss: 0.5944, Train Acc: 0.7886
# Epoch: 2, Batch: 48, Train Loss: 0.5890, Train Acc: 0.7912
# Epoch: 2, Batch: 49, Train Loss: 0.5860, Train Acc: 0.7923
# Epoch: 2, Batch: 50, Train Loss: 0.5853, Train Acc: 0.7925
# Epoch: 2, Batch: 51, Train Loss: 0.5872, Train Acc: 0.7923
# Epoch: 2, Batch: 52, Train Loss: 0.5849, Train Acc: 0.7928
# Epoch: 2, Batch: 53, Train Loss: 0.5860, Train Acc: 0.7926
# Epoch: 2, Batch: 54, Train Loss: 0.5856, Train Acc: 0.7927
# Epoch: 2, Batch: 55, Train Loss: 0.5851, Train Acc: 0.7929
# Epoch: 2, Batch: 56, Train Loss: 0.5835, Train Acc: 0.7932
# Epoch: 2, Batch: 57, Train Loss: 0.5798, Train Acc: 0.7947
# Epoch: 2, Batch: 58, Train Loss: 0.5781, Train Acc: 0.7950
# Epoch: 2, Batch: 59, Train Loss: 0.5771, Train Acc: 0.7959
# Epoch: 2, Batch: 60, Train Loss: 0.5767, Train Acc: 0.7954
# Epoch: 2, Batch: 61, Train Loss: 0.5763, Train Acc: 0.7959
# Epoch: 2, Batch: 62, Train Loss: 0.5738, Train Acc: 0.7971
# Epoch: 2, Batch: 63, Train Loss: 0.5749, Train Acc: 0.7966
# Epoch: 2, Batch: 64, Train Loss: 0.5729, Train Acc: 0.7972
# Epoch: 2, Batch: 65, Train Loss: 0.5712, Train Acc: 0.7977
# Epoch: 2, Batch: 66, Train Loss: 0.5705, Train Acc: 0.7982
# Epoch: 2, Batch: 67, Train Loss: 0.5677, Train Acc: 0.7991
# Epoch: 2, Batch: 68, Train Loss: 0.5672, Train Acc: 0.7996
# Epoch: 2, Batch: 69, Train Loss: 0.5667, Train Acc: 0.7998
# Epoch: 2, Batch: 70, Train Loss: 0.5657, Train Acc: 0.7998
# Epoch: 2, Batch: 71, Train Loss: 0.5667, Train Acc: 0.7993
# Epoch: 2, Batch: 72, Train Loss: 0.5682, Train Acc: 0.7989
# Epoch: 2, Batch: 73, Train Loss: 0.5675, Train Acc: 0.7987
# Epoch: 2, Batch: 74, Train Loss: 0.5645, Train Acc: 0.7999
# Epoch: 2, Batch: 75, Train Loss: 0.5636, Train Acc: 0.8002
# Epoch: 2, Batch: 76, Train Loss: 0.5625, Train Acc: 0.8005
# Epoch: 2, Batch: 77, Train Loss: 0.5618, Train Acc: 0.8007
# Epoch: 2, Batch: 78, Train Loss: 0.5612, Train Acc: 0.8009
# Epoch: 2, Batch: 79, Train Loss: 0.5626, Train Acc: 0.8010
# Epoch: 3, Batch: 1, Train Loss: 0.3996, Train Acc: 0.8594
# Epoch: 3, Batch: 2, Train Loss: 0.6225, Train Acc: 0.7930
# Epoch: 3, Batch: 3, Train Loss: 0.7444, Train Acc: 0.7734
# Epoch: 3, Batch: 4, Train Loss: 0.6841, Train Acc: 0.7910
# Epoch: 3, Batch: 5, Train Loss: 0.6982, Train Acc: 0.7828
# Epoch: 3, Batch: 6, Train Loss: 0.7338, Train Acc: 0.7656
# Epoch: 3, Batch: 7, Train Loss: 0.7416, Train Acc: 0.7556
# Epoch: 3, Batch: 8, Train Loss: 0.7526, Train Acc: 0.7520
# Epoch: 3, Batch: 9, Train Loss: 0.7627, Train Acc: 0.7535
# Epoch: 3, Batch: 10, Train Loss: 0.7651, Train Acc: 0.7516
# Epoch: 3, Batch: 11, Train Loss: 0.7554, Train Acc: 0.7550
# Epoch: 3, Batch: 12, Train Loss: 0.7415, Train Acc: 0.7565
# Epoch: 3, Batch: 13, Train Loss: 0.7373, Train Acc: 0.7548
# Epoch: 3, Batch: 14, Train Loss: 0.7352, Train Acc: 0.7556
# Epoch: 3, Batch: 15, Train Loss: 0.7514, Train Acc: 0.7531
# Epoch: 3, Batch: 16, Train Loss: 0.7550, Train Acc: 0.7500
# Epoch: 3, Batch: 17, Train Loss: 0.7771, Train Acc: 0.7482
# Epoch: 3, Batch: 18, Train Loss: 0.7843, Train Acc: 0.7474
# Epoch: 3, Batch: 19, Train Loss: 0.7776, Train Acc: 0.7488
# Epoch: 3, Batch: 20, Train Loss: 0.7748, Train Acc: 0.7465
# Epoch: 3, Batch: 21, Train Loss: 0.7721, Train Acc: 0.7463
# Epoch: 3, Batch: 22, Train Loss: 0.7641, Train Acc: 0.7464
# Epoch: 3, Batch: 23, Train Loss: 0.7561, Train Acc: 0.7490
# Epoch: 3, Batch: 24, Train Loss: 0.7471, Train Acc: 0.7533
# Epoch: 3, Batch: 25, Train Loss: 0.7387, Train Acc: 0.7556
# Epoch: 3, Batch: 26, Train Loss: 0.7370, Train Acc: 0.7569
# Epoch: 3, Batch: 27, Train Loss: 0.7353, Train Acc: 0.7572
# Epoch: 3, Batch: 28, Train Loss: 0.7294, Train Acc: 0.7581
# Epoch: 3, Batch: 29, Train Loss: 0.7202, Train Acc: 0.7597
# Epoch: 3, Batch: 30, Train Loss: 0.7250, Train Acc: 0.7602
# Epoch: 3, Batch: 31, Train Loss: 0.7283, Train Acc: 0.7613
# Epoch: 3, Batch: 32, Train Loss: 0.7253, Train Acc: 0.7622
# Epoch: 3, Batch: 33, Train Loss: 0.7153, Train Acc: 0.7647
# Epoch: 3, Batch: 34, Train Loss: 0.7113, Train Acc: 0.7654
# Epoch: 3, Batch: 35, Train Loss: 0.7073, Train Acc: 0.7661
# Epoch: 3, Batch: 36, Train Loss: 0.7050, Train Acc: 0.7667
# Epoch: 3, Batch: 37, Train Loss: 0.7032, Train Acc: 0.7675
# Epoch: 3, Batch: 38, Train Loss: 0.7018, Train Acc: 0.7671
# Epoch: 3, Batch: 39, Train Loss: 0.6967, Train Acc: 0.7690
# Epoch: 3, Batch: 40, Train Loss: 0.6906, Train Acc: 0.7697
# Epoch: 3, Batch: 41, Train Loss: 0.6855, Train Acc: 0.7723
# Epoch: 3, Batch: 42, Train Loss: 0.6886, Train Acc: 0.7718
# Epoch: 3, Batch: 43, Train Loss: 0.6833, Train Acc: 0.7725
# Epoch: 3, Batch: 44, Train Loss: 0.6779, Train Acc: 0.7741
# Epoch: 3, Batch: 45, Train Loss: 0.6773, Train Acc: 0.7736
# Epoch: 3, Batch: 46, Train Loss: 0.6717, Train Acc: 0.7753
# Epoch: 3, Batch: 47, Train Loss: 0.6681, Train Acc: 0.7764
# Epoch: 3, Batch: 48, Train Loss: 0.6640, Train Acc: 0.7764
# Epoch: 3, Batch: 49, Train Loss: 0.6637, Train Acc: 0.7763
# Epoch: 3, Batch: 50, Train Loss: 0.6596, Train Acc: 0.7767
# Epoch: 3, Batch: 51, Train Loss: 0.6582, Train Acc: 0.7770
# Epoch: 3, Batch: 52, Train Loss: 0.6547, Train Acc: 0.7773
# Epoch: 3, Batch: 53, Train Loss: 0.6536, Train Acc: 0.7774
# Epoch: 3, Batch: 54, Train Loss: 0.6503, Train Acc: 0.7785
# Epoch: 3, Batch: 55, Train Loss: 0.6494, Train Acc: 0.7781
# Epoch: 3, Batch: 56, Train Loss: 0.6502, Train Acc: 0.7772
# Epoch: 3, Batch: 57, Train Loss: 0.6489, Train Acc: 0.7771
# Epoch: 3, Batch: 58, Train Loss: 0.6465, Train Acc: 0.7779
# Epoch: 3, Batch: 59, Train Loss: 0.6452, Train Acc: 0.7782
# Epoch: 3, Batch: 60, Train Loss: 0.6429, Train Acc: 0.7797
# Epoch: 3, Batch: 61, Train Loss: 0.6434, Train Acc: 0.7797
# Epoch: 3, Batch: 62, Train Loss: 0.6393, Train Acc: 0.7811
# Epoch: 3, Batch: 63, Train Loss: 0.6352, Train Acc: 0.7824
# Epoch: 3, Batch: 64, Train Loss: 0.6323, Train Acc: 0.7833
# Epoch: 3, Batch: 65, Train Loss: 0.6310, Train Acc: 0.7835
# Epoch: 3, Batch: 66, Train Loss: 0.6275, Train Acc: 0.7849
# Epoch: 3, Batch: 67, Train Loss: 0.6251, Train Acc: 0.7850
# Epoch: 3, Batch: 68, Train Loss: 0.6211, Train Acc: 0.7865
# Epoch: 3, Batch: 69, Train Loss: 0.6182, Train Acc: 0.7868
# Epoch: 3, Batch: 70, Train Loss: 0.6166, Train Acc: 0.7871
# Epoch: 3, Batch: 71, Train Loss: 0.6160, Train Acc: 0.7874
# Epoch: 3, Batch: 72, Train Loss: 0.6137, Train Acc: 0.7875
# Epoch: 3, Batch: 73, Train Loss: 0.6107, Train Acc: 0.7886
# Epoch: 3, Batch: 74, Train Loss: 0.6105, Train Acc: 0.7889
# Epoch: 3, Batch: 75, Train Loss: 0.6079, Train Acc: 0.7898
# Epoch: 3, Batch: 76, Train Loss: 0.6060, Train Acc: 0.7906
# Epoch: 3, Batch: 77, Train Loss: 0.6032, Train Acc: 0.7914
# Epoch: 3, Batch: 78, Train Loss: 0.6029, Train Acc: 0.7915
# Epoch: 3, Batch: 79, Train Loss: 0.6043, Train Acc: 0.7914
# Epoch: 4, Batch: 1, Train Loss: 0.3432, Train Acc: 0.8594
# Epoch: 4, Batch: 2, Train Loss: 0.3976, Train Acc: 0.8359
# Epoch: 4, Batch: 3, Train Loss: 0.5027, Train Acc: 0.8177
# Epoch: 4, Batch: 4, Train Loss: 0.5269, Train Acc: 0.8164
# Epoch: 4, Batch: 5, Train Loss: 0.5088, Train Acc: 0.8234
# Epoch: 4, Batch: 6, Train Loss: 0.4862, Train Acc: 0.8281
# Epoch: 4, Batch: 7, Train Loss: 0.4891, Train Acc: 0.8259
# Epoch: 4, Batch: 8, Train Loss: 0.4624, Train Acc: 0.8359
# Epoch: 4, Batch: 9, Train Loss: 0.4761, Train Acc: 0.8307
# Epoch: 4, Batch: 10, Train Loss: 0.4936, Train Acc: 0.8266
# Epoch: 4, Batch: 11, Train Loss: 0.4859, Train Acc: 0.8281
# Epoch: 4, Batch: 12, Train Loss: 0.4903, Train Acc: 0.8229
# Epoch: 4, Batch: 13, Train Loss: 0.4824, Train Acc: 0.8275
# Epoch: 4, Batch: 14, Train Loss: 0.4843, Train Acc: 0.8259
# Epoch: 4, Batch: 15, Train Loss: 0.4922, Train Acc: 0.8234
# Epoch: 4, Batch: 16, Train Loss: 0.4878, Train Acc: 0.8242
# Epoch: 4, Batch: 17, Train Loss: 0.4779, Train Acc: 0.8272
# Epoch: 4, Batch: 18, Train Loss: 0.4712, Train Acc: 0.8299
# Epoch: 4, Batch: 19, Train Loss: 0.4623, Train Acc: 0.8326
# Epoch: 4, Batch: 20, Train Loss: 0.4678, Train Acc: 0.8301
# Epoch: 4, Batch: 21, Train Loss: 0.4638, Train Acc: 0.8315
# Epoch: 4, Batch: 22, Train Loss: 0.4620, Train Acc: 0.8313
# Epoch: 4, Batch: 23, Train Loss: 0.4577, Train Acc: 0.8336
# Epoch: 4, Batch: 24, Train Loss: 0.4577, Train Acc: 0.8327
# Epoch: 4, Batch: 25, Train Loss: 0.4532, Train Acc: 0.8344
# Epoch: 4, Batch: 26, Train Loss: 0.4459, Train Acc: 0.8377
# Epoch: 4, Batch: 27, Train Loss: 0.4449, Train Acc: 0.8371
# Epoch: 4, Batch: 28, Train Loss: 0.4421, Train Acc: 0.8382
# Epoch: 4, Batch: 29, Train Loss: 0.4480, Train Acc: 0.8362
# Epoch: 4, Batch: 30, Train Loss: 0.4448, Train Acc: 0.8380
# Epoch: 4, Batch: 31, Train Loss: 0.4743, Train Acc: 0.8382
# Epoch: 4, Batch: 32, Train Loss: 0.4712, Train Acc: 0.8389
# Epoch: 4, Batch: 33, Train Loss: 0.4661, Train Acc: 0.8395
# Epoch: 4, Batch: 34, Train Loss: 0.4620, Train Acc: 0.8403
# Epoch: 4, Batch: 35, Train Loss: 0.4625, Train Acc: 0.8402
# Epoch: 4, Batch: 36, Train Loss: 0.4597, Train Acc: 0.8416
# Epoch: 4, Batch: 37, Train Loss: 0.4585, Train Acc: 0.8421
# Epoch: 4, Batch: 38, Train Loss: 0.4604, Train Acc: 0.8415
# Epoch: 4, Batch: 39, Train Loss: 0.4569, Train Acc: 0.8425
# Epoch: 4, Batch: 40, Train Loss: 0.4570, Train Acc: 0.8414
# Epoch: 4, Batch: 41, Train Loss: 0.4577, Train Acc: 0.8407
# Epoch: 4, Batch: 42, Train Loss: 0.4627, Train Acc: 0.8406
# Epoch: 4, Batch: 43, Train Loss: 0.4696, Train Acc: 0.8388
# Epoch: 4, Batch: 44, Train Loss: 0.4726, Train Acc: 0.8374
# Epoch: 4, Batch: 45, Train Loss: 0.4774, Train Acc: 0.8351
# Epoch: 4, Batch: 46, Train Loss: 0.4910, Train Acc: 0.8334
# Epoch: 4, Batch: 47, Train Loss: 0.4941, Train Acc: 0.8324
# Epoch: 4, Batch: 48, Train Loss: 0.5019, Train Acc: 0.8307
# Epoch: 4, Batch: 49, Train Loss: 0.5052, Train Acc: 0.8288
# Epoch: 4, Batch: 50, Train Loss: 0.5119, Train Acc: 0.8267
# Epoch: 4, Batch: 51, Train Loss: 0.5205, Train Acc: 0.8241
# Epoch: 4, Batch: 52, Train Loss: 0.5183, Train Acc: 0.8242
# Epoch: 4, Batch: 53, Train Loss: 0.5225, Train Acc: 0.8224
# Epoch: 4, Batch: 54, Train Loss: 0.5254, Train Acc: 0.8210
# Epoch: 4, Batch: 55, Train Loss: 0.5257, Train Acc: 0.8205
# Epoch: 4, Batch: 56, Train Loss: 0.5259, Train Acc: 0.8202
# Epoch: 4, Batch: 57, Train Loss: 0.5291, Train Acc: 0.8189
# Epoch: 4, Batch: 58, Train Loss: 0.5307, Train Acc: 0.8184
# Epoch: 4, Batch: 59, Train Loss: 0.5335, Train Acc: 0.8175
# Epoch: 4, Batch: 60, Train Loss: 0.5363, Train Acc: 0.8174
# Epoch: 4, Batch: 61, Train Loss: 0.5374, Train Acc: 0.8169
# Epoch: 4, Batch: 62, Train Loss: 0.5388, Train Acc: 0.8163
# Epoch: 4, Batch: 63, Train Loss: 0.5413, Train Acc: 0.8151
# Epoch: 4, Batch: 64, Train Loss: 0.5439, Train Acc: 0.8141
# Epoch: 4, Batch: 65, Train Loss: 0.5432, Train Acc: 0.8138
# Epoch: 4, Batch: 66, Train Loss: 0.5439, Train Acc: 0.8137
# Epoch: 4, Batch: 67, Train Loss: 0.5450, Train Acc: 0.8128
# Epoch: 4, Batch: 68, Train Loss: 0.5489, Train Acc: 0.8115
# Epoch: 4, Batch: 69, Train Loss: 0.5497, Train Acc: 0.8111
# Epoch: 4, Batch: 70, Train Loss: 0.5504, Train Acc: 0.8117
# Epoch: 4, Batch: 71, Train Loss: 0.5501, Train Acc: 0.8121
# Epoch: 4, Batch: 72, Train Loss: 0.5518, Train Acc: 0.8114
# Epoch: 4, Batch: 73, Train Loss: 0.5542, Train Acc: 0.8104
# Epoch: 4, Batch: 74, Train Loss: 0.5530, Train Acc: 0.8106
# Epoch: 4, Batch: 75, Train Loss: 0.5519, Train Acc: 0.8107
# Epoch: 4, Batch: 76, Train Loss: 0.5525, Train Acc: 0.8100
# Epoch: 4, Batch: 77, Train Loss: 0.5523, Train Acc: 0.8101
# Epoch: 4, Batch: 78, Train Loss: 0.5512, Train Acc: 0.8106
# Epoch: 4, Batch: 79, Train Loss: 0.5513, Train Acc: 0.8106
# Epoch: 5, Batch: 1, Train Loss: 0.5638, Train Acc: 0.7969
# Epoch: 5, Batch: 2, Train Loss: 0.6981, Train Acc: 0.7812
# Epoch: 5, Batch: 3, Train Loss: 0.6577, Train Acc: 0.7839
# Epoch: 5, Batch: 4, Train Loss: 0.6141, Train Acc: 0.7949
# Epoch: 5, Batch: 5, Train Loss: 0.5880, Train Acc: 0.8000
# Epoch: 5, Batch: 6, Train Loss: 0.5703, Train Acc: 0.8073
# Epoch: 5, Batch: 7, Train Loss: 0.5664, Train Acc: 0.8092
# Epoch: 5, Batch: 8, Train Loss: 0.5741, Train Acc: 0.8076
# Epoch: 5, Batch: 9, Train Loss: 0.5653, Train Acc: 0.8108
# Epoch: 5, Batch: 10, Train Loss: 0.5682, Train Acc: 0.8086
# Epoch: 5, Batch: 11, Train Loss: 0.5553, Train Acc: 0.8132
# Epoch: 5, Batch: 12, Train Loss: 0.5531, Train Acc: 0.8151
# Epoch: 5, Batch: 13, Train Loss: 0.5397, Train Acc: 0.8191
# Epoch: 5, Batch: 14, Train Loss: 0.5364, Train Acc: 0.8181
# Epoch: 5, Batch: 15, Train Loss: 0.5291, Train Acc: 0.8193
# Epoch: 5, Batch: 16, Train Loss: 0.5270, Train Acc: 0.8203
# Epoch: 5, Batch: 17, Train Loss: 0.5170, Train Acc: 0.8244
# Epoch: 5, Batch: 18, Train Loss: 0.5181, Train Acc: 0.8229
# Epoch: 5, Batch: 19, Train Loss: 0.5187, Train Acc: 0.8220
# Epoch: 5, Batch: 20, Train Loss: 0.5145, Train Acc: 0.8238
# Epoch: 5, Batch: 21, Train Loss: 0.5112, Train Acc: 0.8237
# Epoch: 5, Batch: 22, Train Loss: 0.5130, Train Acc: 0.8242
# Epoch: 5, Batch: 23, Train Loss: 0.5079, Train Acc: 0.8247
# Epoch: 5, Batch: 24, Train Loss: 0.5186, Train Acc: 0.8210
# Epoch: 5, Batch: 25, Train Loss: 0.5228, Train Acc: 0.8200
# Epoch: 5, Batch: 26, Train Loss: 0.5244, Train Acc: 0.8185
# Epoch: 5, Batch: 27, Train Loss: 0.5187, Train Acc: 0.8206
# Epoch: 5, Batch: 28, Train Loss: 0.5182, Train Acc: 0.8189
# Epoch: 5, Batch: 29, Train Loss: 0.5136, Train Acc: 0.8214
# Epoch: 5, Batch: 30, Train Loss: 0.5102, Train Acc: 0.8224
# Epoch: 5, Batch: 31, Train Loss: 0.5147, Train Acc: 0.8203
# Epoch: 5, Batch: 32, Train Loss: 0.5103, Train Acc: 0.8223
# Epoch: 5, Batch: 33, Train Loss: 0.5061, Train Acc: 0.8236
# Epoch: 5, Batch: 34, Train Loss: 0.5041, Train Acc: 0.8242
# Epoch: 5, Batch: 35, Train Loss: 0.5014, Train Acc: 0.8252
# Epoch: 5, Batch: 36, Train Loss: 0.5011, Train Acc: 0.8253
# Epoch: 5, Batch: 37, Train Loss: 0.5037, Train Acc: 0.8241
# Epoch: 5, Batch: 38, Train Loss: 0.5024, Train Acc: 0.8246
# Epoch: 5, Batch: 39, Train Loss: 0.5019, Train Acc: 0.8251
# Epoch: 5, Batch: 40, Train Loss: 0.4996, Train Acc: 0.8252
# Epoch: 5, Batch: 41, Train Loss: 0.4981, Train Acc: 0.8256
# Epoch: 5, Batch: 42, Train Loss: 0.4965, Train Acc: 0.8261
# Epoch: 5, Batch: 43, Train Loss: 0.4973, Train Acc: 0.8265
# Epoch: 5, Batch: 44, Train Loss: 0.4955, Train Acc: 0.8262
# Epoch: 5, Batch: 45, Train Loss: 0.4959, Train Acc: 0.8260
# Epoch: 5, Batch: 46, Train Loss: 0.4923, Train Acc: 0.8271
# Epoch: 5, Batch: 47, Train Loss: 0.4908, Train Acc: 0.8278
# Epoch: 5, Batch: 48, Train Loss: 0.4884, Train Acc: 0.8285
# Epoch: 5, Batch: 49, Train Loss: 0.4865, Train Acc: 0.8291
# Epoch: 5, Batch: 50, Train Loss: 0.4872, Train Acc: 0.8294
# Epoch: 5, Batch: 51, Train Loss: 0.4875, Train Acc: 0.8292
# Epoch: 5, Batch: 52, Train Loss: 0.4876, Train Acc: 0.8286
# Epoch: 5, Batch: 53, Train Loss: 0.4882, Train Acc: 0.8289
# Epoch: 5, Batch: 54, Train Loss: 0.4857, Train Acc: 0.8294
# Epoch: 5, Batch: 55, Train Loss: 0.4852, Train Acc: 0.8298
# Epoch: 5, Batch: 56, Train Loss: 0.4811, Train Acc: 0.8312
# Epoch: 5, Batch: 57, Train Loss: 0.4791, Train Acc: 0.8317
# Epoch: 5, Batch: 58, Train Loss: 0.4805, Train Acc: 0.8311
# Epoch: 5, Batch: 59, Train Loss: 0.4817, Train Acc: 0.8304
# Epoch: 5, Batch: 60, Train Loss: 0.4806, Train Acc: 0.8307
# Epoch: 5, Batch: 61, Train Loss: 0.4799, Train Acc: 0.8304
# Epoch: 5, Batch: 62, Train Loss: 0.4791, Train Acc: 0.8299
# Epoch: 5, Batch: 63, Train Loss: 0.4790, Train Acc: 0.8297
# Epoch: 5, Batch: 64, Train Loss: 0.4788, Train Acc: 0.8296
# Epoch: 5, Batch: 65, Train Loss: 0.4770, Train Acc: 0.8308
# Epoch: 5, Batch: 66, Train Loss: 0.4763, Train Acc: 0.8310
# Epoch: 5, Batch: 67, Train Loss: 0.4759, Train Acc: 0.8313
# Epoch: 5, Batch: 68, Train Loss: 0.4737, Train Acc: 0.8325
# Epoch: 5, Batch: 69, Train Loss: 0.4736, Train Acc: 0.8324
# Epoch: 5, Batch: 70, Train Loss: 0.4736, Train Acc: 0.8326
# Epoch: 5, Batch: 71, Train Loss: 0.4731, Train Acc: 0.8327
# Epoch: 5, Batch: 72, Train Loss: 0.4717, Train Acc: 0.8328
# Epoch: 5, Batch: 73, Train Loss: 0.4721, Train Acc: 0.8325
# Epoch: 5, Batch: 74, Train Loss: 0.4723, Train Acc: 0.8328
# Epoch: 5, Batch: 75, Train Loss: 0.4701, Train Acc: 0.8334
# Epoch: 5, Batch: 76, Train Loss: 0.4691, Train Acc: 0.8338
# Epoch: 5, Batch: 77, Train Loss: 0.4668, Train Acc: 0.8345
# Epoch: 5, Batch: 78, Train Loss: 0.4664, Train Acc: 0.8344
# Epoch: 5, Batch: 79, Train Loss: 0.4665, Train Acc: 0.8343
# Epoch: 6, Batch: 1, Train Loss: 0.2801, Train Acc: 0.9219
# Epoch: 6, Batch: 2, Train Loss: 0.3578, Train Acc: 0.8711
# Epoch: 6, Batch: 3, Train Loss: 0.4178, Train Acc: 0.8516
# Epoch: 6, Batch: 4, Train Loss: 0.4317, Train Acc: 0.8535
# Epoch: 6, Batch: 5, Train Loss: 0.4202, Train Acc: 0.8578
# Epoch: 6, Batch: 6, Train Loss: 0.4170, Train Acc: 0.8607
# Epoch: 6, Batch: 7, Train Loss: 0.4209, Train Acc: 0.8583
# Epoch: 6, Batch: 8, Train Loss: 0.4318, Train Acc: 0.8525
# Epoch: 6, Batch: 9, Train Loss: 0.4242, Train Acc: 0.8542
# Epoch: 6, Batch: 10, Train Loss: 0.4150, Train Acc: 0.8555
# Epoch: 6, Batch: 11, Train Loss: 0.4192, Train Acc: 0.8565
# Epoch: 6, Batch: 12, Train Loss: 0.4143, Train Acc: 0.8555
# Epoch: 6, Batch: 13, Train Loss: 0.4158, Train Acc: 0.8552
# Epoch: 6, Batch: 14, Train Loss: 0.4245, Train Acc: 0.8521
# Epoch: 6, Batch: 15, Train Loss: 0.4222, Train Acc: 0.8505
# Epoch: 6, Batch: 16, Train Loss: 0.4160, Train Acc: 0.8530
# Epoch: 6, Batch: 17, Train Loss: 0.4138, Train Acc: 0.8543
# Epoch: 6, Batch: 18, Train Loss: 0.4188, Train Acc: 0.8520
# Epoch: 6, Batch: 19, Train Loss: 0.4203, Train Acc: 0.8507
# Epoch: 6, Batch: 20, Train Loss: 0.4330, Train Acc: 0.8484
# Epoch: 6, Batch: 21, Train Loss: 0.4345, Train Acc: 0.8486
# Epoch: 6, Batch: 22, Train Loss: 0.4373, Train Acc: 0.8480
# Epoch: 6, Batch: 23, Train Loss: 0.4303, Train Acc: 0.8505
# Epoch: 6, Batch: 24, Train Loss: 0.4256, Train Acc: 0.8516
# Epoch: 6, Batch: 25, Train Loss: 0.4239, Train Acc: 0.8519
# Epoch: 6, Batch: 26, Train Loss: 0.4198, Train Acc: 0.8522
# Epoch: 6, Batch: 27, Train Loss: 0.4153, Train Acc: 0.8539
# Epoch: 6, Batch: 28, Train Loss: 0.4102, Train Acc: 0.8555
# Epoch: 6, Batch: 29, Train Loss: 0.4115, Train Acc: 0.8556
# Epoch: 6, Batch: 30, Train Loss: 0.4064, Train Acc: 0.8581
# Epoch: 6, Batch: 31, Train Loss: 0.4044, Train Acc: 0.8579
# Epoch: 6, Batch: 32, Train Loss: 0.4037, Train Acc: 0.8582
# Epoch: 6, Batch: 33, Train Loss: 0.4024, Train Acc: 0.8582
# Epoch: 6, Batch: 34, Train Loss: 0.4002, Train Acc: 0.8585
# Epoch: 6, Batch: 35, Train Loss: 0.3978, Train Acc: 0.8592
# Epoch: 6, Batch: 36, Train Loss: 0.3965, Train Acc: 0.8598
# Epoch: 6, Batch: 37, Train Loss: 0.3951, Train Acc: 0.8600
# Epoch: 6, Batch: 38, Train Loss: 0.3923, Train Acc: 0.8608
# Epoch: 6, Batch: 39, Train Loss: 0.3964, Train Acc: 0.8592
# Epoch: 6, Batch: 40, Train Loss: 0.3960, Train Acc: 0.8594
# Epoch: 6, Batch: 41, Train Loss: 0.3989, Train Acc: 0.8590
# Epoch: 6, Batch: 42, Train Loss: 0.3952, Train Acc: 0.8603
# Epoch: 6, Batch: 43, Train Loss: 0.3959, Train Acc: 0.8603
# Epoch: 6, Batch: 44, Train Loss: 0.3943, Train Acc: 0.8608
# Epoch: 6, Batch: 45, Train Loss: 0.3941, Train Acc: 0.8613
# Epoch: 6, Batch: 46, Train Loss: 0.3959, Train Acc: 0.8618
# Epoch: 6, Batch: 47, Train Loss: 0.3957, Train Acc: 0.8619
# Epoch: 6, Batch: 48, Train Loss: 0.3970, Train Acc: 0.8612
# Epoch: 6, Batch: 49, Train Loss: 0.3944, Train Acc: 0.8624
# Epoch: 6, Batch: 50, Train Loss: 0.3939, Train Acc: 0.8623
# Epoch: 6, Batch: 51, Train Loss: 0.3912, Train Acc: 0.8635
# Epoch: 6, Batch: 52, Train Loss: 0.3912, Train Acc: 0.8630
# Epoch: 6, Batch: 53, Train Loss: 0.3888, Train Acc: 0.8639
# Epoch: 6, Batch: 54, Train Loss: 0.3868, Train Acc: 0.8649
# Epoch: 6, Batch: 55, Train Loss: 0.3859, Train Acc: 0.8651
# Epoch: 6, Batch: 56, Train Loss: 0.3839, Train Acc: 0.8662
# Epoch: 6, Batch: 57, Train Loss: 0.3840, Train Acc: 0.8660
# Epoch: 6, Batch: 58, Train Loss: 0.3865, Train Acc: 0.8649
# Epoch: 6, Batch: 59, Train Loss: 0.3857, Train Acc: 0.8648
# Epoch: 6, Batch: 60, Train Loss: 0.3861, Train Acc: 0.8643
# Epoch: 6, Batch: 61, Train Loss: 0.3857, Train Acc: 0.8650
# Epoch: 6, Batch: 62, Train Loss: 0.3838, Train Acc: 0.8658
# Epoch: 6, Batch: 63, Train Loss: 0.3844, Train Acc: 0.8653
# Epoch: 6, Batch: 64, Train Loss: 0.3826, Train Acc: 0.8662
# Epoch: 6, Batch: 65, Train Loss: 0.3820, Train Acc: 0.8659
# Epoch: 6, Batch: 66, Train Loss: 0.3809, Train Acc: 0.8661
# Epoch: 6, Batch: 67, Train Loss: 0.3822, Train Acc: 0.8653
# Epoch: 6, Batch: 68, Train Loss: 0.3830, Train Acc: 0.8651
# Epoch: 6, Batch: 69, Train Loss: 0.3822, Train Acc: 0.8655
# Epoch: 6, Batch: 70, Train Loss: 0.3812, Train Acc: 0.8657
# Epoch: 6, Batch: 71, Train Loss: 0.3811, Train Acc: 0.8655
# Epoch: 6, Batch: 72, Train Loss: 0.3829, Train Acc: 0.8645
# Epoch: 6, Batch: 73, Train Loss: 0.3809, Train Acc: 0.8653
# Epoch: 6, Batch: 74, Train Loss: 0.3824, Train Acc: 0.8648
# Epoch: 6, Batch: 75, Train Loss: 0.3834, Train Acc: 0.8643
# Epoch: 6, Batch: 76, Train Loss: 0.3832, Train Acc: 0.8643
# Epoch: 6, Batch: 77, Train Loss: 0.3832, Train Acc: 0.8640
# Epoch: 6, Batch: 78, Train Loss: 0.3826, Train Acc: 0.8640
# Epoch: 6, Batch: 79, Train Loss: 0.3824, Train Acc: 0.8640
# Epoch: 7, Batch: 1, Train Loss: 0.2559, Train Acc: 0.8906
# Epoch: 7, Batch: 2, Train Loss: 0.3153, Train Acc: 0.8828
# Epoch: 7, Batch: 3, Train Loss: 0.3815, Train Acc: 0.8464
# Epoch: 7, Batch: 4, Train Loss: 0.3896, Train Acc: 0.8496
# Epoch: 7, Batch: 5, Train Loss: 0.3660, Train Acc: 0.8609
# Epoch: 7, Batch: 6, Train Loss: 0.3738, Train Acc: 0.8581
# Epoch: 7, Batch: 7, Train Loss: 0.3552, Train Acc: 0.8694
# Epoch: 7, Batch: 8, Train Loss: 0.3492, Train Acc: 0.8721
# Epoch: 7, Batch: 9, Train Loss: 0.3619, Train Acc: 0.8715
# Epoch: 7, Batch: 10, Train Loss: 0.3492, Train Acc: 0.8773
# Epoch: 7, Batch: 11, Train Loss: 0.3371, Train Acc: 0.8814
# Epoch: 7, Batch: 12, Train Loss: 0.3318, Train Acc: 0.8835
# Epoch: 7, Batch: 13, Train Loss: 0.3300, Train Acc: 0.8840
# Epoch: 7, Batch: 14, Train Loss: 0.3209, Train Acc: 0.8873
# Epoch: 7, Batch: 15, Train Loss: 0.3242, Train Acc: 0.8891
# Epoch: 7, Batch: 16, Train Loss: 0.3196, Train Acc: 0.8906
# Epoch: 7, Batch: 17, Train Loss: 0.3253, Train Acc: 0.8883
# Epoch: 7, Batch: 18, Train Loss: 0.3288, Train Acc: 0.8872
# Epoch: 7, Batch: 19, Train Loss: 0.3237, Train Acc: 0.8873
# Epoch: 7, Batch: 20, Train Loss: 0.3217, Train Acc: 0.8879
# Epoch: 7, Batch: 21, Train Loss: 0.3160, Train Acc: 0.8895
# Epoch: 7, Batch: 22, Train Loss: 0.3160, Train Acc: 0.8878
# Epoch: 7, Batch: 23, Train Loss: 0.3178, Train Acc: 0.8859
# Epoch: 7, Batch: 24, Train Loss: 0.3170, Train Acc: 0.8861
# Epoch: 7, Batch: 25, Train Loss: 0.3135, Train Acc: 0.8872
# Epoch: 7, Batch: 26, Train Loss: 0.3164, Train Acc: 0.8861
# Epoch: 7, Batch: 27, Train Loss: 0.3151, Train Acc: 0.8869
# Epoch: 7, Batch: 28, Train Loss: 0.3145, Train Acc: 0.8876
# Epoch: 7, Batch: 29, Train Loss: 0.3133, Train Acc: 0.8890
# Epoch: 7, Batch: 30, Train Loss: 0.3163, Train Acc: 0.8870
# Epoch: 7, Batch: 31, Train Loss: 0.3156, Train Acc: 0.8868
# Epoch: 7, Batch: 32, Train Loss: 0.3170, Train Acc: 0.8855
# Epoch: 7, Batch: 33, Train Loss: 0.3166, Train Acc: 0.8861
# Epoch: 7, Batch: 34, Train Loss: 0.3165, Train Acc: 0.8858
# Epoch: 7, Batch: 35, Train Loss: 0.3170, Train Acc: 0.8855
# Epoch: 7, Batch: 36, Train Loss: 0.3155, Train Acc: 0.8867
# Epoch: 7, Batch: 37, Train Loss: 0.3116, Train Acc: 0.8887
# Epoch: 7, Batch: 38, Train Loss: 0.3132, Train Acc: 0.8880
# Epoch: 7, Batch: 39, Train Loss: 0.3121, Train Acc: 0.8880
# Epoch: 7, Batch: 40, Train Loss: 0.3109, Train Acc: 0.8885
# Epoch: 7, Batch: 41, Train Loss: 0.3098, Train Acc: 0.8893
# Epoch: 7, Batch: 42, Train Loss: 0.3108, Train Acc: 0.8897
# Epoch: 7, Batch: 43, Train Loss: 0.3106, Train Acc: 0.8895
# Epoch: 7, Batch: 44, Train Loss: 0.3097, Train Acc: 0.8897
# Epoch: 7, Batch: 45, Train Loss: 0.3114, Train Acc: 0.8894
# Epoch: 7, Batch: 46, Train Loss: 0.3102, Train Acc: 0.8898
# Epoch: 7, Batch: 47, Train Loss: 0.3094, Train Acc: 0.8898
# Epoch: 7, Batch: 48, Train Loss: 0.3087, Train Acc: 0.8901
# Epoch: 7, Batch: 49, Train Loss: 0.3088, Train Acc: 0.8898
# Epoch: 7, Batch: 50, Train Loss: 0.3112, Train Acc: 0.8892
# Epoch: 7, Batch: 51, Train Loss: 0.3095, Train Acc: 0.8897
# Epoch: 7, Batch: 52, Train Loss: 0.3106, Train Acc: 0.8893
# Epoch: 7, Batch: 53, Train Loss: 0.3095, Train Acc: 0.8897
# Epoch: 7, Batch: 54, Train Loss: 0.3080, Train Acc: 0.8900
# Epoch: 7, Batch: 55, Train Loss: 0.3098, Train Acc: 0.8893
# Epoch: 7, Batch: 56, Train Loss: 0.3108, Train Acc: 0.8892
# Epoch: 7, Batch: 57, Train Loss: 0.3098, Train Acc: 0.8893
# Epoch: 7, Batch: 58, Train Loss: 0.3090, Train Acc: 0.8897
# Epoch: 7, Batch: 59, Train Loss: 0.3128, Train Acc: 0.8885
# Epoch: 7, Batch: 60, Train Loss: 0.3125, Train Acc: 0.8889
# Epoch: 7, Batch: 61, Train Loss: 0.3144, Train Acc: 0.8881
# Epoch: 7, Batch: 62, Train Loss: 0.3127, Train Acc: 0.8889
# Epoch: 7, Batch: 63, Train Loss: 0.3129, Train Acc: 0.8886
# Epoch: 7, Batch: 64, Train Loss: 0.3105, Train Acc: 0.8896
# Epoch: 7, Batch: 65, Train Loss: 0.3112, Train Acc: 0.8895
# Epoch: 7, Batch: 66, Train Loss: 0.3110, Train Acc: 0.8898
# Epoch: 7, Batch: 67, Train Loss: 0.3102, Train Acc: 0.8902
# Epoch: 7, Batch: 68, Train Loss: 0.3106, Train Acc: 0.8897
# Epoch: 7, Batch: 69, Train Loss: 0.3102, Train Acc: 0.8898
# Epoch: 7, Batch: 70, Train Loss: 0.3103, Train Acc: 0.8897
# Epoch: 7, Batch: 71, Train Loss: 0.3096, Train Acc: 0.8902
# Epoch: 7, Batch: 72, Train Loss: 0.3105, Train Acc: 0.8902
# Epoch: 7, Batch: 73, Train Loss: 0.3125, Train Acc: 0.8893
# Epoch: 7, Batch: 74, Train Loss: 0.3130, Train Acc: 0.8893
# Epoch: 7, Batch: 75, Train Loss: 0.3121, Train Acc: 0.8896
# Epoch: 7, Batch: 76, Train Loss: 0.3125, Train Acc: 0.8897
# Epoch: 7, Batch: 77, Train Loss: 0.3121, Train Acc: 0.8898
# Epoch: 7, Batch: 78, Train Loss: 0.3114, Train Acc: 0.8898
# Epoch: 7, Batch: 79, Train Loss: 0.3113, Train Acc: 0.8899
# Epoch: 8, Batch: 1, Train Loss: 0.2434, Train Acc: 0.9219
# Epoch: 8, Batch: 2, Train Loss: 0.2891, Train Acc: 0.8984
# Epoch: 8, Batch: 3, Train Loss: 0.2910, Train Acc: 0.8906
# Epoch: 8, Batch: 4, Train Loss: 0.2945, Train Acc: 0.8848
# Epoch: 8, Batch: 5, Train Loss: 0.2849, Train Acc: 0.8953
# Epoch: 8, Batch: 6, Train Loss: 0.2772, Train Acc: 0.8997
# Epoch: 8, Batch: 7, Train Loss: 0.2884, Train Acc: 0.8951
# Epoch: 8, Batch: 8, Train Loss: 0.2776, Train Acc: 0.8975
# Epoch: 8, Batch: 9, Train Loss: 0.2760, Train Acc: 0.8984
# Epoch: 8, Batch: 10, Train Loss: 0.2822, Train Acc: 0.8961
# Epoch: 8, Batch: 11, Train Loss: 0.2854, Train Acc: 0.8970
# Epoch: 8, Batch: 12, Train Loss: 0.2935, Train Acc: 0.8958
# Epoch: 8, Batch: 13, Train Loss: 0.2971, Train Acc: 0.8936
# Epoch: 8, Batch: 14, Train Loss: 0.2963, Train Acc: 0.8917
# Epoch: 8, Batch: 15, Train Loss: 0.2914, Train Acc: 0.8922
# Epoch: 8, Batch: 16, Train Loss: 0.3041, Train Acc: 0.8887
# Epoch: 8, Batch: 17, Train Loss: 0.2997, Train Acc: 0.8897
# Epoch: 8, Batch: 18, Train Loss: 0.3047, Train Acc: 0.8880
# Epoch: 8, Batch: 19, Train Loss: 0.3051, Train Acc: 0.8890
# Epoch: 8, Batch: 20, Train Loss: 0.3043, Train Acc: 0.8887
# Epoch: 8, Batch: 21, Train Loss: 0.3000, Train Acc: 0.8910
# Epoch: 8, Batch: 22, Train Loss: 0.2944, Train Acc: 0.8935
# Epoch: 8, Batch: 23, Train Loss: 0.2953, Train Acc: 0.8933
# Epoch: 8, Batch: 24, Train Loss: 0.2941, Train Acc: 0.8936
# Epoch: 8, Batch: 25, Train Loss: 0.2947, Train Acc: 0.8931
# Epoch: 8, Batch: 26, Train Loss: 0.2907, Train Acc: 0.8948
# Epoch: 8, Batch: 27, Train Loss: 0.2884, Train Acc: 0.8964
# Epoch: 8, Batch: 28, Train Loss: 0.2898, Train Acc: 0.8959
# Epoch: 8, Batch: 29, Train Loss: 0.2896, Train Acc: 0.8957
# Epoch: 8, Batch: 30, Train Loss: 0.2914, Train Acc: 0.8953
# Epoch: 8, Batch: 31, Train Loss: 0.2880, Train Acc: 0.8962
# Epoch: 8, Batch: 32, Train Loss: 0.2857, Train Acc: 0.8967
# Epoch: 8, Batch: 33, Train Loss: 0.2876, Train Acc: 0.8968
# Epoch: 8, Batch: 34, Train Loss: 0.2886, Train Acc: 0.8973
# Epoch: 8, Batch: 35, Train Loss: 0.2895, Train Acc: 0.8971
# Epoch: 8, Batch: 36, Train Loss: 0.2890, Train Acc: 0.8978
# Epoch: 8, Batch: 37, Train Loss: 0.2924, Train Acc: 0.8972
# Epoch: 8, Batch: 38, Train Loss: 0.2889, Train Acc: 0.8986
# Epoch: 8, Batch: 39, Train Loss: 0.2901, Train Acc: 0.8972
# Epoch: 8, Batch: 40, Train Loss: 0.2891, Train Acc: 0.8977
# Epoch: 8, Batch: 41, Train Loss: 0.2877, Train Acc: 0.8979
# Epoch: 8, Batch: 42, Train Loss: 0.2882, Train Acc: 0.8975
# Epoch: 8, Batch: 43, Train Loss: 0.2883, Train Acc: 0.8972
# Epoch: 8, Batch: 44, Train Loss: 0.2867, Train Acc: 0.8977
# Epoch: 8, Batch: 45, Train Loss: 0.2902, Train Acc: 0.8970
# Epoch: 8, Batch: 46, Train Loss: 0.2874, Train Acc: 0.8981
# Epoch: 8, Batch: 47, Train Loss: 0.2873, Train Acc: 0.8979
# Epoch: 8, Batch: 48, Train Loss: 0.2870, Train Acc: 0.8983
# Epoch: 8, Batch: 49, Train Loss: 0.2872, Train Acc: 0.8980
# Epoch: 8, Batch: 50, Train Loss: 0.2886, Train Acc: 0.8972
# Epoch: 8, Batch: 51, Train Loss: 0.2876, Train Acc: 0.8978
# Epoch: 8, Batch: 52, Train Loss: 0.2856, Train Acc: 0.8983
# Epoch: 8, Batch: 53, Train Loss: 0.2847, Train Acc: 0.8981
# Epoch: 8, Batch: 54, Train Loss: 0.2848, Train Acc: 0.8980
# Epoch: 8, Batch: 55, Train Loss: 0.2839, Train Acc: 0.8980
# Epoch: 8, Batch: 56, Train Loss: 0.2825, Train Acc: 0.8983
# Epoch: 8, Batch: 57, Train Loss: 0.2820, Train Acc: 0.8982
# Epoch: 8, Batch: 58, Train Loss: 0.2837, Train Acc: 0.8982
# Epoch: 8, Batch: 59, Train Loss: 0.2835, Train Acc: 0.8983
# Epoch: 8, Batch: 60, Train Loss: 0.2834, Train Acc: 0.8982
# Epoch: 8, Batch: 61, Train Loss: 0.2826, Train Acc: 0.8983
# Epoch: 8, Batch: 62, Train Loss: 0.2829, Train Acc: 0.8979
# Epoch: 8, Batch: 63, Train Loss: 0.2833, Train Acc: 0.8977
# Epoch: 8, Batch: 64, Train Loss: 0.2828, Train Acc: 0.8977
# Epoch: 8, Batch: 65, Train Loss: 0.2817, Train Acc: 0.8980
# Epoch: 8, Batch: 66, Train Loss: 0.2807, Train Acc: 0.8981
# Epoch: 8, Batch: 67, Train Loss: 0.2793, Train Acc: 0.8987
# Epoch: 8, Batch: 68, Train Loss: 0.2781, Train Acc: 0.8988
# Epoch: 8, Batch: 69, Train Loss: 0.2793, Train Acc: 0.8982
# Epoch: 8, Batch: 70, Train Loss: 0.2792, Train Acc: 0.8984
# Epoch: 8, Batch: 71, Train Loss: 0.2788, Train Acc: 0.8984
# Epoch: 8, Batch: 72, Train Loss: 0.2795, Train Acc: 0.8981
# Epoch: 8, Batch: 73, Train Loss: 0.2791, Train Acc: 0.8983
# Epoch: 8, Batch: 74, Train Loss: 0.2799, Train Acc: 0.8983
# Epoch: 8, Batch: 75, Train Loss: 0.2802, Train Acc: 0.8981
# Epoch: 8, Batch: 76, Train Loss: 0.2800, Train Acc: 0.8983
# Epoch: 8, Batch: 77, Train Loss: 0.2794, Train Acc: 0.8984
# Epoch: 8, Batch: 78, Train Loss: 0.2792, Train Acc: 0.8984
# Epoch: 8, Batch: 79, Train Loss: 0.2793, Train Acc: 0.8984
# Epoch: 9, Batch: 1, Train Loss: 0.1738, Train Acc: 0.9375
# Epoch: 9, Batch: 2, Train Loss: 0.1725, Train Acc: 0.9375
# Epoch: 9, Batch: 3, Train Loss: 0.1994, Train Acc: 0.9271
# Epoch: 9, Batch: 4, Train Loss: 0.2102, Train Acc: 0.9219
# Epoch: 9, Batch: 5, Train Loss: 0.2158, Train Acc: 0.9234
# Epoch: 9, Batch: 6, Train Loss: 0.2108, Train Acc: 0.9245
# Epoch: 9, Batch: 7, Train Loss: 0.2169, Train Acc: 0.9208
# Epoch: 9, Batch: 8, Train Loss: 0.2164, Train Acc: 0.9199
# Epoch: 9, Batch: 9, Train Loss: 0.2275, Train Acc: 0.9141
# Epoch: 9, Batch: 10, Train Loss: 0.2278, Train Acc: 0.9148
# Epoch: 9, Batch: 11, Train Loss: 0.2286, Train Acc: 0.9126
# Epoch: 9, Batch: 12, Train Loss: 0.2308, Train Acc: 0.9108
# Epoch: 9, Batch: 13, Train Loss: 0.2235, Train Acc: 0.9141
# Epoch: 9, Batch: 14, Train Loss: 0.2262, Train Acc: 0.9152
# Epoch: 9, Batch: 15, Train Loss: 0.2257, Train Acc: 0.9156
# Epoch: 9, Batch: 16, Train Loss: 0.2341, Train Acc: 0.9136
# Epoch: 9, Batch: 17, Train Loss: 0.2403, Train Acc: 0.9122
# Epoch: 9, Batch: 18, Train Loss: 0.2376, Train Acc: 0.9145
# Epoch: 9, Batch: 19, Train Loss: 0.2410, Train Acc: 0.9128
# Epoch: 9, Batch: 20, Train Loss: 0.2398, Train Acc: 0.9141
# Epoch: 9, Batch: 21, Train Loss: 0.2457, Train Acc: 0.9111
# Epoch: 9, Batch: 22, Train Loss: 0.2504, Train Acc: 0.9098
# Epoch: 9, Batch: 23, Train Loss: 0.2508, Train Acc: 0.9100
# Epoch: 9, Batch: 24, Train Loss: 0.2508, Train Acc: 0.9098
# Epoch: 9, Batch: 25, Train Loss: 0.2508, Train Acc: 0.9094
# Epoch: 9, Batch: 26, Train Loss: 0.2526, Train Acc: 0.9093
# Epoch: 9, Batch: 27, Train Loss: 0.2572, Train Acc: 0.9086
# Epoch: 9, Batch: 28, Train Loss: 0.2575, Train Acc: 0.9074
# Epoch: 9, Batch: 29, Train Loss: 0.2605, Train Acc: 0.9068
# Epoch: 9, Batch: 30, Train Loss: 0.2643, Train Acc: 0.9057
# Epoch: 9, Batch: 31, Train Loss: 0.2607, Train Acc: 0.9070
# Epoch: 9, Batch: 32, Train Loss: 0.2610, Train Acc: 0.9067
# Epoch: 9, Batch: 33, Train Loss: 0.2587, Train Acc: 0.9077
# Epoch: 9, Batch: 34, Train Loss: 0.2587, Train Acc: 0.9079
# Epoch: 9, Batch: 35, Train Loss: 0.2619, Train Acc: 0.9067
# Epoch: 9, Batch: 36, Train Loss: 0.2601, Train Acc: 0.9073
# Epoch: 9, Batch: 37, Train Loss: 0.2611, Train Acc: 0.9073
# Epoch: 9, Batch: 38, Train Loss: 0.2603, Train Acc: 0.9071
# Epoch: 9, Batch: 39, Train Loss: 0.2637, Train Acc: 0.9062
# Epoch: 9, Batch: 40, Train Loss: 0.2620, Train Acc: 0.9066
# Epoch: 9, Batch: 41, Train Loss: 0.2607, Train Acc: 0.9064
# Epoch: 9, Batch: 42, Train Loss: 0.2620, Train Acc: 0.9059
# Epoch: 9, Batch: 43, Train Loss: 0.2610, Train Acc: 0.9064
# Epoch: 9, Batch: 44, Train Loss: 0.2590, Train Acc: 0.9068
# Epoch: 9, Batch: 45, Train Loss: 0.2578, Train Acc: 0.9075
# Epoch: 9, Batch: 46, Train Loss: 0.2568, Train Acc: 0.9079
# Epoch: 9, Batch: 47, Train Loss: 0.2585, Train Acc: 0.9074
# Epoch: 9, Batch: 48, Train Loss: 0.2571, Train Acc: 0.9079
# Epoch: 9, Batch: 49, Train Loss: 0.2576, Train Acc: 0.9074
# Epoch: 9, Batch: 50, Train Loss: 0.2556, Train Acc: 0.9078
# Epoch: 9, Batch: 51, Train Loss: 0.2563, Train Acc: 0.9075
# Epoch: 9, Batch: 52, Train Loss: 0.2551, Train Acc: 0.9078
# Epoch: 9, Batch: 53, Train Loss: 0.2554, Train Acc: 0.9074
# Epoch: 9, Batch: 54, Train Loss: 0.2530, Train Acc: 0.9077
# Epoch: 9, Batch: 55, Train Loss: 0.2534, Train Acc: 0.9075
# Epoch: 9, Batch: 56, Train Loss: 0.2527, Train Acc: 0.9079
# Epoch: 9, Batch: 57, Train Loss: 0.2512, Train Acc: 0.9084
# Epoch: 9, Batch: 58, Train Loss: 0.2501, Train Acc: 0.9092
# Epoch: 9, Batch: 59, Train Loss: 0.2507, Train Acc: 0.9092
# Epoch: 9, Batch: 60, Train Loss: 0.2512, Train Acc: 0.9094
# Epoch: 9, Batch: 61, Train Loss: 0.2547, Train Acc: 0.9088
# Epoch: 9, Batch: 62, Train Loss: 0.2559, Train Acc: 0.9080
# Epoch: 9, Batch: 63, Train Loss: 0.2561, Train Acc: 0.9080
# Epoch: 9, Batch: 64, Train Loss: 0.2569, Train Acc: 0.9082
# Epoch: 9, Batch: 65, Train Loss: 0.2576, Train Acc: 0.9077
# Epoch: 9, Batch: 66, Train Loss: 0.2566, Train Acc: 0.9081
# Epoch: 9, Batch: 67, Train Loss: 0.2564, Train Acc: 0.9085
# Epoch: 9, Batch: 68, Train Loss: 0.2559, Train Acc: 0.9087
# Epoch: 9, Batch: 69, Train Loss: 0.2563, Train Acc: 0.9084
# Epoch: 9, Batch: 70, Train Loss: 0.2552, Train Acc: 0.9089
# Epoch: 9, Batch: 71, Train Loss: 0.2547, Train Acc: 0.9091
# Epoch: 9, Batch: 72, Train Loss: 0.2536, Train Acc: 0.9093
# Epoch: 9, Batch: 73, Train Loss: 0.2552, Train Acc: 0.9089
# Epoch: 9, Batch: 74, Train Loss: 0.2550, Train Acc: 0.9091
# Epoch: 9, Batch: 75, Train Loss: 0.2549, Train Acc: 0.9092
# Epoch: 9, Batch: 76, Train Loss: 0.2562, Train Acc: 0.9091
# Epoch: 9, Batch: 77, Train Loss: 0.2574, Train Acc: 0.9089
# Epoch: 9, Batch: 78, Train Loss: 0.2571, Train Acc: 0.9087
# Epoch: 9, Batch: 79, Train Loss: 0.2610, Train Acc: 0.9085
# Epoch: 10, Batch: 1, Train Loss: 0.1906, Train Acc: 0.9219
# Epoch: 10, Batch: 2, Train Loss: 0.1864, Train Acc: 0.9297
# Epoch: 10, Batch: 3, Train Loss: 0.2057, Train Acc: 0.9323
# Epoch: 10, Batch: 4, Train Loss: 0.2446, Train Acc: 0.9121
# Epoch: 10, Batch: 5, Train Loss: 0.2645, Train Acc: 0.9047
# Epoch: 10, Batch: 6, Train Loss: 0.2553, Train Acc: 0.9076
# Epoch: 10, Batch: 7, Train Loss: 0.2576, Train Acc: 0.9074
# Epoch: 10, Batch: 8, Train Loss: 0.2622, Train Acc: 0.9082
# Epoch: 10, Batch: 9, Train Loss: 0.2517, Train Acc: 0.9132
# Epoch: 10, Batch: 10, Train Loss: 0.2418, Train Acc: 0.9172
# Epoch: 10, Batch: 11, Train Loss: 0.2499, Train Acc: 0.9134
# Epoch: 10, Batch: 12, Train Loss: 0.2482, Train Acc: 0.9154
# Epoch: 10, Batch: 13, Train Loss: 0.2459, Train Acc: 0.9165
# Epoch: 10, Batch: 14, Train Loss: 0.2672, Train Acc: 0.9141
# Epoch: 10, Batch: 15, Train Loss: 0.2718, Train Acc: 0.9109
# Epoch: 10, Batch: 16, Train Loss: 0.2711, Train Acc: 0.9102
# Epoch: 10, Batch: 17, Train Loss: 0.2653, Train Acc: 0.9118
# Epoch: 10, Batch: 18, Train Loss: 0.2653, Train Acc: 0.9123
# Epoch: 10, Batch: 19, Train Loss: 0.2687, Train Acc: 0.9112
# Epoch: 10, Batch: 20, Train Loss: 0.2732, Train Acc: 0.9098
# Epoch: 10, Batch: 21, Train Loss: 0.2703, Train Acc: 0.9103
# Epoch: 10, Batch: 22, Train Loss: 0.2669, Train Acc: 0.9119
# Epoch: 10, Batch: 23, Train Loss: 0.2718, Train Acc: 0.9103
# Epoch: 10, Batch: 24, Train Loss: 0.2687, Train Acc: 0.9111
# Epoch: 10, Batch: 25, Train Loss: 0.2688, Train Acc: 0.9113
# Epoch: 10, Batch: 26, Train Loss: 0.2704, Train Acc: 0.9102
# Epoch: 10, Batch: 27, Train Loss: 0.2702, Train Acc: 0.9094
# Epoch: 10, Batch: 28, Train Loss: 0.2699, Train Acc: 0.9096
# Epoch: 10, Batch: 29, Train Loss: 0.2720, Train Acc: 0.9076
# Epoch: 10, Batch: 30, Train Loss: 0.2721, Train Acc: 0.9081
# Epoch: 10, Batch: 31, Train Loss: 0.2730, Train Acc: 0.9080
# Epoch: 10, Batch: 32, Train Loss: 0.2724, Train Acc: 0.9080
# Epoch: 10, Batch: 33, Train Loss: 0.2696, Train Acc: 0.9084
# Epoch: 10, Batch: 34, Train Loss: 0.2668, Train Acc: 0.9090
# Epoch: 10, Batch: 35, Train Loss: 0.2728, Train Acc: 0.9069
# Epoch: 10, Batch: 36, Train Loss: 0.2708, Train Acc: 0.9071
# Epoch: 10, Batch: 37, Train Loss: 0.2698, Train Acc: 0.9073
# Epoch: 10, Batch: 38, Train Loss: 0.2712, Train Acc: 0.9075
# Epoch: 10, Batch: 39, Train Loss: 0.2726, Train Acc: 0.9073
# Epoch: 10, Batch: 40, Train Loss: 0.2721, Train Acc: 0.9066
# Epoch: 10, Batch: 41, Train Loss: 0.2718, Train Acc: 0.9066
# Epoch: 10, Batch: 42, Train Loss: 0.2724, Train Acc: 0.9068
# Epoch: 10, Batch: 43, Train Loss: 0.2701, Train Acc: 0.9081
# Epoch: 10, Batch: 44, Train Loss: 0.2686, Train Acc: 0.9087
# Epoch: 10, Batch: 45, Train Loss: 0.2684, Train Acc: 0.9087
# Epoch: 10, Batch: 46, Train Loss: 0.2680, Train Acc: 0.9079
# Epoch: 10, Batch: 47, Train Loss: 0.2676, Train Acc: 0.9076
# Epoch: 10, Batch: 48, Train Loss: 0.2670, Train Acc: 0.9074
# Epoch: 10, Batch: 49, Train Loss: 0.2666, Train Acc: 0.9070
# Epoch: 10, Batch: 50, Train Loss: 0.2659, Train Acc: 0.9073
# Epoch: 10, Batch: 51, Train Loss: 0.2646, Train Acc: 0.9073
# Epoch: 10, Batch: 52, Train Loss: 0.2640, Train Acc: 0.9075
# Epoch: 10, Batch: 53, Train Loss: 0.2625, Train Acc: 0.9076
# Epoch: 10, Batch: 54, Train Loss: 0.2622, Train Acc: 0.9076
# Epoch: 10, Batch: 55, Train Loss: 0.2613, Train Acc: 0.9078
# Epoch: 10, Batch: 56, Train Loss: 0.2615, Train Acc: 0.9078
# Epoch: 10, Batch: 57, Train Loss: 0.2628, Train Acc: 0.9078
# Epoch: 10, Batch: 58, Train Loss: 0.2625, Train Acc: 0.9077
# Epoch: 10, Batch: 59, Train Loss: 0.2629, Train Acc: 0.9074
# Epoch: 10, Batch: 60, Train Loss: 0.2631, Train Acc: 0.9077
# Epoch: 10, Batch: 61, Train Loss: 0.2622, Train Acc: 0.9083
# Epoch: 10, Batch: 62, Train Loss: 0.2603, Train Acc: 0.9088
# Epoch: 10, Batch: 63, Train Loss: 0.2627, Train Acc: 0.9077
# Epoch: 10, Batch: 64, Train Loss: 0.2630, Train Acc: 0.9075
# Epoch: 10, Batch: 65, Train Loss: 0.2635, Train Acc: 0.9077
# Epoch: 10, Batch: 66, Train Loss: 0.2627, Train Acc: 0.9077
# Epoch: 10, Batch: 67, Train Loss: 0.2668, Train Acc: 0.9062
# Epoch: 10, Batch: 68, Train Loss: 0.2676, Train Acc: 0.9059
# Epoch: 10, Batch: 69, Train Loss: 0.2677, Train Acc: 0.9060
# Epoch: 10, Batch: 70, Train Loss: 0.2663, Train Acc: 0.9068
# Epoch: 10, Batch: 71, Train Loss: 0.2673, Train Acc: 0.9062
# Epoch: 10, Batch: 72, Train Loss: 0.2669, Train Acc: 0.9062
# Epoch: 10, Batch: 73, Train Loss: 0.2663, Train Acc: 0.9065
# Epoch: 10, Batch: 74, Train Loss: 0.2658, Train Acc: 0.9066
# Epoch: 10, Batch: 75, Train Loss: 0.2665, Train Acc: 0.9059
# Epoch: 10, Batch: 76, Train Loss: 0.2671, Train Acc: 0.9060
# Epoch: 10, Batch: 77, Train Loss: 0.2664, Train Acc: 0.9062
# Epoch: 10, Batch: 78, Train Loss: 0.2670, Train Acc: 0.9061
# Epoch: 10, Batch: 79, Train Loss: 0.2675, Train Acc: 0.9058
# Epoch: 11, Batch: 1, Train Loss: 0.1802, Train Acc: 0.9219
# Epoch: 11, Batch: 2, Train Loss: 0.1629, Train Acc: 0.9453
# Epoch: 11, Batch: 3, Train Loss: 0.1770, Train Acc: 0.9427
# Epoch: 11, Batch: 4, Train Loss: 0.1628, Train Acc: 0.9473
# Epoch: 11, Batch: 5, Train Loss: 0.1673, Train Acc: 0.9406
# Epoch: 11, Batch: 6, Train Loss: 0.1710, Train Acc: 0.9401
# Epoch: 11, Batch: 7, Train Loss: 0.2132, Train Acc: 0.9286
# Epoch: 11, Batch: 8, Train Loss: 0.2041, Train Acc: 0.9316
# Epoch: 11, Batch: 9, Train Loss: 0.1983, Train Acc: 0.9314
# Epoch: 11, Batch: 10, Train Loss: 0.2033, Train Acc: 0.9313
# Epoch: 11, Batch: 11, Train Loss: 0.2080, Train Acc: 0.9297
# Epoch: 11, Batch: 12, Train Loss: 0.2125, Train Acc: 0.9271
# Epoch: 11, Batch: 13, Train Loss: 0.2193, Train Acc: 0.9231
# Epoch: 11, Batch: 14, Train Loss: 0.2147, Train Acc: 0.9241
# Epoch: 11, Batch: 15, Train Loss: 0.2127, Train Acc: 0.9255
# Epoch: 11, Batch: 16, Train Loss: 0.2092, Train Acc: 0.9263
# Epoch: 11, Batch: 17, Train Loss: 0.2125, Train Acc: 0.9260
# Epoch: 11, Batch: 18, Train Loss: 0.2243, Train Acc: 0.9236
# Epoch: 11, Batch: 19, Train Loss: 0.2253, Train Acc: 0.9223
# Epoch: 11, Batch: 20, Train Loss: 0.2286, Train Acc: 0.9227
# Epoch: 11, Batch: 21, Train Loss: 0.2301, Train Acc: 0.9204
# Epoch: 11, Batch: 22, Train Loss: 0.2308, Train Acc: 0.9201
# Epoch: 11, Batch: 23, Train Loss: 0.2362, Train Acc: 0.9181
# ...
# Epoch: 17, Batch: 51, Train Loss: 1.1759, Train Acc: 0.6881
# Epoch: 17, Batch: 52, Train Loss: 1.1637, Train Acc: 0.6902
# Epoch: 17, Batch: 53, Train Loss: 1.1542, Train Acc: 0.6913
# Epoch: 17, Batch: 54, Train Loss: 1.1451, Train Acc: 0.6926
# Epoch: 17, Batch: 55, Train Loss: 1.1348, Train Acc: 0.6946
# Epoch: 17, Batch: 56, Train Loss: 1.1265, Train Acc: 0.6956
# Epoch: 17, Batch: 57, Train Loss: 1.1201, Train Acc: 0.6956
# Epoch: 17, Batch: 58, Train Loss: 1.1109, Train Acc: 0.6973
# Epoch: 17, Batch: 59, Train Loss: 1.1028, Train Acc: 0.6992
# Epoch: 17, Batch: 60, Train Loss: 1.0943, Train Acc: 0.7005
# Epoch: 17, Batch: 61, Train Loss: 1.0872, Train Acc: 0.7015
# Epoch: 17, Batch: 62, Train Loss: 1.0816, Train Acc: 0.7014
# Epoch: 17, Batch: 63, Train Loss: 1.0728, Train Acc: 0.7035
# Epoch: 17, Batch: 64, Train Loss: 1.0668, Train Acc: 0.7045
# Epoch: 17, Batch: 65, Train Loss: 1.0607, Train Acc: 0.7060
# Epoch: 17, Batch: 66, Train Loss: 1.0535, Train Acc: 0.7063
# Epoch: 17, Batch: 67, Train Loss: 1.0465, Train Acc: 0.7072
# Epoch: 17, Batch: 68, Train Loss: 1.0399, Train Acc: 0.7078
# Epoch: 17, Batch: 69, Train Loss: 1.0340, Train Acc: 0.7084
# Epoch: 17, Batch: 70, Train Loss: 1.0290, Train Acc: 0.7090
# Epoch: 17, Batch: 71, Train Loss: 1.0251, Train Acc: 0.7099
# Epoch: 17, Batch: 72, Train Loss: 1.0197, Train Acc: 0.7103
# Epoch: 17, Batch: 73, Train Loss: 1.0155, Train Acc: 0.7106
# Epoch: 17, Batch: 74, Train Loss: 1.0098, Train Acc: 0.7113
# Epoch: 17, Batch: 75, Train Loss: 1.0040, Train Acc: 0.7119
# Epoch: 17, Batch: 76, Train Loss: 0.9977, Train Acc: 0.7126
# Epoch: 17, Batch: 77, Train Loss: 0.9929, Train Acc: 0.7132
# Epoch: 17, Batch: 78, Train Loss: 0.9882, Train Acc: 0.7136
# Epoch: 17, Batch: 79, Train Loss: 0.9883, Train Acc: 0.7133
# Epoch: 18, Batch: 1, Train Loss: 0.7664, Train Acc: 0.7344
# Epoch: 18, Batch: 2, Train Loss: 0.6406, Train Acc: 0.7852
# Epoch: 18, Batch: 3, Train Loss: 0.6480, Train Acc: 0.7812
# Epoch: 18, Batch: 4, Train Loss: 0.6430, Train Acc: 0.7793
# Epoch: 18, Batch: 5, Train Loss: 0.6613, Train Acc: 0.7656
# Epoch: 18, Batch: 6, Train Loss: 0.6673, Train Acc: 0.7617
# Epoch: 18, Batch: 7, Train Loss: 0.6409, Train Acc: 0.7679
# Epoch: 18, Batch: 8, Train Loss: 0.6383, Train Acc: 0.7676
# Epoch: 18, Batch: 9, Train Loss: 0.6296, Train Acc: 0.7656
# Epoch: 18, Batch: 10, Train Loss: 0.6254, Train Acc: 0.7641
# Epoch: 18, Batch: 11, Train Loss: 0.6237, Train Acc: 0.7678
# Epoch: 18, Batch: 12, Train Loss: 0.6076, Train Acc: 0.7734
# Epoch: 18, Batch: 13, Train Loss: 0.6028, Train Acc: 0.7728
# Epoch: 18, Batch: 14, Train Loss: 0.6010, Train Acc: 0.7734
# Epoch: 18, Batch: 15, Train Loss: 0.6048, Train Acc: 0.7703
# Epoch: 18, Batch: 16, Train Loss: 0.6052, Train Acc: 0.7705
# Epoch: 18, Batch: 17, Train Loss: 0.6189, Train Acc: 0.7707
# Epoch: 18, Batch: 18, Train Loss: 0.6329, Train Acc: 0.7661
# Epoch: 18, Batch: 19, Train Loss: 0.6307, Train Acc: 0.7677
# Epoch: 18, Batch: 20, Train Loss: 0.6230, Train Acc: 0.7684
# Epoch: 18, Batch: 21, Train Loss: 0.6143, Train Acc: 0.7719
# Epoch: 18, Batch: 22, Train Loss: 0.6099, Train Acc: 0.7710
# Epoch: 18, Batch: 23, Train Loss: 0.6371, Train Acc: 0.7704
# Epoch: 18, Batch: 24, Train Loss: 0.6261, Train Acc: 0.7725
# Epoch: 18, Batch: 25, Train Loss: 0.6403, Train Acc: 0.7694
# Epoch: 18, Batch: 26, Train Loss: 0.6368, Train Acc: 0.7716
# Epoch: 18, Batch: 27, Train Loss: 0.6359, Train Acc: 0.7720
# Epoch: 18, Batch: 28, Train Loss: 0.6260, Train Acc: 0.7751
# Epoch: 18, Batch: 29, Train Loss: 0.6194, Train Acc: 0.7775
# Epoch: 18, Batch: 30, Train Loss: 0.6204, Train Acc: 0.7771
# Epoch: 18, Batch: 31, Train Loss: 0.6228, Train Acc: 0.7757
# Epoch: 18, Batch: 32, Train Loss: 0.6220, Train Acc: 0.7756
# Epoch: 18, Batch: 33, Train Loss: 0.6176, Train Acc: 0.7779
# Epoch: 18, Batch: 34, Train Loss: 0.6150, Train Acc: 0.7783
# Epoch: 18, Batch: 35, Train Loss: 0.6102, Train Acc: 0.7799
# Epoch: 18, Batch: 36, Train Loss: 0.6081, Train Acc: 0.7799
# Epoch: 18, Batch: 37, Train Loss: 0.6066, Train Acc: 0.7812
# Epoch: 18, Batch: 38, Train Loss: 0.6021, Train Acc: 0.7831
# Epoch: 18, Batch: 39, Train Loss: 0.6023, Train Acc: 0.7831
# Epoch: 18, Batch: 40, Train Loss: 0.5995, Train Acc: 0.7848
# Epoch: 18, Batch: 41, Train Loss: 0.5953, Train Acc: 0.7862
# Epoch: 18, Batch: 42, Train Loss: 0.5943, Train Acc: 0.7859
# Epoch: 18, Batch: 43, Train Loss: 0.5930, Train Acc: 0.7863
# Epoch: 18, Batch: 44, Train Loss: 0.5906, Train Acc: 0.7871
# Epoch: 18, Batch: 45, Train Loss: 0.5911, Train Acc: 0.7861
# Epoch: 18, Batch: 46, Train Loss: 0.5895, Train Acc: 0.7862
# Epoch: 18, Batch: 47, Train Loss: 0.5874, Train Acc: 0.7869
# Epoch: 18, Batch: 48, Train Loss: 0.5829, Train Acc: 0.7882
# Epoch: 18, Batch: 49, Train Loss: 0.5811, Train Acc: 0.7889
# Epoch: 18, Batch: 50, Train Loss: 0.5803, Train Acc: 0.7887
# Epoch: 18, Batch: 51, Train Loss: 0.5805, Train Acc: 0.7880
# Epoch: 18, Batch: 52, Train Loss: 0.5788, Train Acc: 0.7885
# Epoch: 18, Batch: 53, Train Loss: 0.5772, Train Acc: 0.7894
# Epoch: 18, Batch: 54, Train Loss: 0.5753, Train Acc: 0.7905
# Epoch: 18, Batch: 55, Train Loss: 0.5736, Train Acc: 0.7909
# Epoch: 18, Batch: 56, Train Loss: 0.5739, Train Acc: 0.7913
# Epoch: 18, Batch: 57, Train Loss: 0.5720, Train Acc: 0.7919
# Epoch: 18, Batch: 58, Train Loss: 0.5742, Train Acc: 0.7908
# Epoch: 18, Batch: 59, Train Loss: 0.5725, Train Acc: 0.7912
# Epoch: 18, Batch: 60, Train Loss: 0.5713, Train Acc: 0.7918
# Epoch: 18, Batch: 61, Train Loss: 0.5686, Train Acc: 0.7928
# Epoch: 18, Batch: 62, Train Loss: 0.5685, Train Acc: 0.7928
# Epoch: 18, Batch: 63, Train Loss: 0.5672, Train Acc: 0.7930
# Epoch: 18, Batch: 64, Train Loss: 0.5738, Train Acc: 0.7919
# Epoch: 18, Batch: 65, Train Loss: 0.5726, Train Acc: 0.7923
# Epoch: 18, Batch: 66, Train Loss: 0.5726, Train Acc: 0.7926
# Epoch: 18, Batch: 67, Train Loss: 0.5730, Train Acc: 0.7928
# Epoch: 18, Batch: 68, Train Loss: 0.5714, Train Acc: 0.7930
# Epoch: 18, Batch: 69, Train Loss: 0.5721, Train Acc: 0.7929
# Epoch: 18, Batch: 70, Train Loss: 0.5727, Train Acc: 0.7926
# Epoch: 18, Batch: 71, Train Loss: 0.5747, Train Acc: 0.7923
# Epoch: 18, Batch: 72, Train Loss: 0.5738, Train Acc: 0.7924
# Epoch: 18, Batch: 73, Train Loss: 0.5735, Train Acc: 0.7920
# Epoch: 18, Batch: 74, Train Loss: 0.5718, Train Acc: 0.7923
# Epoch: 18, Batch: 75, Train Loss: 0.5716, Train Acc: 0.7924
# Epoch: 18, Batch: 76, Train Loss: 0.5717, Train Acc: 0.7925
# Epoch: 18, Batch: 77, Train Loss: 0.5720, Train Acc: 0.7928
# Epoch: 18, Batch: 78, Train Loss: 0.5700, Train Acc: 0.7937
# Epoch: 18, Batch: 79, Train Loss: 0.5696, Train Acc: 0.7938
# Epoch: 19, Batch: 1, Train Loss: 0.6534, Train Acc: 0.7344
# Epoch: 19, Batch: 2, Train Loss: 0.5968, Train Acc: 0.7578
# Epoch: 19, Batch: 3, Train Loss: 0.5586, Train Acc: 0.7865
# Epoch: 19, Batch: 4, Train Loss: 0.5592, Train Acc: 0.7988
# Epoch: 19, Batch: 5, Train Loss: 0.5262, Train Acc: 0.8031
# Epoch: 19, Batch: 6, Train Loss: 0.5189, Train Acc: 0.8086
# Epoch: 19, Batch: 7, Train Loss: 0.5195, Train Acc: 0.8058
# Epoch: 19, Batch: 8, Train Loss: 0.5062, Train Acc: 0.8145
# Epoch: 19, Batch: 9, Train Loss: 0.5158, Train Acc: 0.8108
# Epoch: 19, Batch: 10, Train Loss: 0.5004, Train Acc: 0.8141
# Epoch: 19, Batch: 11, Train Loss: 0.5046, Train Acc: 0.8153
# Epoch: 19, Batch: 12, Train Loss: 0.5167, Train Acc: 0.8118
# Epoch: 19, Batch: 13, Train Loss: 0.5181, Train Acc: 0.8089
# Epoch: 19, Batch: 14, Train Loss: 0.5142, Train Acc: 0.8097
# Epoch: 19, Batch: 15, Train Loss: 0.5064, Train Acc: 0.8130
# Epoch: 19, Batch: 16, Train Loss: 0.4971, Train Acc: 0.8169
# Epoch: 19, Batch: 17, Train Loss: 0.4930, Train Acc: 0.8185
# Epoch: 19, Batch: 18, Train Loss: 0.4882, Train Acc: 0.8194
# Epoch: 19, Batch: 19, Train Loss: 0.4902, Train Acc: 0.8178
# Epoch: 19, Batch: 20, Train Loss: 0.4899, Train Acc: 0.8187
# Epoch: 19, Batch: 21, Train Loss: 0.4904, Train Acc: 0.8199
# Epoch: 19, Batch: 22, Train Loss: 0.4918, Train Acc: 0.8196
# Epoch: 19, Batch: 23, Train Loss: 0.4908, Train Acc: 0.8203
# Epoch: 19, Batch: 24, Train Loss: 0.4919, Train Acc: 0.8206
# Epoch: 19, Batch: 25, Train Loss: 0.4893, Train Acc: 0.8222
# Epoch: 19, Batch: 26, Train Loss: 0.4835, Train Acc: 0.8233
# Epoch: 19, Batch: 27, Train Loss: 0.4816, Train Acc: 0.8238
# Epoch: 19, Batch: 28, Train Loss: 0.4785, Train Acc: 0.8251
# Epoch: 19, Batch: 29, Train Loss: 0.4812, Train Acc: 0.8252
# Epoch: 19, Batch: 30, Train Loss: 0.4826, Train Acc: 0.8240
# Epoch: 19, Batch: 31, Train Loss: 0.4781, Train Acc: 0.8256
# Epoch: 19, Batch: 32, Train Loss: 0.4770, Train Acc: 0.8257
# Epoch: 19, Batch: 33, Train Loss: 0.4728, Train Acc: 0.8267
# Epoch: 19, Batch: 34, Train Loss: 0.4722, Train Acc: 0.8270
# Epoch: 19, Batch: 35, Train Loss: 0.4700, Train Acc: 0.8283
# Epoch: 19, Batch: 36, Train Loss: 0.4653, Train Acc: 0.8296
# Epoch: 19, Batch: 37, Train Loss: 0.4640, Train Acc: 0.8296
# Epoch: 19, Batch: 38, Train Loss: 0.4629, Train Acc: 0.8300
# Epoch: 19, Batch: 39, Train Loss: 0.4617, Train Acc: 0.8297
# Epoch: 19, Batch: 40, Train Loss: 0.4643, Train Acc: 0.8293
# Epoch: 19, Batch: 41, Train Loss: 0.4616, Train Acc: 0.8298
# Epoch: 19, Batch: 42, Train Loss: 0.4610, Train Acc: 0.8304
# Epoch: 19, Batch: 43, Train Loss: 0.4601, Train Acc: 0.8310
# Epoch: 19, Batch: 44, Train Loss: 0.4622, Train Acc: 0.8301
# Epoch: 19, Batch: 45, Train Loss: 0.4592, Train Acc: 0.8307
# Epoch: 19, Batch: 46, Train Loss: 0.4583, Train Acc: 0.8319
# Epoch: 19, Batch: 47, Train Loss: 0.4588, Train Acc: 0.8314
# Epoch: 19, Batch: 48, Train Loss: 0.4579, Train Acc: 0.8315
# Epoch: 19, Batch: 49, Train Loss: 0.4568, Train Acc: 0.8318
# Epoch: 19, Batch: 50, Train Loss: 0.4570, Train Acc: 0.8316
# Epoch: 19, Batch: 51, Train Loss: 0.4579, Train Acc: 0.8310
# Epoch: 19, Batch: 52, Train Loss: 0.4560, Train Acc: 0.8317
# Epoch: 19, Batch: 53, Train Loss: 0.4556, Train Acc: 0.8321
# Epoch: 19, Batch: 54, Train Loss: 0.4562, Train Acc: 0.8313
# Epoch: 19, Batch: 55, Train Loss: 0.4590, Train Acc: 0.8310
# Epoch: 19, Batch: 56, Train Loss: 0.4582, Train Acc: 0.8311
# Epoch: 19, Batch: 57, Train Loss: 0.4588, Train Acc: 0.8306
# Epoch: 19, Batch: 58, Train Loss: 0.4590, Train Acc: 0.8315
# Epoch: 19, Batch: 59, Train Loss: 0.4602, Train Acc: 0.8313
# Epoch: 19, Batch: 60, Train Loss: 0.4618, Train Acc: 0.8309
# Epoch: 19, Batch: 61, Train Loss: 0.4619, Train Acc: 0.8309
# Epoch: 19, Batch: 62, Train Loss: 0.4619, Train Acc: 0.8309
# Epoch: 19, Batch: 63, Train Loss: 0.4599, Train Acc: 0.8315
# Epoch: 19, Batch: 64, Train Loss: 0.4588, Train Acc: 0.8317
# Epoch: 19, Batch: 65, Train Loss: 0.4600, Train Acc: 0.8316
# Epoch: 19, Batch: 66, Train Loss: 0.4603, Train Acc: 0.8317
# Epoch: 19, Batch: 67, Train Loss: 0.4607, Train Acc: 0.8316
# Epoch: 19, Batch: 68, Train Loss: 0.4590, Train Acc: 0.8323
# Epoch: 19, Batch: 69, Train Loss: 0.4586, Train Acc: 0.8328
# Epoch: 19, Batch: 70, Train Loss: 0.4592, Train Acc: 0.8324
# Epoch: 19, Batch: 71, Train Loss: 0.4583, Train Acc: 0.8326
# Epoch: 19, Batch: 72, Train Loss: 0.4582, Train Acc: 0.8328
# Epoch: 19, Batch: 73, Train Loss: 0.4588, Train Acc: 0.8325
# Epoch: 19, Batch: 74, Train Loss: 0.4587, Train Acc: 0.8322
# Epoch: 19, Batch: 75, Train Loss: 0.4588, Train Acc: 0.8321
# Epoch: 19, Batch: 76, Train Loss: 0.4577, Train Acc: 0.8323
# Epoch: 19, Batch: 77, Train Loss: 0.4573, Train Acc: 0.8324
# Epoch: 19, Batch: 78, Train Loss: 0.4563, Train Acc: 0.8332
# Epoch: 19, Batch: 79, Train Loss: 0.4579, Train Acc: 0.8330
# Epoch: 20, Batch: 1, Train Loss: 0.3858, Train Acc: 0.8594
# Epoch: 20, Batch: 2, Train Loss: 0.4978, Train Acc: 0.8359
# Epoch: 20, Batch: 3, Train Loss: 0.4972, Train Acc: 0.8359
# Epoch: 20, Batch: 4, Train Loss: 0.4620, Train Acc: 0.8398
# Epoch: 20, Batch: 5, Train Loss: 0.4518, Train Acc: 0.8328
# Epoch: 20, Batch: 6, Train Loss: 0.4462, Train Acc: 0.8372
# Epoch: 20, Batch: 7, Train Loss: 0.4429, Train Acc: 0.8382
# Epoch: 20, Batch: 8, Train Loss: 0.4393, Train Acc: 0.8369
# Epoch: 20, Batch: 9, Train Loss: 0.4399, Train Acc: 0.8368
# Epoch: 20, Batch: 10, Train Loss: 0.4432, Train Acc: 0.8320
# Epoch: 20, Batch: 11, Train Loss: 0.4540, Train Acc: 0.8303
# Epoch: 20, Batch: 12, Train Loss: 0.4465, Train Acc: 0.8340
# Epoch: 20, Batch: 13, Train Loss: 0.4435, Train Acc: 0.8341
# Epoch: 20, Batch: 14, Train Loss: 0.4548, Train Acc: 0.8276
# Epoch: 20, Batch: 15, Train Loss: 0.4516, Train Acc: 0.8307
# Epoch: 20, Batch: 16, Train Loss: 0.4435, Train Acc: 0.8354
# Epoch: 20, Batch: 17, Train Loss: 0.4479, Train Acc: 0.8355
# Epoch: 20, Batch: 18, Train Loss: 0.4483, Train Acc: 0.8342
# Epoch: 20, Batch: 19, Train Loss: 0.4447, Train Acc: 0.8347
# Epoch: 20, Batch: 20, Train Loss: 0.4441, Train Acc: 0.8375
# Epoch: 20, Batch: 21, Train Loss: 0.4376, Train Acc: 0.8400
# Epoch: 20, Batch: 22, Train Loss: 0.4371, Train Acc: 0.8406
# Epoch: 20, Batch: 23, Train Loss: 0.4336, Train Acc: 0.8427
# Epoch: 20, Batch: 24, Train Loss: 0.4388, Train Acc: 0.8411
# Epoch: 20, Batch: 25, Train Loss: 0.4427, Train Acc: 0.8397
# Epoch: 20, Batch: 26, Train Loss: 0.4441, Train Acc: 0.8380
# Epoch: 20, Batch: 27, Train Loss: 0.4469, Train Acc: 0.8371
# Epoch: 20, Batch: 28, Train Loss: 0.4452, Train Acc: 0.8382
# Epoch: 20, Batch: 29, Train Loss: 0.4439, Train Acc: 0.8386
# Epoch: 20, Batch: 30, Train Loss: 0.4410, Train Acc: 0.8401
# Epoch: 20, Batch: 31, Train Loss: 0.4368, Train Acc: 0.8407
# Epoch: 20, Batch: 32, Train Loss: 0.4350, Train Acc: 0.8420
# Epoch: 20, Batch: 33, Train Loss: 0.4318, Train Acc: 0.8435
# Epoch: 20, Batch: 34, Train Loss: 0.4306, Train Acc: 0.8440
# Epoch: 20, Batch: 35, Train Loss: 0.4279, Train Acc: 0.8446
# Epoch: 20, Batch: 36, Train Loss: 0.4281, Train Acc: 0.8440
# Epoch: 20, Batch: 37, Train Loss: 0.4246, Train Acc: 0.8448
# Epoch: 20, Batch: 38, Train Loss: 0.4296, Train Acc: 0.8452
# Epoch: 20, Batch: 39, Train Loss: 0.4301, Train Acc: 0.8450
# Epoch: 20, Batch: 40, Train Loss: 0.4301, Train Acc: 0.8451
# Epoch: 20, Batch: 41, Train Loss: 0.4277, Train Acc: 0.8460
# Epoch: 20, Batch: 42, Train Loss: 0.4264, Train Acc: 0.8465
# Epoch: 20, Batch: 43, Train Loss: 0.4267, Train Acc: 0.8465
# Epoch: 20, Batch: 44, Train Loss: 0.4253, Train Acc: 0.8469
# Epoch: 20, Batch: 45, Train Loss: 0.4270, Train Acc: 0.8460
# Epoch: 20, Batch: 46, Train Loss: 0.4267, Train Acc: 0.8458
# Epoch: 20, Batch: 47, Train Loss: 0.4269, Train Acc: 0.8462
# Epoch: 20, Batch: 48, Train Loss: 0.4289, Train Acc: 0.8465
# Epoch: 20, Batch: 49, Train Loss: 0.4276, Train Acc: 0.8466
# Epoch: 20, Batch: 50, Train Loss: 0.4273, Train Acc: 0.8466
# Epoch: 20, Batch: 51, Train Loss: 0.4265, Train Acc: 0.8467
# Epoch: 20, Batch: 52, Train Loss: 0.4253, Train Acc: 0.8471
# Epoch: 20, Batch: 53, Train Loss: 0.4260, Train Acc: 0.8463
# Epoch: 20, Batch: 54, Train Loss: 0.4252, Train Acc: 0.8468
# Epoch: 20, Batch: 55, Train Loss: 0.4236, Train Acc: 0.8469
# Epoch: 20, Batch: 56, Train Loss: 0.4229, Train Acc: 0.8467
# Epoch: 20, Batch: 57, Train Loss: 0.4221, Train Acc: 0.8470
# Epoch: 20, Batch: 58, Train Loss: 0.4227, Train Acc: 0.8470
# Epoch: 20, Batch: 59, Train Loss: 0.4213, Train Acc: 0.8472
# Epoch: 20, Batch: 60, Train Loss: 0.4196, Train Acc: 0.8477
# Epoch: 20, Batch: 61, Train Loss: 0.4184, Train Acc: 0.8485
# Epoch: 20, Batch: 62, Train Loss: 0.4186, Train Acc: 0.8480
# Epoch: 20, Batch: 63, Train Loss: 0.4184, Train Acc: 0.8477
# Epoch: 20, Batch: 64, Train Loss: 0.4175, Train Acc: 0.8477
# Epoch: 20, Batch: 65, Train Loss: 0.4155, Train Acc: 0.8478
# Epoch: 20, Batch: 66, Train Loss: 0.4138, Train Acc: 0.8486
# Epoch: 20, Batch: 67, Train Loss: 0.4122, Train Acc: 0.8495
# Epoch: 20, Batch: 68, Train Loss: 0.4109, Train Acc: 0.8502
# Epoch: 20, Batch: 69, Train Loss: 0.4099, Train Acc: 0.8504
# Epoch: 20, Batch: 70, Train Loss: 0.4110, Train Acc: 0.8500
# Epoch: 20, Batch: 71, Train Loss: 0.4130, Train Acc: 0.8495
# Epoch: 20, Batch: 72, Train Loss: 0.4108, Train Acc: 0.8502
# Epoch: 20, Batch: 73, Train Loss: 0.4092, Train Acc: 0.8505
# Epoch: 20, Batch: 74, Train Loss: 0.4074, Train Acc: 0.8516
# Epoch: 20, Batch: 75, Train Loss: 0.4071, Train Acc: 0.8520
# Epoch: 20, Batch: 76, Train Loss: 0.4059, Train Acc: 0.8521
# Epoch: 20, Batch: 77, Train Loss: 0.4062, Train Acc: 0.8519
# Epoch: 20, Batch: 78, Train Loss: 0.4056, Train Acc: 0.8520
# Epoch: 20, Batch: 79, Train Loss: 0.4054, Train Acc: 0.8521
# train loss 0.405, train acc 0.852, test acc 0.870

# %% [markdown]
# # CIFAR-10

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter

class Bottleneck(nn.Module):
    def __init__(self, in_channels, channels, stride=1, use_1x1conv=False):
        super(Bottleneck,self).__init__()
        self.conv1 = nn.Conv2d(in_channels, channels, kernel_size=1, stride=1, bias=False)
        self.bn1 = nn.BatchNorm2d(channels)
        self.conv2 = nn.Conv2d(channels, channels, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(channels)
        self.conv3 = nn.Conv2d(channels, channels*4, kernel_size=1, stride=1, bias=False)
        self.bn3 = nn.BatchNorm2d(channels*4)

        if use_1x1conv:
            self.conv4 = nn.Conv2d(
                in_channels, channels*4, kernel_size=1, stride=stride
            )
        else:
            self.conv4 = None

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))

        if  self.conv4 == None:
            identity = x
        else:
            identity = self.conv4(x)

        out += identity
        return F.relu(out)

def bottleneck_block(in_channels, channels, num_bottlenecks, stride=1):
    blk = []
    for i in range(num_bottlenecks):
        if i == 0:
            blk.append(Bottleneck(in_channels, channels, stride=stride, use_1x1conv=True))
        else:
            blk.append(Bottleneck(channels*4, channels))
    return blk


    b1 = nn.Sequential(nn.Conv2d(1, 64, kernel_size=7, stride=2, padding=3),
                       nn.BatchNorm2d(64), nn.ReLU(),
                       nn.MaxPool2d(kernel_size=3, stride=2, padding=1))

    b2 = nn.Sequential(*bottleneck_block(64, 64, layers[0], stride=1))
    b3 = nn.Sequential(*bottleneck_block(64*4, 128, layers[1], stride=2))
    b4 = nn.Sequential(*bottleneck_block(128*4, 256, layers[2], stride=2))
    b5 = nn.Sequential(*bottleneck_block(256*4, 512, layers[3], stride=2))

    resnet = nn.Sequential(
        b1, b2, b3, b4, b5,
        nn.AdaptiveAvgPool2d((1,1)),
        nn.Flatten(),
        nn.Linear(512*4, num_classes)
    )
    return resnet

def resnet50():
    return ResNet(Bottleneck, [3, 4, 6, 3])

def resnet101():
    return ResNet(Bottleneck, [3, 4, 23, 3])



def train_loss(net, train_iter, test_iter, epochs, loss, device, lr):
    net.to(device)
    writer = SummaryWriter()  # 创建 TensorBoard writer

    def init_weights(m):
        if type(m) == nn.Linear or type(m) == nn.Conv2d:
            # nn.init.xavier_uniform(m.weight)
            nn.init.kaiming_normal_(m.weight)
    net.apply(init_weights)
            
    trainer = torch.optim.Adam(net.parameters(), lr=lr)
    for epoch in range(epochs):
        # 训练损失之和，训练准确率之和，样本数
        metric = d2l.Accumulator(3)
        net.train()
        timer, num_batches = d2l.Timer(), len(train_iter)
        for i, (X, y) in enumerate(train_iter):
            trainer.zero_grad()
            X, y = X.to(device), y.to(device)
            y_hat = net(X)
            l = loss(y_hat, y)
            l.backward()
            trainer.step()
            with torch.no_grad():
                metric.add(l * X.shape[0], d2l.accuracy(y_hat, y), X.shape[0])

            train_loss = metric[0] / metric[2]
            train_acc = metric[1] / metric[2]

            # 将训练损失和准确率写入 TensorBoard
            writer.add_scalar('Train/Loss', train_loss, epoch * num_batches + i)
            writer.add_scalar('Train/Accuracy', train_acc, epoch * num_batches + i)

            # 打印训练过程
            print(f'Epoch: {epoch+1}, Batch: {i+1}, Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}')

        test_acc = d2l.evaluate_accuracy_gpu(net, test_iter)
        writer.add_scalar('Test/Accuracy', test_acc, epoch)  # 将测试准确率写入 TensorBoard

        test_acc = d2l.evaluate_accuracy_gpu(net, test_iter)
        writer.add_scalar('Test/Accuracy', test_acc, epoch)  # 将测试准确率写入 TensorBoard

    print(f'train loss {train_loss:.3f}, train acc {train_acc:.3f}, test acc {test_acc:.3f}')
    torch.save(net.state_dict(), f".\\model\\ResNet-50_Dict_FashionMNIST-10_Epoch{epochs}_Accuracy{test_acc*100:.2f}%.pth")
    torch.save(net, f".\\model\\ResNet-50_FashionMNIST-10_Epoch{epochs}_Accuracy{test_acc*100:.2f}%.pth")
    writer.close()  # 关闭 TensorBoard writer
    
    
# 加载MNIST
trans24 = transforms.Compose(
    [transforms.ToTensor()])#28*28



train_dataset = datasets.MNIST(
    root=r'./', train=True, transform=trans24, download=True)
test_dataset = datasets.MNIST(
    root=r'./', train=False, transform=trans24, download=True)

# 配置数据加载器
batch_size = 128
train_loader64 = DataLoader(dataset=train_dataset,
                          batch_size=batch_size, shuffle=True)
test_loader64 = DataLoader(dataset=test_dataset,
                         batch_size=batch_size, shuffle=True)
def resnet50():
    return ResNet(Bottleneck, [3, 4, 6, 3])

def resnet110():
    return ResNet(Bottleneck, [18, 18, 18, 18])
# 开始训练
#epochs,lr = 20, 0.001
epochs, lr = 20, 0.001
device = torch.device("cuda:0")
loss = nn.CrossEntropyLoss()
resnet50 = resnet50()
train_loss(resnet50, test_loader64, test_loader64, epochs, loss, device, lr)
# tensorboard 运行
# (mytorch) PS F:\DeepLearn\resnet\runs> tensorboard --logdir=Apr10_17-45-21_NikeLee
# 其中 'Apr10_17-45-21_NikeLee'是文件夹名称
# Out:
# Epoch: 1, Batch: 1, Train Loss: 6.4479, Train Acc: 0.1094
# Epoch: 1, Batch: 2, Train Loss: 9.8244, Train Acc: 0.1992
# Epoch: 1, Batch: 3, Train Loss: 11.8972, Train Acc: 0.2292
# Epoch: 1, Batch: 4, Train Loss: 12.8932, Train Acc: 0.2402
# Epoch: 1, Batch: 5, Train Loss: 12.2660, Train Acc: 0.2516
# Epoch: 1, Batch: 6, Train Loss: 10.9620, Train Acc: 0.2943
# Epoch: 1, Batch: 7, Train Loss: 9.6736, Train Acc: 0.3393
# Epoch: 1, Batch: 8, Train Loss: 8.7180, Train Acc: 0.3779
# Epoch: 1, Batch: 9, Train Loss: 7.9866, Train Acc: 0.4071
# Epoch: 1, Batch: 10, Train Loss: 7.3705, Train Acc: 0.4359
# Epoch: 1, Batch: 11, Train Loss: 6.8977, Train Acc: 0.4581
# Epoch: 1, Batch: 12, Train Loss: 6.4702, Train Acc: 0.4779
# Epoch: 1, Batch: 13, Train Loss: 6.1345, Train Acc: 0.4928
# Epoch: 1, Batch: 14, Train Loss: 5.7658, Train Acc: 0.5162
# Epoch: 1, Batch: 15, Train Loss: 5.4420, Train Acc: 0.5333
# Epoch: 1, Batch: 16, Train Loss: 5.1831, Train Acc: 0.5479
# Epoch: 1, Batch: 17, Train Loss: 4.9849, Train Acc: 0.5579
# Epoch: 1, Batch: 18, Train Loss: 4.7689, Train Acc: 0.5707
# Epoch: 1, Batch: 19, Train Loss: 4.5626, Train Acc: 0.5835
# Epoch: 1, Batch: 20, Train Loss: 4.3828, Train Acc: 0.5934
# Epoch: 1, Batch: 21, Train Loss: 4.2236, Train Acc: 0.6031
# Epoch: 1, Batch: 22, Train Loss: 4.0730, Train Acc: 0.6126
# Epoch: 1, Batch: 23, Train Loss: 3.9264, Train Acc: 0.6233
# Epoch: 1, Batch: 24, Train Loss: 3.8011, Train Acc: 0.6302
# Epoch: 1, Batch: 25, Train Loss: 3.6671, Train Acc: 0.6406
# Epoch: 1, Batch: 26, Train Loss: 3.5453, Train Acc: 0.6490
# Epoch: 1, Batch: 27, Train Loss: 3.4469, Train Acc: 0.6560
# Epoch: 1, Batch: 28, Train Loss: 3.3467, Train Acc: 0.6632
# Epoch: 1, Batch: 29, Train Loss: 3.2410, Train Acc: 0.6708
# Epoch: 1, Batch: 30, Train Loss: 3.1573, Train Acc: 0.6766
# Epoch: 1, Batch: 31, Train Loss: 3.0712, Train Acc: 0.6827
# Epoch: 1, Batch: 32, Train Loss: 2.9857, Train Acc: 0.6897
# Epoch: 1, Batch: 33, Train Loss: 2.9131, Train Acc: 0.6948
# Epoch: 1, Batch: 34, Train Loss: 2.8379, Train Acc: 0.7020
# Epoch: 1, Batch: 35, Train Loss: 2.7675, Train Acc: 0.7080
# Epoch: 1, Batch: 36, Train Loss: 2.6993, Train Acc: 0.7142
# Epoch: 1, Batch: 37, Train Loss: 2.6383, Train Acc: 0.7185
# Epoch: 1, Batch: 38, Train Loss: 2.5856, Train Acc: 0.7227
# Epoch: 1, Batch: 39, Train Loss: 2.5485, Train Acc: 0.7254
# Epoch: 1, Batch: 40, Train Loss: 2.4916, Train Acc: 0.7309
# Epoch: 1, Batch: 41, Train Loss: 2.4422, Train Acc: 0.7336
# Epoch: 1, Batch: 42, Train Loss: 2.3976, Train Acc: 0.7370
# Epoch: 1, Batch: 43, Train Loss: 2.3511, Train Acc: 0.7411
# Epoch: 1, Batch: 44, Train Loss: 2.3146, Train Acc: 0.7429
# Epoch: 1, Batch: 45, Train Loss: 2.2782, Train Acc: 0.7455
# Epoch: 1, Batch: 46, Train Loss: 2.2333, Train Acc: 0.7498
# Epoch: 1, Batch: 47, Train Loss: 2.1929, Train Acc: 0.7528
# Epoch: 1, Batch: 48, Train Loss: 2.1537, Train Acc: 0.7560
# Epoch: 1, Batch: 49, Train Loss: 2.1170, Train Acc: 0.7594
# Epoch: 1, Batch: 50, Train Loss: 2.0831, Train Acc: 0.7619
# Epoch: 1, Batch: 51, Train Loss: 2.0499, Train Acc: 0.7647
# Epoch: 1, Batch: 52, Train Loss: 2.0148, Train Acc: 0.7683
# Epoch: 1, Batch: 53, Train Loss: 1.9876, Train Acc: 0.7699
# Epoch: 1, Batch: 54, Train Loss: 1.9595, Train Acc: 0.7723
# Epoch: 1, Batch: 55, Train Loss: 1.9312, Train Acc: 0.7750
# Epoch: 1, Batch: 56, Train Loss: 1.9009, Train Acc: 0.7773
# Epoch: 1, Batch: 57, Train Loss: 1.8801, Train Acc: 0.7793
# Epoch: 1, Batch: 58, Train Loss: 1.8528, Train Acc: 0.7815
# Epoch: 1, Batch: 59, Train Loss: 1.8271, Train Acc: 0.7840
# Epoch: 1, Batch: 60, Train Loss: 1.8044, Train Acc: 0.7861
# Epoch: 1, Batch: 61, Train Loss: 1.7804, Train Acc: 0.7883
# Epoch: 1, Batch: 62, Train Loss: 1.7560, Train Acc: 0.7906
# Epoch: 1, Batch: 63, Train Loss: 1.7368, Train Acc: 0.7923
# Epoch: 1, Batch: 64, Train Loss: 1.7123, Train Acc: 0.7948
# Epoch: 1, Batch: 65, Train Loss: 1.6907, Train Acc: 0.7971
# Epoch: 1, Batch: 66, Train Loss: 1.6699, Train Acc: 0.7989
# Epoch: 1, Batch: 67, Train Loss: 1.6471, Train Acc: 0.8012
# Epoch: 1, Batch: 68, Train Loss: 1.6274, Train Acc: 0.8031
# Epoch: 1, Batch: 69, Train Loss: 1.6052, Train Acc: 0.8053
# Epoch: 1, Batch: 70, Train Loss: 1.5882, Train Acc: 0.8065
# Epoch: 1, Batch: 71, Train Loss: 1.5701, Train Acc: 0.8080
# Epoch: 1, Batch: 72, Train Loss: 1.5529, Train Acc: 0.8097
# Epoch: 1, Batch: 73, Train Loss: 1.5383, Train Acc: 0.8105
# Epoch: 1, Batch: 74, Train Loss: 1.5225, Train Acc: 0.8120
# Epoch: 1, Batch: 75, Train Loss: 1.5078, Train Acc: 0.8134
# Epoch: 1, Batch: 76, Train Loss: 1.4944, Train Acc: 0.8146
# Epoch: 1, Batch: 77, Train Loss: 1.4792, Train Acc: 0.8156
# Epoch: 1, Batch: 78, Train Loss: 1.4658, Train Acc: 0.8164
# Epoch: 1, Batch: 79, Train Loss: 1.4634, Train Acc: 0.8167
# Epoch: 2, Batch: 1, Train Loss: 0.1078, Train Acc: 0.9531
# Epoch: 2, Batch: 2, Train Loss: 0.1845, Train Acc: 0.9375
# Epoch: 2, Batch: 3, Train Loss: 0.2559, Train Acc: 0.9219
# Epoch: 2, Batch: 4, Train Loss: 0.2341, Train Acc: 0.9297
# Epoch: 2, Batch: 5, Train Loss: 0.2117, Train Acc: 0.9375
# Epoch: 2, Batch: 6, Train Loss: 0.2115, Train Acc: 0.9375
# Epoch: 2, Batch: 7, Train Loss: 0.2224, Train Acc: 0.9342
# Epoch: 2, Batch: 8, Train Loss: 0.2121, Train Acc: 0.9375
# Epoch: 2, Batch: 9, Train Loss: 0.2039, Train Acc: 0.9375
# Epoch: 2, Batch: 10, Train Loss: 0.2094, Train Acc: 0.9398
# Epoch: 2, Batch: 11, Train Loss: 0.2113, Train Acc: 0.9403
# Epoch: 2, Batch: 12, Train Loss: 0.2227, Train Acc: 0.9368
# Epoch: 2, Batch: 13, Train Loss: 0.2306, Train Acc: 0.9351
# Epoch: 2, Batch: 14, Train Loss: 0.2183, Train Acc: 0.9381
# Epoch: 2, Batch: 15, Train Loss: 0.2114, Train Acc: 0.9391
# Epoch: 2, Batch: 16, Train Loss: 0.2042, Train Acc: 0.9414
# Epoch: 2, Batch: 17, Train Loss: 0.2020, Train Acc: 0.9435
# Epoch: 2, Batch: 18, Train Loss: 0.2062, Train Acc: 0.9418
# Epoch: 2, Batch: 19, Train Loss: 0.2063, Train Acc: 0.9424
# Epoch: 2, Batch: 20, Train Loss: 0.2015, Train Acc: 0.9441
# Epoch: 2, Batch: 21, Train Loss: 0.1976, Train Acc: 0.9449
# Epoch: 2, Batch: 22, Train Loss: 0.1924, Train Acc: 0.9464
# Epoch: 2, Batch: 23, Train Loss: 0.1887, Train Acc: 0.9474
# Epoch: 2, Batch: 24, Train Loss: 0.1846, Train Acc: 0.9486
# Epoch: 2, Batch: 25, Train Loss: 0.1928, Train Acc: 0.9469
# Epoch: 2, Batch: 26, Train Loss: 0.1894, Train Acc: 0.9480
# Epoch: 2, Batch: 27, Train Loss: 0.1849, Train Acc: 0.9494
# Epoch: 2, Batch: 28, Train Loss: 0.1791, Train Acc: 0.9512
# Epoch: 2, Batch: 29, Train Loss: 0.1754, Train Acc: 0.9526
# Epoch: 2, Batch: 30, Train Loss: 0.1738, Train Acc: 0.9526
# Epoch: 2, Batch: 31, Train Loss: 0.1757, Train Acc: 0.9524
# Epoch: 2, Batch: 32, Train Loss: 0.1822, Train Acc: 0.9512
# Epoch: 2, Batch: 33, Train Loss: 0.1828, Train Acc: 0.9510
# Epoch: 2, Batch: 34, Train Loss: 0.1806, Train Acc: 0.9515
# Epoch: 2, Batch: 35, Train Loss: 0.1822, Train Acc: 0.9509
# Epoch: 2, Batch: 36, Train Loss: 0.1811, Train Acc: 0.9514
# Epoch: 2, Batch: 37, Train Loss: 0.1796, Train Acc: 0.9514
# Epoch: 2, Batch: 38, Train Loss: 0.1782, Train Acc: 0.9517
# Epoch: 2, Batch: 39, Train Loss: 0.1811, Train Acc: 0.9515
# Epoch: 2, Batch: 40, Train Loss: 0.1835, Train Acc: 0.9514
# Epoch: 2, Batch: 41, Train Loss: 0.1811, Train Acc: 0.9518
# Epoch: 2, Batch: 42, Train Loss: 0.1804, Train Acc: 0.9520
# Epoch: 2, Batch: 43, Train Loss: 0.1832, Train Acc: 0.9513
# Epoch: 2, Batch: 44, Train Loss: 0.1817, Train Acc: 0.9517
# Epoch: 2, Batch: 45, Train Loss: 0.1822, Train Acc: 0.9517
# Epoch: 2, Batch: 46, Train Loss: 0.1801, Train Acc: 0.9523
# Epoch: 2, Batch: 47, Train Loss: 0.1842, Train Acc: 0.9518
# Epoch: 2, Batch: 48, Train Loss: 0.1842, Train Acc: 0.9518
# Epoch: 2, Batch: 49, Train Loss: 0.1845, Train Acc: 0.9514
# Epoch: 2, Batch: 50, Train Loss: 0.1823, Train Acc: 0.9519
# Epoch: 2, Batch: 51, Train Loss: 0.1806, Train Acc: 0.9522
# Epoch: 2, Batch: 52, Train Loss: 0.1787, Train Acc: 0.9524
# Epoch: 2, Batch: 53, Train Loss: 0.1794, Train Acc: 0.9522
# Epoch: 2, Batch: 54, Train Loss: 0.1791, Train Acc: 0.9521
# Epoch: 2, Batch: 55, Train Loss: 0.1772, Train Acc: 0.9524
# Epoch: 2, Batch: 56, Train Loss: 0.1758, Train Acc: 0.9528
# Epoch: 2, Batch: 57, Train Loss: 0.1732, Train Acc: 0.9534
# Epoch: 2, Batch: 58, Train Loss: 0.1735, Train Acc: 0.9534
# Epoch: 2, Batch: 59, Train Loss: 0.1731, Train Acc: 0.9531
# Epoch: 2, Batch: 60, Train Loss: 0.1737, Train Acc: 0.9527
# Epoch: 2, Batch: 61, Train Loss: 0.1737, Train Acc: 0.9525
# Epoch: 2, Batch: 62, Train Loss: 0.1726, Train Acc: 0.9529
# Epoch: 2, Batch: 63, Train Loss: 0.1715, Train Acc: 0.9532
# Epoch: 2, Batch: 64, Train Loss: 0.1713, Train Acc: 0.9531
# Epoch: 2, Batch: 65, Train Loss: 0.1714, Train Acc: 0.9534
# Epoch: 2, Batch: 66, Train Loss: 0.1730, Train Acc: 0.9534
# Epoch: 2, Batch: 67, Train Loss: 0.1730, Train Acc: 0.9534
# Epoch: 2, Batch: 68, Train Loss: 0.1727, Train Acc: 0.9532
# Epoch: 2, Batch: 69, Train Loss: 0.1718, Train Acc: 0.9534
# Epoch: 2, Batch: 70, Train Loss: 0.1712, Train Acc: 0.9536
# Epoch: 2, Batch: 71, Train Loss: 0.1712, Train Acc: 0.9536
# Epoch: 2, Batch: 72, Train Loss: 0.1695, Train Acc: 0.9540
# Epoch: 2, Batch: 73, Train Loss: 0.1686, Train Acc: 0.9541
# Epoch: 2, Batch: 74, Train Loss: 0.1674, Train Acc: 0.9542
# Epoch: 2, Batch: 75, Train Loss: 0.1658, Train Acc: 0.9546
# Epoch: 2, Batch: 76, Train Loss: 0.1649, Train Acc: 0.9548
# Epoch: 2, Batch: 77, Train Loss: 0.1641, Train Acc: 0.9551
# Epoch: 2, Batch: 78, Train Loss: 0.1646, Train Acc: 0.9549
# Epoch: 2, Batch: 79, Train Loss: 0.1659, Train Acc: 0.9548
# Epoch: 3, Batch: 1, Train Loss: 0.1372, Train Acc: 0.9688
# Epoch: 3, Batch: 2, Train Loss: 0.1499, Train Acc: 0.9531
# Epoch: 3, Batch: 3, Train Loss: 0.1539, Train Acc: 0.9531
# Epoch: 3, Batch: 4, Train Loss: 0.2529, Train Acc: 0.9355
# Epoch: 3, Batch: 5, Train Loss: 0.3095, Train Acc: 0.9250
# Epoch: 3, Batch: 6, Train Loss: 0.2619, Train Acc: 0.9375
# Epoch: 3, Batch: 7, Train Loss: 0.2430, Train Acc: 0.9375
# Epoch: 3, Batch: 8, Train Loss: 0.2294, Train Acc: 0.9424
# Epoch: 3, Batch: 9, Train Loss: 0.2195, Train Acc: 0.9418
# Epoch: 3, Batch: 10, Train Loss: 0.2154, Train Acc: 0.9414
# Epoch: 3, Batch: 11, Train Loss: 0.2060, Train Acc: 0.9439
# Epoch: 3, Batch: 12, Train Loss: 0.1963, Train Acc: 0.9453
# Epoch: 3, Batch: 13, Train Loss: 0.1948, Train Acc: 0.9477
# Epoch: 3, Batch: 14, Train Loss: 0.1903, Train Acc: 0.9481
# Epoch: 3, Batch: 15, Train Loss: 0.1904, Train Acc: 0.9484
# Epoch: 3, Batch: 16, Train Loss: 0.1840, Train Acc: 0.9502
# Epoch: 3, Batch: 17, Train Loss: 0.1786, Train Acc: 0.9508
# Epoch: 3, Batch: 18, Train Loss: 0.1751, Train Acc: 0.9518
# Epoch: 3, Batch: 19, Train Loss: 0.1705, Train Acc: 0.9523
# Epoch: 3, Batch: 20, Train Loss: 0.1666, Train Acc: 0.9531
# Epoch: 3, Batch: 21, Train Loss: 0.1631, Train Acc: 0.9539
# Epoch: 3, Batch: 22, Train Loss: 0.1647, Train Acc: 0.9535
# Epoch: 3, Batch: 23, Train Loss: 0.1602, Train Acc: 0.9548
# Epoch: 3, Batch: 24, Train Loss: 0.1545, Train Acc: 0.9567
# Epoch: 3, Batch: 25, Train Loss: 0.1548, Train Acc: 0.9566
# Epoch: 3, Batch: 26, Train Loss: 0.1525, Train Acc: 0.9570
# Epoch: 3, Batch: 27, Train Loss: 0.1558, Train Acc: 0.9572
# Epoch: 3, Batch: 28, Train Loss: 0.1519, Train Acc: 0.9579
# Epoch: 3, Batch: 29, Train Loss: 0.1499, Train Acc: 0.9588
# Epoch: 3, Batch: 30, Train Loss: 0.1493, Train Acc: 0.9589
# Epoch: 3, Batch: 31, Train Loss: 0.1494, Train Acc: 0.9592
# Epoch: 3, Batch: 32, Train Loss: 0.1501, Train Acc: 0.9585
# Epoch: 3, Batch: 33, Train Loss: 0.1520, Train Acc: 0.9583
# Epoch: 3, Batch: 34, Train Loss: 0.1521, Train Acc: 0.9586
# Epoch: 3, Batch: 35, Train Loss: 0.1503, Train Acc: 0.9589
# Epoch: 3, Batch: 36, Train Loss: 0.1470, Train Acc: 0.9596
# Epoch: 3, Batch: 37, Train Loss: 0.1444, Train Acc: 0.9601
# Epoch: 3, Batch: 38, Train Loss: 0.1442, Train Acc: 0.9599
# Epoch: 3, Batch: 39, Train Loss: 0.1435, Train Acc: 0.9599
# Epoch: 3, Batch: 40, Train Loss: 0.1438, Train Acc: 0.9600
# Epoch: 3, Batch: 41, Train Loss: 0.1435, Train Acc: 0.9598
# Epoch: 3, Batch: 42, Train Loss: 0.1471, Train Acc: 0.9596
# Epoch: 3, Batch: 43, Train Loss: 0.1466, Train Acc: 0.9598
# Epoch: 3, Batch: 44, Train Loss: 0.1456, Train Acc: 0.9599
# Epoch: 3, Batch: 45, Train Loss: 0.1440, Train Acc: 0.9602
# Epoch: 3, Batch: 46, Train Loss: 0.1445, Train Acc: 0.9599
# Epoch: 3, Batch: 47, Train Loss: 0.1416, Train Acc: 0.9608
# Epoch: 3, Batch: 48, Train Loss: 0.1412, Train Acc: 0.9604
# Epoch: 3, Batch: 49, Train Loss: 0.1388, Train Acc: 0.9613
# Epoch: 3, Batch: 50, Train Loss: 0.1378, Train Acc: 0.9616
# Epoch: 3, Batch: 51, Train Loss: 0.1367, Train Acc: 0.9619
# Epoch: 3, Batch: 52, Train Loss: 0.1377, Train Acc: 0.9615
# Epoch: 3, Batch: 53, Train Loss: 0.1358, Train Acc: 0.9621
# Epoch: 3, Batch: 54, Train Loss: 0.1349, Train Acc: 0.9621
# Epoch: 3, Batch: 55, Train Loss: 0.1349, Train Acc: 0.9622
# Epoch: 3, Batch: 56, Train Loss: 0.1368, Train Acc: 0.9621
# Epoch: 3, Batch: 57, Train Loss: 0.1367, Train Acc: 0.9618
# Epoch: 3, Batch: 58, Train Loss: 0.1351, Train Acc: 0.9623
# Epoch: 3, Batch: 59, Train Loss: 0.1344, Train Acc: 0.9625
# Epoch: 3, Batch: 60, Train Loss: 0.1349, Train Acc: 0.9625
# Epoch: 3, Batch: 61, Train Loss: 0.1355, Train Acc: 0.9622
# Epoch: 3, Batch: 62, Train Loss: 0.1353, Train Acc: 0.9626
# Epoch: 3, Batch: 63, Train Loss: 0.1347, Train Acc: 0.9628
# Epoch: 3, Batch: 64, Train Loss: 0.1337, Train Acc: 0.9630
# Epoch: 3, Batch: 65, Train Loss: 0.1353, Train Acc: 0.9627
# Epoch: 3, Batch: 66, Train Loss: 0.1339, Train Acc: 0.9629
# Epoch: 3, Batch: 67, Train Loss: 0.1331, Train Acc: 0.9633
# Epoch: 3, Batch: 68, Train Loss: 0.1329, Train Acc: 0.9634
# Epoch: 3, Batch: 69, Train Loss: 0.1318, Train Acc: 0.9637
# Epoch: 3, Batch: 70, Train Loss: 0.1328, Train Acc: 0.9635
# Epoch: 3, Batch: 71, Train Loss: 0.1313, Train Acc: 0.9638
# Epoch: 3, Batch: 72, Train Loss: 0.1312, Train Acc: 0.9640
# Epoch: 3, Batch: 73, Train Loss: 0.1299, Train Acc: 0.9643
# Epoch: 3, Batch: 74, Train Loss: 0.1314, Train Acc: 0.9637
# Epoch: 3, Batch: 75, Train Loss: 0.1310, Train Acc: 0.9637
# Epoch: 3, Batch: 76, Train Loss: 0.1301, Train Acc: 0.9638
# Epoch: 3, Batch: 77, Train Loss: 0.1292, Train Acc: 0.9642
# Epoch: 3, Batch: 78, Train Loss: 0.1285, Train Acc: 0.9643
# Epoch: 3, Batch: 79, Train Loss: 0.1285, Train Acc: 0.9643
# Epoch: 4, Batch: 1, Train Loss: 0.0611, Train Acc: 0.9766
# Epoch: 4, Batch: 2, Train Loss: 0.0495, Train Acc: 0.9805
# Epoch: 4, Batch: 3, Train Loss: 0.0578, Train Acc: 0.9792
# Epoch: 4, Batch: 4, Train Loss: 0.0636, Train Acc: 0.9766
# Epoch: 4, Batch: 5, Train Loss: 0.0640, Train Acc: 0.9766
# Epoch: 4, Batch: 6, Train Loss: 0.0640, Train Acc: 0.9740
# Epoch: 4, Batch: 7, Train Loss: 0.0858, Train Acc: 0.9688
# Epoch: 4, Batch: 8, Train Loss: 0.0786, Train Acc: 0.9717
# Epoch: 4, Batch: 9, Train Loss: 0.0780, Train Acc: 0.9731
# Epoch: 4, Batch: 10, Train Loss: 0.0892, Train Acc: 0.9711
# Epoch: 4, Batch: 11, Train Loss: 0.0866, Train Acc: 0.9709
# Epoch: 4, Batch: 12, Train Loss: 0.0921, Train Acc: 0.9707
# Epoch: 4, Batch: 13, Train Loss: 0.0870, Train Acc: 0.9724
# Epoch: 4, Batch: 14, Train Loss: 0.0816, Train Acc: 0.9743
# Epoch: 4, Batch: 15, Train Loss: 0.0786, Train Acc: 0.9750
# Epoch: 4, Batch: 16, Train Loss: 0.0743, Train Acc: 0.9766
# Epoch: 4, Batch: 17, Train Loss: 0.0704, Train Acc: 0.9779
# Epoch: 4, Batch: 18, Train Loss: 0.0707, Train Acc: 0.9774
# Epoch: 4, Batch: 19, Train Loss: 0.0697, Train Acc: 0.9778
# Epoch: 4, Batch: 20, Train Loss: 0.0685, Train Acc: 0.9785
# Epoch: 4, Batch: 21, Train Loss: 0.0677, Train Acc: 0.9788
# Epoch: 4, Batch: 22, Train Loss: 0.0666, Train Acc: 0.9787
# Epoch: 4, Batch: 23, Train Loss: 0.0649, Train Acc: 0.9793
# Epoch: 4, Batch: 24, Train Loss: 0.0654, Train Acc: 0.9795
# Epoch: 4, Batch: 25, Train Loss: 0.0651, Train Acc: 0.9797
# Epoch: 4, Batch: 26, Train Loss: 0.0683, Train Acc: 0.9787
# Epoch: 4, Batch: 27, Train Loss: 0.0673, Train Acc: 0.9789
# Epoch: 4, Batch: 28, Train Loss: 0.0699, Train Acc: 0.9782
# Epoch: 4, Batch: 29, Train Loss: 0.0677, Train Acc: 0.9790
# Epoch: 4, Batch: 30, Train Loss: 0.0668, Train Acc: 0.9794
# Epoch: 4, Batch: 31, Train Loss: 0.0650, Train Acc: 0.9798
# Epoch: 4, Batch: 32, Train Loss: 0.0641, Train Acc: 0.9797
# Epoch: 4, Batch: 33, Train Loss: 0.0653, Train Acc: 0.9796
# Epoch: 4, Batch: 34, Train Loss: 0.0671, Train Acc: 0.9791
# Epoch: 4, Batch: 35, Train Loss: 0.0684, Train Acc: 0.9792
# Epoch: 4, Batch: 36, Train Loss: 0.0681, Train Acc: 0.9792
# Epoch: 4, Batch: 37, Train Loss: 0.0687, Train Acc: 0.9787
# Epoch: 4, Batch: 38, Train Loss: 0.0673, Train Acc: 0.9792
# Epoch: 4, Batch: 39, Train Loss: 0.0672, Train Acc: 0.9792
# Epoch: 4, Batch: 40, Train Loss: 0.0667, Train Acc: 0.9793
# Epoch: 4, Batch: 41, Train Loss: 0.0655, Train Acc: 0.9798
# Epoch: 4, Batch: 42, Train Loss: 0.0645, Train Acc: 0.9801
# Epoch: 4, Batch: 43, Train Loss: 0.0633, Train Acc: 0.9806
# Epoch: 4, Batch: 44, Train Loss: 0.0635, Train Acc: 0.9808
# Epoch: 4, Batch: 45, Train Loss: 0.0627, Train Acc: 0.9811
# Epoch: 4, Batch: 46, Train Loss: 0.0619, Train Acc: 0.9813
# Epoch: 4, Batch: 47, Train Loss: 0.0612, Train Acc: 0.9814
# Epoch: 4, Batch: 48, Train Loss: 0.0621, Train Acc: 0.9810
# Epoch: 4, Batch: 49, Train Loss: 0.0624, Train Acc: 0.9810
# Epoch: 4, Batch: 50, Train Loss: 0.0613, Train Acc: 0.9814
# Epoch: 4, Batch: 51, Train Loss: 0.0622, Train Acc: 0.9813
# Epoch: 4, Batch: 52, Train Loss: 0.0625, Train Acc: 0.9812
# Epoch: 4, Batch: 53, Train Loss: 0.0614, Train Acc: 0.9816
# Epoch: 4, Batch: 54, Train Loss: 0.0612, Train Acc: 0.9818
# Epoch: 4, Batch: 55, Train Loss: 0.0636, Train Acc: 0.9814
# Epoch: 4, Batch: 56, Train Loss: 0.0639, Train Acc: 0.9814
# Epoch: 4, Batch: 57, Train Loss: 0.0635, Train Acc: 0.9815
# Epoch: 4, Batch: 58, Train Loss: 0.0628, Train Acc: 0.9817
# Epoch: 4, Batch: 59, Train Loss: 0.0624, Train Acc: 0.9815
# Epoch: 4, Batch: 60, Train Loss: 0.0624, Train Acc: 0.9815
# Epoch: 4, Batch: 61, Train Loss: 0.0625, Train Acc: 0.9816
# Epoch: 4, Batch: 62, Train Loss: 0.0626, Train Acc: 0.9815
# Epoch: 4, Batch: 63, Train Loss: 0.0624, Train Acc: 0.9815
# Epoch: 4, Batch: 64, Train Loss: 0.0645, Train Acc: 0.9810
# Epoch: 4, Batch: 65, Train Loss: 0.0648, Train Acc: 0.9810
# Epoch: 4, Batch: 66, Train Loss: 0.0639, Train Acc: 0.9813
# Epoch: 4, Batch: 67, Train Loss: 0.0634, Train Acc: 0.9815
# Epoch: 4, Batch: 68, Train Loss: 0.0628, Train Acc: 0.9816
# Epoch: 4, Batch: 69, Train Loss: 0.0621, Train Acc: 0.9819
# Epoch: 4, Batch: 70, Train Loss: 0.0624, Train Acc: 0.9817
# Epoch: 4, Batch: 71, Train Loss: 0.0619, Train Acc: 0.9818
# Epoch: 4, Batch: 72, Train Loss: 0.0615, Train Acc: 0.9819
# Epoch: 4, Batch: 73, Train Loss: 0.0613, Train Acc: 0.9819
# Epoch: 4, Batch: 74, Train Loss: 0.0606, Train Acc: 0.9822
# Epoch: 4, Batch: 75, Train Loss: 0.0611, Train Acc: 0.9821
# Epoch: 4, Batch: 76, Train Loss: 0.0612, Train Acc: 0.9820
# Epoch: 4, Batch: 77, Train Loss: 0.0608, Train Acc: 0.9821
# Epoch: 4, Batch: 78, Train Loss: 0.0607, Train Acc: 0.9823
# Epoch: 4, Batch: 79, Train Loss: 0.0612, Train Acc: 0.9821
# Epoch: 5, Batch: 1, Train Loss: 0.0697, Train Acc: 0.9766
# Epoch: 5, Batch: 2, Train Loss: 0.0494, Train Acc: 0.9805
# Epoch: 5, Batch: 3, Train Loss: 0.1713, Train Acc: 0.9609
# Epoch: 5, Batch: 4, Train Loss: 0.1583, Train Acc: 0.9629
# Epoch: 5, Batch: 5, Train Loss: 0.1620, Train Acc: 0.9625
# Epoch: 5, Batch: 6, Train Loss: 0.1637, Train Acc: 0.9622
# Epoch: 5, Batch: 7, Train Loss: 0.1490, Train Acc: 0.9643
# Epoch: 5, Batch: 8, Train Loss: 0.1331, Train Acc: 0.9678
# Epoch: 5, Batch: 9, Train Loss: 0.1512, Train Acc: 0.9653
# Epoch: 5, Batch: 10, Train Loss: 0.1420, Train Acc: 0.9664
# Epoch: 5, Batch: 11, Train Loss: 0.1307, Train Acc: 0.9695
# Epoch: 5, Batch: 12, Train Loss: 0.1291, Train Acc: 0.9701
# Epoch: 5, Batch: 13, Train Loss: 0.1642, Train Acc: 0.9633
# Epoch: 5, Batch: 14, Train Loss: 0.1569, Train Acc: 0.9643
# Epoch: 5, Batch: 15, Train Loss: 0.1552, Train Acc: 0.9646
# Epoch: 5, Batch: 16, Train Loss: 0.1650, Train Acc: 0.9629
# Epoch: 5, Batch: 17, Train Loss: 0.1582, Train Acc: 0.9637
# Epoch: 5, Batch: 18, Train Loss: 0.1571, Train Acc: 0.9627
# Epoch: 5, Batch: 19, Train Loss: 0.1533, Train Acc: 0.9626
# Epoch: 5, Batch: 20, Train Loss: 0.1549, Train Acc: 0.9621
# Epoch: 5, Batch: 21, Train Loss: 0.1562, Train Acc: 0.9617
# Epoch: 5, Batch: 22, Train Loss: 0.1564, Train Acc: 0.9624
# Epoch: 5, Batch: 23, Train Loss: 0.1521, Train Acc: 0.9633
# Epoch: 5, Batch: 24, Train Loss: 0.1505, Train Acc: 0.9639
# Epoch: 5, Batch: 25, Train Loss: 0.1536, Train Acc: 0.9637
# Epoch: 5, Batch: 26, Train Loss: 0.1551, Train Acc: 0.9624
# Epoch: 5, Batch: 27, Train Loss: 0.1556, Train Acc: 0.9627
# Epoch: 5, Batch: 28, Train Loss: 0.1546, Train Acc: 0.9629
# Epoch: 5, Batch: 29, Train Loss: 0.1502, Train Acc: 0.9636
# Epoch: 5, Batch: 30, Train Loss: 0.1470, Train Acc: 0.9646
# Epoch: 5, Batch: 31, Train Loss: 0.1463, Train Acc: 0.9642
# Epoch: 5, Batch: 32, Train Loss: 0.1434, Train Acc: 0.9648
# Epoch: 5, Batch: 33, Train Loss: 0.1415, Train Acc: 0.9652
# Epoch: 5, Batch: 34, Train Loss: 0.1406, Train Acc: 0.9655
# Epoch: 5, Batch: 35, Train Loss: 0.1379, Train Acc: 0.9663
# Epoch: 5, Batch: 36, Train Loss: 0.1383, Train Acc: 0.9661
# Epoch: 5, Batch: 37, Train Loss: 0.1356, Train Acc: 0.9666
# Epoch: 5, Batch: 38, Train Loss: 0.1359, Train Acc: 0.9663
# Epoch: 5, Batch: 39, Train Loss: 0.1335, Train Acc: 0.9665
# Epoch: 5, Batch: 40, Train Loss: 0.1304, Train Acc: 0.9674
# Epoch: 5, Batch: 41, Train Loss: 0.1289, Train Acc: 0.9678
# Epoch: 5, Batch: 42, Train Loss: 0.1270, Train Acc: 0.9684
# Epoch: 5, Batch: 43, Train Loss: 0.1249, Train Acc: 0.9688
# Epoch: 5, Batch: 44, Train Loss: 0.1227, Train Acc: 0.9693
# Epoch: 5, Batch: 45, Train Loss: 0.1208, Train Acc: 0.9696
# Epoch: 5, Batch: 46, Train Loss: 0.1203, Train Acc: 0.9694
# Epoch: 5, Batch: 47, Train Loss: 0.1190, Train Acc: 0.9697
# Epoch: 5, Batch: 48, Train Loss: 0.1169, Train Acc: 0.9704
# Epoch: 5, Batch: 49, Train Loss: 0.1154, Train Acc: 0.9705
# Epoch: 5, Batch: 50, Train Loss: 0.1137, Train Acc: 0.9708
# Epoch: 5, Batch: 51, Train Loss: 0.1147, Train Acc: 0.9704
# Epoch: 5, Batch: 52, Train Loss: 0.1141, Train Acc: 0.9707
# Epoch: 5, Batch: 53, Train Loss: 0.1121, Train Acc: 0.9713
# Epoch: 5, Batch: 54, Train Loss: 0.1114, Train Acc: 0.9711
# Epoch: 5, Batch: 55, Train Loss: 0.1118, Train Acc: 0.9707
# Epoch: 5, Batch: 56, Train Loss: 0.1111, Train Acc: 0.9708
# Epoch: 5, Batch: 57, Train Loss: 0.1103, Train Acc: 0.9711
# Epoch: 5, Batch: 58, Train Loss: 0.1093, Train Acc: 0.9712
# Epoch: 5, Batch: 59, Train Loss: 0.1083, Train Acc: 0.9714
# Epoch: 5, Batch: 60, Train Loss: 0.1088, Train Acc: 0.9715
# Epoch: 5, Batch: 61, Train Loss: 0.1092, Train Acc: 0.9716
# Epoch: 5, Batch: 62, Train Loss: 0.1077, Train Acc: 0.9718
# Epoch: 5, Batch: 63, Train Loss: 0.1064, Train Acc: 0.9720
# Epoch: 5, Batch: 64, Train Loss: 0.1054, Train Acc: 0.9720
# Epoch: 5, Batch: 65, Train Loss: 0.1055, Train Acc: 0.9720
# Epoch: 5, Batch: 66, Train Loss: 0.1052, Train Acc: 0.9719
# Epoch: 5, Batch: 67, Train Loss: 0.1051, Train Acc: 0.9715
# Epoch: 5, Batch: 68, Train Loss: 0.1048, Train Acc: 0.9717
# Epoch: 5, Batch: 69, Train Loss: 0.1035, Train Acc: 0.9721
# Epoch: 5, Batch: 70, Train Loss: 0.1026, Train Acc: 0.9722
# Epoch: 5, Batch: 71, Train Loss: 0.1014, Train Acc: 0.9724
# Epoch: 5, Batch: 72, Train Loss: 0.1016, Train Acc: 0.9724
# Epoch: 5, Batch: 73, Train Loss: 0.1011, Train Acc: 0.9725
# Epoch: 5, Batch: 74, Train Loss: 0.1005, Train Acc: 0.9727
# Epoch: 5, Batch: 75, Train Loss: 0.1001, Train Acc: 0.9729
# Epoch: 5, Batch: 76, Train Loss: 0.0992, Train Acc: 0.9731
# Epoch: 5, Batch: 77, Train Loss: 0.0989, Train Acc: 0.9731
# Epoch: 5, Batch: 78, Train Loss: 0.0990, Train Acc: 0.9732
# Epoch: 5, Batch: 79, Train Loss: 0.0997, Train Acc: 0.9731
# Epoch: 6, Batch: 1, Train Loss: 0.0913, Train Acc: 0.9688
# Epoch: 6, Batch: 2, Train Loss: 0.4235, Train Acc: 0.9336
# Epoch: 6, Batch: 3, Train Loss: 0.3892, Train Acc: 0.9375
# Epoch: 6, Batch: 4, Train Loss: 0.3379, Train Acc: 0.9414
# Epoch: 6, Batch: 5, Train Loss: 0.2926, Train Acc: 0.9500
# Epoch: 6, Batch: 6, Train Loss: 0.2707, Train Acc: 0.9505
# Epoch: 6, Batch: 7, Train Loss: 0.2840, Train Acc: 0.9498
# Epoch: 6, Batch: 8, Train Loss: 0.2718, Train Acc: 0.9492
# Epoch: 6, Batch: 9, Train Loss: 0.2651, Train Acc: 0.9497
# Epoch: 6, Batch: 10, Train Loss: 0.2520, Train Acc: 0.9500
# Epoch: 6, Batch: 11, Train Loss: 0.2336, Train Acc: 0.9531
# Epoch: 6, Batch: 12, Train Loss: 0.2216, Train Acc: 0.9544
# Epoch: 6, Batch: 13, Train Loss: 0.2215, Train Acc: 0.9549
# Epoch: 6, Batch: 14, Train Loss: 0.2228, Train Acc: 0.9526
# Epoch: 6, Batch: 15, Train Loss: 0.2168, Train Acc: 0.9536
# Epoch: 6, Batch: 16, Train Loss: 0.2088, Train Acc: 0.9551
# Epoch: 6, Batch: 17, Train Loss: 0.2007, Train Acc: 0.9559
# Epoch: 6, Batch: 18, Train Loss: 0.2010, Train Acc: 0.9544
# Epoch: 6, Batch: 19, Train Loss: 0.1925, Train Acc: 0.9564
# Epoch: 6, Batch: 20, Train Loss: 0.1876, Train Acc: 0.9566
# Epoch: 6, Batch: 21, Train Loss: 0.1822, Train Acc: 0.9568
# Epoch: 6, Batch: 22, Train Loss: 0.1757, Train Acc: 0.9577
# Epoch: 6, Batch: 23, Train Loss: 0.1728, Train Acc: 0.9582
# Epoch: 6, Batch: 24, Train Loss: 0.1669, Train Acc: 0.9596
# Epoch: 6, Batch: 25, Train Loss: 0.1655, Train Acc: 0.9606
# Epoch: 6, Batch: 26, Train Loss: 0.1652, Train Acc: 0.9606
# Epoch: 6, Batch: 27, Train Loss: 0.1656, Train Acc: 0.9604
# Epoch: 6, Batch: 28, Train Loss: 0.1665, Train Acc: 0.9593
# Epoch: 6, Batch: 29, Train Loss: 0.1652, Train Acc: 0.9593
# Epoch: 6, Batch: 30, Train Loss: 0.1623, Train Acc: 0.9596
# Epoch: 6, Batch: 31, Train Loss: 0.1591, Train Acc: 0.9599
# Epoch: 6, Batch: 32, Train Loss: 0.1555, Train Acc: 0.9604
# Epoch: 6, Batch: 33, Train Loss: 0.1545, Train Acc: 0.9607
# Epoch: 6, Batch: 34, Train Loss: 0.1530, Train Acc: 0.9612
# Epoch: 6, Batch: 35, Train Loss: 0.1523, Train Acc: 0.9618
# Epoch: 6, Batch: 36, Train Loss: 0.1495, Train Acc: 0.9627
# Epoch: 6, Batch: 37, Train Loss: 0.1457, Train Acc: 0.9637
# Epoch: 6, Batch: 38, Train Loss: 0.1469, Train Acc: 0.9634
# Epoch: 6, Batch: 39, Train Loss: 0.1493, Train Acc: 0.9625
# Epoch: 6, Batch: 40, Train Loss: 0.1480, Train Acc: 0.9625
# Epoch: 6, Batch: 41, Train Loss: 0.1469, Train Acc: 0.9632
# Epoch: 6, Batch: 42, Train Loss: 0.1452, Train Acc: 0.9637
# Epoch: 6, Batch: 43, Train Loss: 0.1420, Train Acc: 0.9644
# Epoch: 6, Batch: 44, Train Loss: 0.1396, Train Acc: 0.9650
# Epoch: 6, Batch: 45, Train Loss: 0.1377, Train Acc: 0.9655
# Epoch: 6, Batch: 46, Train Loss: 0.1365, Train Acc: 0.9657
# Epoch: 6, Batch: 47, Train Loss: 0.1341, Train Acc: 0.9663
# Epoch: 6, Batch: 48, Train Loss: 0.1329, Train Acc: 0.9663
# Epoch: 6, Batch: 49, Train Loss: 0.1312, Train Acc: 0.9668
# Epoch: 6, Batch: 50, Train Loss: 0.1291, Train Acc: 0.9673
# Epoch: 6, Batch: 51, Train Loss: 0.1277, Train Acc: 0.9675
# Epoch: 6, Batch: 52, Train Loss: 0.1258, Train Acc: 0.9680
# Epoch: 6, Batch: 53, Train Loss: 0.1255, Train Acc: 0.9679
# Epoch: 6, Batch: 54, Train Loss: 0.1237, Train Acc: 0.9683
# Epoch: 6, Batch: 55, Train Loss: 0.1221, Train Acc: 0.9688
# Epoch: 6, Batch: 56, Train Loss: 0.1207, Train Acc: 0.9690
# Epoch: 6, Batch: 57, Train Loss: 0.1220, Train Acc: 0.9688
# Epoch: 6, Batch: 58, Train Loss: 0.1210, Train Acc: 0.9688
# Epoch: 6, Batch: 59, Train Loss: 0.1194, Train Acc: 0.9691
# Epoch: 6, Batch: 60, Train Loss: 0.1176, Train Acc: 0.9697
# Epoch: 6, Batch: 61, Train Loss: 0.1172, Train Acc: 0.9698
# Epoch: 6, Batch: 62, Train Loss: 0.1158, Train Acc: 0.9700
# Epoch: 6, Batch: 63, Train Loss: 0.1155, Train Acc: 0.9700
# Epoch: 6, Batch: 64, Train Loss: 0.1142, Train Acc: 0.9703
# Epoch: 6, Batch: 65, Train Loss: 0.1135, Train Acc: 0.9703
# Epoch: 6, Batch: 66, Train Loss: 0.1124, Train Acc: 0.9705
# Epoch: 6, Batch: 67, Train Loss: 0.1110, Train Acc: 0.9708
# Epoch: 6, Batch: 68, Train Loss: 0.1100, Train Acc: 0.9709
# Epoch: 6, Batch: 69, Train Loss: 0.1091, Train Acc: 0.9711
# Epoch: 6, Batch: 70, Train Loss: 0.1087, Train Acc: 0.9713
# Epoch: 6, Batch: 71, Train Loss: 0.1074, Train Acc: 0.9716
# Epoch: 6, Batch: 72, Train Loss: 0.1085, Train Acc: 0.9715
# Epoch: 6, Batch: 73, Train Loss: 0.1085, Train Acc: 0.9715
# Epoch: 6, Batch: 74, Train Loss: 0.1075, Train Acc: 0.9717
# Epoch: 6, Batch: 75, Train Loss: 0.1083, Train Acc: 0.9716
# Epoch: 6, Batch: 76, Train Loss: 0.1072, Train Acc: 0.9717
# Epoch: 6, Batch: 77, Train Loss: 0.1061, Train Acc: 0.9720
# Epoch: 6, Batch: 78, Train Loss: 0.1057, Train Acc: 0.9719
# Epoch: 6, Batch: 79, Train Loss: 0.1055, Train Acc: 0.9719
# Epoch: 7, Batch: 1, Train Loss: 0.0235, Train Acc: 0.9922
# Epoch: 7, Batch: 2, Train Loss: 0.0158, Train Acc: 0.9961
# Epoch: 7, Batch: 3, Train Loss: 0.0292, Train Acc: 0.9896
# Epoch: 7, Batch: 4, Train Loss: 0.0229, Train Acc: 0.9922
# Epoch: 7, Batch: 5, Train Loss: 0.0400, Train Acc: 0.9875
# Epoch: 7, Batch: 6, Train Loss: 0.0381, Train Acc: 0.9870
# Epoch: 7, Batch: 7, Train Loss: 0.0363, Train Acc: 0.9877
# Epoch: 7, Batch: 8, Train Loss: 0.0322, Train Acc: 0.9893
# Epoch: 7, Batch: 9, Train Loss: 0.0294, Train Acc: 0.9905
# Epoch: 7, Batch: 10, Train Loss: 0.0287, Train Acc: 0.9906
# Epoch: 7, Batch: 11, Train Loss: 0.0290, Train Acc: 0.9901
# Epoch: 7, Batch: 12, Train Loss: 0.0288, Train Acc: 0.9902
# Epoch: 7, Batch: 13, Train Loss: 0.0290, Train Acc: 0.9898
# Epoch: 7, Batch: 14, Train Loss: 0.0279, Train Acc: 0.9900
# Epoch: 7, Batch: 15, Train Loss: 0.0274, Train Acc: 0.9901
# Epoch: 7, Batch: 16, Train Loss: 0.0263, Train Acc: 0.9907
# Epoch: 7, Batch: 17, Train Loss: 0.0276, Train Acc: 0.9908
# Epoch: 7, Batch: 18, Train Loss: 0.0272, Train Acc: 0.9909
# Epoch: 7, Batch: 19, Train Loss: 0.0292, Train Acc: 0.9901
# Epoch: 7, Batch: 20, Train Loss: 0.0399, Train Acc: 0.9895
# Epoch: 7, Batch: 21, Train Loss: 0.0415, Train Acc: 0.9888
# Epoch: 7, Batch: 22, Train Loss: 0.0398, Train Acc: 0.9893
# Epoch: 7, Batch: 23, Train Loss: 0.0381, Train Acc: 0.9898
# Epoch: 7, Batch: 24, Train Loss: 0.0373, Train Acc: 0.9899
# Epoch: 7, Batch: 25, Train Loss: 0.0361, Train Acc: 0.9903
# Epoch: 7, Batch: 26, Train Loss: 0.0392, Train Acc: 0.9895
# Epoch: 7, Batch: 27, Train Loss: 0.0379, Train Acc: 0.9899
# Epoch: 7, Batch: 28, Train Loss: 0.0385, Train Acc: 0.9900
# Epoch: 7, Batch: 29, Train Loss: 0.0384, Train Acc: 0.9900
# Epoch: 7, Batch: 30, Train Loss: 0.0384, Train Acc: 0.9898
# Epoch: 7, Batch: 31, Train Loss: 0.0382, Train Acc: 0.9899
# Epoch: 7, Batch: 32, Train Loss: 0.0411, Train Acc: 0.9893
# Epoch: 7, Batch: 33, Train Loss: 0.0406, Train Acc: 0.9893
# Epoch: 7, Batch: 34, Train Loss: 0.0399, Train Acc: 0.9894
# Epoch: 7, Batch: 35, Train Loss: 0.0396, Train Acc: 0.9895
# Epoch: 7, Batch: 36, Train Loss: 0.0394, Train Acc: 0.9894
# Epoch: 7, Batch: 37, Train Loss: 0.0385, Train Acc: 0.9897
# Epoch: 7, Batch: 38, Train Loss: 0.0384, Train Acc: 0.9895
# Epoch: 7, Batch: 39, Train Loss: 0.0378, Train Acc: 0.9896
# Epoch: 7, Batch: 40, Train Loss: 0.0371, Train Acc: 0.9898
# Epoch: 7, Batch: 41, Train Loss: 0.0365, Train Acc: 0.9901
# Epoch: 7, Batch: 42, Train Loss: 0.0358, Train Acc: 0.9901
# Epoch: 7, Batch: 43, Train Loss: 0.0352, Train Acc: 0.9902
# Epoch: 7, Batch: 44, Train Loss: 0.0352, Train Acc: 0.9902
# Epoch: 7, Batch: 45, Train Loss: 0.0351, Train Acc: 0.9903
# Epoch: 7, Batch: 46, Train Loss: 0.0349, Train Acc: 0.9901
# Epoch: 7, Batch: 47, Train Loss: 0.0343, Train Acc: 0.9902
# Epoch: 7, Batch: 48, Train Loss: 0.0353, Train Acc: 0.9901
# Epoch: 7, Batch: 49, Train Loss: 0.0349, Train Acc: 0.9900
# Epoch: 7, Batch: 50, Train Loss: 0.0343, Train Acc: 0.9902
# Epoch: 7, Batch: 51, Train Loss: 0.0337, Train Acc: 0.9903
# Epoch: 7, Batch: 52, Train Loss: 0.0334, Train Acc: 0.9904
# Epoch: 7, Batch: 53, Train Loss: 0.0328, Train Acc: 0.9906
# Epoch: 7, Batch: 54, Train Loss: 0.0325, Train Acc: 0.9907
# Epoch: 7, Batch: 55, Train Loss: 0.0327, Train Acc: 0.9906
# Epoch: 7, Batch: 56, Train Loss: 0.0329, Train Acc: 0.9907
# Epoch: 7, Batch: 57, Train Loss: 0.0333, Train Acc: 0.9905
# Epoch: 7, Batch: 58, Train Loss: 0.0331, Train Acc: 0.9904
# Epoch: 7, Batch: 59, Train Loss: 0.0333, Train Acc: 0.9903
# Epoch: 7, Batch: 60, Train Loss: 0.0335, Train Acc: 0.9902
# Epoch: 7, Batch: 61, Train Loss: 0.0330, Train Acc: 0.9904
# Epoch: 7, Batch: 62, Train Loss: 0.0326, Train Acc: 0.9905
# Epoch: 7, Batch: 63, Train Loss: 0.0322, Train Acc: 0.9907
# Epoch: 7, Batch: 64, Train Loss: 0.0321, Train Acc: 0.9906
# Epoch: 7, Batch: 65, Train Loss: 0.0318, Train Acc: 0.9906
# Epoch: 7, Batch: 66, Train Loss: 0.0315, Train Acc: 0.9906
# Epoch: 7, Batch: 67, Train Loss: 0.0311, Train Acc: 0.9908
# Epoch: 7, Batch: 68, Train Loss: 0.0311, Train Acc: 0.9908
# Epoch: 7, Batch: 69, Train Loss: 0.0308, Train Acc: 0.9909
# Epoch: 7, Batch: 70, Train Loss: 0.0307, Train Acc: 0.9910
# Epoch: 7, Batch: 71, Train Loss: 0.0313, Train Acc: 0.9909
# Epoch: 7, Batch: 72, Train Loss: 0.0309, Train Acc: 0.9910
# Epoch: 7, Batch: 73, Train Loss: 0.0306, Train Acc: 0.9911
# Epoch: 7, Batch: 74, Train Loss: 0.0309, Train Acc: 0.9910
# Epoch: 7, Batch: 75, Train Loss: 0.0309, Train Acc: 0.9910
# Epoch: 7, Batch: 76, Train Loss: 0.0309, Train Acc: 0.9910
# Epoch: 7, Batch: 77, Train Loss: 0.0307, Train Acc: 0.9910
# Epoch: 7, Batch: 78, Train Loss: 0.0303, Train Acc: 0.9911
# Epoch: 7, Batch: 79, Train Loss: 0.0303, Train Acc: 0.9911
# Epoch: 8, Batch: 1, Train Loss: 0.0010, Train Acc: 1.0000
# Epoch: 8, Batch: 2, Train Loss: 0.0078, Train Acc: 0.9961
# Epoch: 8, Batch: 3, Train Loss: 0.0160, Train Acc: 0.9948
# Epoch: 8, Batch: 4, Train Loss: 0.0136, Train Acc: 0.9961
# Epoch: 8, Batch: 5, Train Loss: 0.0114, Train Acc: 0.9969
# Epoch: 8, Batch: 6, Train Loss: 0.0102, Train Acc: 0.9974
# Epoch: 8, Batch: 7, Train Loss: 0.0131, Train Acc: 0.9967
# Epoch: 8, Batch: 8, Train Loss: 0.0118, Train Acc: 0.9971
# Epoch: 8, Batch: 9, Train Loss: 0.0116, Train Acc: 0.9974
# Epoch: 8, Batch: 10, Train Loss: 0.0106, Train Acc: 0.9977
# Epoch: 8, Batch: 11, Train Loss: 0.0099, Train Acc: 0.9979
# Epoch: 8, Batch: 12, Train Loss: 0.0095, Train Acc: 0.9980
# Epoch: 8, Batch: 13, Train Loss: 0.0093, Train Acc: 0.9982
# Epoch: 8, Batch: 14, Train Loss: 0.0099, Train Acc: 0.9978
# Epoch: 8, Batch: 15, Train Loss: 0.0098, Train Acc: 0.9974
# Epoch: 8, Batch: 16, Train Loss: 0.0098, Train Acc: 0.9976
# Epoch: 8, Batch: 17, Train Loss: 0.0096, Train Acc: 0.9977
# Epoch: 8, Batch: 18, Train Loss: 0.0093, Train Acc: 0.9978
# Epoch: 8, Batch: 19, Train Loss: 0.0089, Train Acc: 0.9979
# Epoch: 8, Batch: 20, Train Loss: 0.0085, Train Acc: 0.9980
# Epoch: 8, Batch: 21, Train Loss: 0.0081, Train Acc: 0.9981
# Epoch: 8, Batch: 22, Train Loss: 0.0081, Train Acc: 0.9982
# Epoch: 8, Batch: 23, Train Loss: 0.0085, Train Acc: 0.9980
# Epoch: 8, Batch: 24, Train Loss: 0.0086, Train Acc: 0.9977
# Epoch: 8, Batch: 25, Train Loss: 0.0087, Train Acc: 0.9978
# Epoch: 8, Batch: 26, Train Loss: 0.0084, Train Acc: 0.9979
# Epoch: 8, Batch: 27, Train Loss: 0.0081, Train Acc: 0.9980
# Epoch: 8, Batch: 28, Train Loss: 0.0079, Train Acc: 0.9980
# Epoch: 8, Batch: 29, Train Loss: 0.0076, Train Acc: 0.9981
# Epoch: 8, Batch: 30, Train Loss: 0.0076, Train Acc: 0.9982
# Epoch: 8, Batch: 31, Train Loss: 0.0073, Train Acc: 0.9982
# Epoch: 8, Batch: 32, Train Loss: 0.0074, Train Acc: 0.9983
# Epoch: 8, Batch: 33, Train Loss: 0.0072, Train Acc: 0.9983
# Epoch: 8, Batch: 34, Train Loss: 0.0070, Train Acc: 0.9984
# Epoch: 8, Batch: 35, Train Loss: 0.0068, Train Acc: 0.9984
# Epoch: 8, Batch: 36, Train Loss: 0.0067, Train Acc: 0.9985
# Epoch: 8, Batch: 37, Train Loss: 0.0066, Train Acc: 0.9985
# Epoch: 8, Batch: 38, Train Loss: 0.0065, Train Acc: 0.9986
# Epoch: 8, Batch: 39, Train Loss: 0.0064, Train Acc: 0.9986
# Epoch: 8, Batch: 40, Train Loss: 0.0063, Train Acc: 0.9986
# Epoch: 8, Batch: 41, Train Loss: 0.0065, Train Acc: 0.9985
# Epoch: 8, Batch: 42, Train Loss: 0.0065, Train Acc: 0.9985
# Epoch: 8, Batch: 43, Train Loss: 0.0067, Train Acc: 0.9982
# Epoch: 8, Batch: 44, Train Loss: 0.0068, Train Acc: 0.9982
# Epoch: 8, Batch: 45, Train Loss: 0.0067, Train Acc: 0.9983
# Epoch: 8, Batch: 46, Train Loss: 0.0066, Train Acc: 0.9983
# Epoch: 8, Batch: 47, Train Loss: 0.0066, Train Acc: 0.9983
# Epoch: 8, Batch: 48, Train Loss: 0.0067, Train Acc: 0.9982
# Epoch: 8, Batch: 49, Train Loss: 0.0067, Train Acc: 0.9982
# Epoch: 8, Batch: 50, Train Loss: 0.0066, Train Acc: 0.9983
# Epoch: 8, Batch: 51, Train Loss: 0.0064, Train Acc: 0.9983
# Epoch: 8, Batch: 52, Train Loss: 0.0064, Train Acc: 0.9983
# Epoch: 8, Batch: 53, Train Loss: 0.0063, Train Acc: 0.9984
# Epoch: 8, Batch: 54, Train Loss: 0.0062, Train Acc: 0.9984
# Epoch: 8, Batch: 55, Train Loss: 0.0068, Train Acc: 0.9982
# Epoch: 8, Batch: 56, Train Loss: 0.0074, Train Acc: 0.9980
# Epoch: 8, Batch: 57, Train Loss: 0.0073, Train Acc: 0.9981
# Epoch: 8, Batch: 58, Train Loss: 0.0072, Train Acc: 0.9981
# Epoch: 8, Batch: 59, Train Loss: 0.0071, Train Acc: 0.9981
# Epoch: 8, Batch: 60, Train Loss: 0.0076, Train Acc: 0.9979
# Epoch: 8, Batch: 61, Train Loss: 0.0075, Train Acc: 0.9980
# Epoch: 8, Batch: 62, Train Loss: 0.0087, Train Acc: 0.9976
# Epoch: 8, Batch: 63, Train Loss: 0.0086, Train Acc: 0.9976
# Epoch: 8, Batch: 64, Train Loss: 0.0085, Train Acc: 0.9977
# Epoch: 8, Batch: 65, Train Loss: 0.0083, Train Acc: 0.9977
# Epoch: 8, Batch: 66, Train Loss: 0.0083, Train Acc: 0.9978
# Epoch: 8, Batch: 67, Train Loss: 0.0088, Train Acc: 0.9976
# Epoch: 8, Batch: 68, Train Loss: 0.0094, Train Acc: 0.9974
# Epoch: 8, Batch: 69, Train Loss: 0.0096, Train Acc: 0.9973
# Epoch: 8, Batch: 70, Train Loss: 0.0119, Train Acc: 0.9969
# Epoch: 8, Batch: 71, Train Loss: 0.0118, Train Acc: 0.9969
# Epoch: 8, Batch: 72, Train Loss: 0.0121, Train Acc: 0.9967
# Epoch: 8, Batch: 73, Train Loss: 0.0120, Train Acc: 0.9967
# Epoch: 8, Batch: 74, Train Loss: 0.0120, Train Acc: 0.9966
# Epoch: 8, Batch: 75, Train Loss: 0.0121, Train Acc: 0.9966
# Epoch: 8, Batch: 76, Train Loss: 0.0123, Train Acc: 0.9965
# Epoch: 8, Batch: 77, Train Loss: 0.0130, Train Acc: 0.9964
# Epoch: 8, Batch: 78, Train Loss: 0.0131, Train Acc: 0.9964
# Epoch: 8, Batch: 79, Train Loss: 0.0131, Train Acc: 0.9964
# Epoch: 9, Batch: 1, Train Loss: 0.0381, Train Acc: 0.9844
# Epoch: 9, Batch: 2, Train Loss: 0.0196, Train Acc: 0.9922
# Epoch: 9, Batch: 3, Train Loss: 0.0167, Train Acc: 0.9922
# Epoch: 9, Batch: 4, Train Loss: 0.0141, Train Acc: 0.9941
# Epoch: 9, Batch: 5, Train Loss: 0.0113, Train Acc: 0.9953
# Epoch: 9, Batch: 6, Train Loss: 0.0110, Train Acc: 0.9948
# Epoch: 9, Batch: 7, Train Loss: 0.0095, Train Acc: 0.9955
# Epoch: 9, Batch: 8, Train Loss: 0.0084, Train Acc: 0.9961
# Epoch: 9, Batch: 9, Train Loss: 0.0107, Train Acc: 0.9939
# Epoch: 9, Batch: 10, Train Loss: 0.0109, Train Acc: 0.9938
# Epoch: 9, Batch: 11, Train Loss: 0.0102, Train Acc: 0.9943
# Epoch: 9, Batch: 12, Train Loss: 0.0094, Train Acc: 0.9948
# Epoch: 9, Batch: 13, Train Loss: 0.0089, Train Acc: 0.9952
# Epoch: 9, Batch: 14, Train Loss: 0.0087, Train Acc: 0.9955
# Epoch: 9, Batch: 15, Train Loss: 0.0082, Train Acc: 0.9958
# Epoch: 9, Batch: 16, Train Loss: 0.0078, Train Acc: 0.9961
# Epoch: 9, Batch: 17, Train Loss: 0.0074, Train Acc: 0.9963
# Epoch: 9, Batch: 18, Train Loss: 0.0070, Train Acc: 0.9965
# Epoch: 9, Batch: 19, Train Loss: 0.0068, Train Acc: 0.9967
# Epoch: 9, Batch: 20, Train Loss: 0.0065, Train Acc: 0.9969
# Epoch: 9, Batch: 21, Train Loss: 0.0063, Train Acc: 0.9970
# Epoch: 9, Batch: 22, Train Loss: 0.0061, Train Acc: 0.9972
# Epoch: 9, Batch: 23, Train Loss: 0.0063, Train Acc: 0.9969
# Epoch: 9, Batch: 24, Train Loss: 0.0061, Train Acc: 0.9971
# Epoch: 9, Batch: 25, Train Loss: 0.0063, Train Acc: 0.9969
# Epoch: 9, Batch: 26, Train Loss: 0.0061, Train Acc: 0.9970
# Epoch: 9, Batch: 27, Train Loss: 0.0080, Train Acc: 0.9968
# Epoch: 9, Batch: 28, Train Loss: 0.0078, Train Acc: 0.9969
# Epoch: 9, Batch: 29, Train Loss: 0.0075, Train Acc: 0.9970
# Epoch: 9, Batch: 30, Train Loss: 0.0082, Train Acc: 0.9966
# Epoch: 9, Batch: 31, Train Loss: 0.0080, Train Acc: 0.9967
# Epoch: 9, Batch: 32, Train Loss: 0.0078, Train Acc: 0.9968
# Epoch: 9, Batch: 33, Train Loss: 0.0081, Train Acc: 0.9967
# Epoch: 9, Batch: 34, Train Loss: 0.0078, Train Acc: 0.9968
# Epoch: 9, Batch: 35, Train Loss: 0.0083, Train Acc: 0.9964
# Epoch: 9, Batch: 36, Train Loss: 0.0084, Train Acc: 0.9963
# Epoch: 9, Batch: 37, Train Loss: 0.0082, Train Acc: 0.9964
# Epoch: 9, Batch: 38, Train Loss: 0.0083, Train Acc: 0.9965
# Epoch: 9, Batch: 39, Train Loss: 0.0081, Train Acc: 0.9966
# Epoch: 9, Batch: 40, Train Loss: 0.0079, Train Acc: 0.9967
# Epoch: 9, Batch: 41, Train Loss: 0.0077, Train Acc: 0.9968
# Epoch: 9, Batch: 42, Train Loss: 0.0079, Train Acc: 0.9967
# Epoch: 9, Batch: 43, Train Loss: 0.0085, Train Acc: 0.9965
# Epoch: 9, Batch: 44, Train Loss: 0.0084, Train Acc: 0.9966
# Epoch: 9, Batch: 45, Train Loss: 0.0096, Train Acc: 0.9962
# Epoch: 9, Batch: 46, Train Loss: 0.0099, Train Acc: 0.9961
# Epoch: 9, Batch: 47, Train Loss: 0.0097, Train Acc: 0.9962
# Epoch: 9, Batch: 48, Train Loss: 0.0096, Train Acc: 0.9963
# Epoch: 9, Batch: 49, Train Loss: 0.0095, Train Acc: 0.9963
# Epoch: 9, Batch: 50, Train Loss: 0.0097, Train Acc: 0.9962
# Epoch: 9, Batch: 51, Train Loss: 0.0096, Train Acc: 0.9963
# Epoch: 9, Batch: 52, Train Loss: 0.0097, Train Acc: 0.9962
# Epoch: 9, Batch: 53, Train Loss: 0.0099, Train Acc: 0.9962
# Epoch: 9, Batch: 54, Train Loss: 0.0098, Train Acc: 0.9962
# Epoch: 9, Batch: 55, Train Loss: 0.0096, Train Acc: 0.9963
# Epoch: 9, Batch: 56, Train Loss: 0.0097, Train Acc: 0.9962
# Epoch: 9, Batch: 57, Train Loss: 0.0097, Train Acc: 0.9962
# Epoch: 9, Batch: 58, Train Loss: 0.0095, Train Acc: 0.9962
# Epoch: 9, Batch: 59, Train Loss: 0.0105, Train Acc: 0.9960
# Epoch: 9, Batch: 60, Train Loss: 0.0103, Train Acc: 0.9961
# Epoch: 9, Batch: 61, Train Loss: 0.0108, Train Acc: 0.9959
# Epoch: 9, Batch: 62, Train Loss: 0.0107, Train Acc: 0.9958
# Epoch: 9, Batch: 63, Train Loss: 0.0106, Train Acc: 0.9959
# Epoch: 9, Batch: 64, Train Loss: 0.0105, Train Acc: 0.9960
# Epoch: 9, Batch: 65, Train Loss: 0.0108, Train Acc: 0.9959
# Epoch: 9, Batch: 66, Train Loss: 0.0106, Train Acc: 0.9960
# Epoch: 9, Batch: 67, Train Loss: 0.0108, Train Acc: 0.9958
# Epoch: 9, Batch: 68, Train Loss: 0.0113, Train Acc: 0.9957
# Epoch: 9, Batch: 69, Train Loss: 0.0112, Train Acc: 0.9958
# Epoch: 9, Batch: 70, Train Loss: 0.0113, Train Acc: 0.9958
# Epoch: 9, Batch: 71, Train Loss: 0.0113, Train Acc: 0.9957
# Epoch: 9, Batch: 72, Train Loss: 0.0120, Train Acc: 0.9957
# Epoch: 9, Batch: 73, Train Loss: 0.0122, Train Acc: 0.9956
# Epoch: 9, Batch: 74, Train Loss: 0.0121, Train Acc: 0.9957
# Epoch: 9, Batch: 75, Train Loss: 0.0128, Train Acc: 0.9955
# Epoch: 9, Batch: 76, Train Loss: 0.0128, Train Acc: 0.9955
# Epoch: 9, Batch: 77, Train Loss: 0.0127, Train Acc: 0.9955
# Epoch: 9, Batch: 78, Train Loss: 0.0126, Train Acc: 0.9956
# Epoch: 9, Batch: 79, Train Loss: 0.0125, Train Acc: 0.9956
# Epoch: 10, Batch: 1, Train Loss: 0.0028, Train Acc: 1.0000
# Epoch: 10, Batch: 2, Train Loss: 0.0037, Train Acc: 1.0000
# Epoch: 10, Batch: 3, Train Loss: 0.0095, Train Acc: 0.9974
# Epoch: 10, Batch: 4, Train Loss: 0.0139, Train Acc: 0.9961
# Epoch: 10, Batch: 5, Train Loss: 0.0116, Train Acc: 0.9969
# Epoch: 10, Batch: 6, Train Loss: 0.0104, Train Acc: 0.9974
# Epoch: 10, Batch: 7, Train Loss: 0.0091, Train Acc: 0.9978
# Epoch: 10, Batch: 8, Train Loss: 0.0083, Train Acc: 0.9980
# Epoch: 10, Batch: 9, Train Loss: 0.0076, Train Acc: 0.9983
# Epoch: 10, Batch: 10, Train Loss: 0.0071, Train Acc: 0.9984
# Epoch: 10, Batch: 11, Train Loss: 0.0065, Train Acc: 0.9986
# Epoch: 10, Batch: 12, Train Loss: 0.0060, Train Acc: 0.9987
# Epoch: 10, Batch: 13, Train Loss: 0.0056, Train Acc: 0.9988
# Epoch: 10, Batch: 14, Train Loss: 0.0052, Train Acc: 0.9989
# Epoch: 10, Batch: 15, Train Loss: 0.0049, Train Acc: 0.9990
# Epoch: 10, Batch: 16, Train Loss: 0.0048, Train Acc: 0.9990
# Epoch: 10, Batch: 17, Train Loss: 0.0049, Train Acc: 0.9986
# Epoch: 10, Batch: 18, Train Loss: 0.0049, Train Acc: 0.9987
# Epoch: 10, Batch: 19, Train Loss: 0.0049, Train Acc: 0.9988
# Epoch: 10, Batch: 20, Train Loss: 0.0047, Train Acc: 0.9988
# Epoch: 10, Batch: 21, Train Loss: 0.0045, Train Acc: 0.9989
# Epoch: 10, Batch: 22, Train Loss: 0.0043, Train Acc: 0.9989
# Epoch: 10, Batch: 23, Train Loss: 0.0041, Train Acc: 0.9990
# Epoch: 10, Batch: 24, Train Loss: 0.0040, Train Acc: 0.9990
# Epoch: 10, Batch: 25, Train Loss: 0.0038, Train Acc: 0.9991
# Epoch: 10, Batch: 26, Train Loss: 0.0037, Train Acc: 0.9991
# Epoch: 10, Batch: 27, Train Loss: 0.0040, Train Acc: 0.9988
# Epoch: 10, Batch: 28, Train Loss: 0.0044, Train Acc: 0.9986
# Epoch: 10, Batch: 29, Train Loss: 0.0043, Train Acc: 0.9987
# Epoch: 10, Batch: 30, Train Loss: 0.0042, Train Acc: 0.9987
# Epoch: 10, Batch: 31, Train Loss: 0.0041, Train Acc: 0.9987
# Epoch: 10, Batch: 32, Train Loss: 0.0040, Train Acc: 0.9988
# Epoch: 10, Batch: 33, Train Loss: 0.0039, Train Acc: 0.9988
# Epoch: 10, Batch: 34, Train Loss: 0.0039, Train Acc: 0.9989
# Epoch: 10, Batch: 35, Train Loss: 0.0039, Train Acc: 0.9989
# Epoch: 10, Batch: 36, Train Loss: 0.0040, Train Acc: 0.9989
# Epoch: 10, Batch: 37, Train Loss: 0.0039, Train Acc: 0.9989
# Epoch: 10, Batch: 38, Train Loss: 0.0038, Train Acc: 0.9990
# Epoch: 10, Batch: 39, Train Loss: 0.0041, Train Acc: 0.9986
# Epoch: 10, Batch: 40, Train Loss: 0.0040, Train Acc: 0.9986
# Epoch: 10, Batch: 41, Train Loss: 0.0040, Train Acc: 0.9987
# Epoch: 10, Batch: 42, Train Loss: 0.0040, Train Acc: 0.9987
# Epoch: 10, Batch: 43, Train Loss: 0.0039, Train Acc: 0.9987
# Epoch: 10, Batch: 44, Train Loss: 0.0039, Train Acc: 0.9988
# Epoch: 10, Batch: 45, Train Loss: 0.0038, Train Acc: 0.9988
# Epoch: 10, Batch: 46, Train Loss: 0.0046, Train Acc: 0.9985
# Epoch: 10, Batch: 47, Train Loss: 0.0048, Train Acc: 0.9983
# Epoch: 10, Batch: 48, Train Loss: 0.0048, Train Acc: 0.9984
# Epoch: 10, Batch: 49, Train Loss: 0.0047, Train Acc: 0.9984
# Epoch: 10, Batch: 50, Train Loss: 0.0047, Train Acc: 0.9984
# Epoch: 10, Batch: 51, Train Loss: 0.0046, Train Acc: 0.9985
# Epoch: 10, Batch: 52, Train Loss: 0.0046, Train Acc: 0.9985
# Epoch: 10, Batch: 53, Train Loss: 0.0045, Train Acc: 0.9985
# Epoch: 10, Batch: 54, Train Loss: 0.0045, Train Acc: 0.9986
# Epoch: 10, Batch: 55, Train Loss: 0.0047, Train Acc: 0.9984
# Epoch: 10, Batch: 56, Train Loss: 0.0047, Train Acc: 0.9985
# Epoch: 10, Batch: 57, Train Loss: 0.0047, Train Acc: 0.9985
# Epoch: 10, Batch: 58, Train Loss: 0.0049, Train Acc: 0.9984
# Epoch: 10, Batch: 59, Train Loss: 0.0048, Train Acc: 0.9984
# Epoch: 10, Batch: 60, Train Loss: 0.0047, Train Acc: 0.9984
# Epoch: 10, Batch: 61, Train Loss: 0.0051, Train Acc: 0.9983
# Epoch: 10, Batch: 62, Train Loss: 0.0051, Train Acc: 0.9984
# Epoch: 10, Batch: 63, Train Loss: 0.0050, Train Acc: 0.9984
# Epoch: 10, Batch: 64, Train Loss: 0.0050, Train Acc: 0.9984
# Epoch: 10, Batch: 65, Train Loss: 0.0054, Train Acc: 0.9983
# Epoch: 10, Batch: 66, Train Loss: 0.0053, Train Acc: 0.9983
# Epoch: 10, Batch: 67, Train Loss: 0.0062, Train Acc: 0.9983
# Epoch: 10, Batch: 68, Train Loss: 0.0062, Train Acc: 0.9983
# Epoch: 10, Batch: 69, Train Loss: 0.0068, Train Acc: 0.9981
# Epoch: 10, Batch: 70, Train Loss: 0.0067, Train Acc: 0.9981
# Epoch: 10, Batch: 71, Train Loss: 0.0072, Train Acc: 0.9980
# Epoch: 10, Batch: 72, Train Loss: 0.0071, Train Acc: 0.9980
# Epoch: 10, Batch: 73, Train Loss: 0.0079, Train Acc: 0.9980
# Epoch: 10, Batch: 74, Train Loss: 0.0078, Train Acc: 0.9980
# Epoch: 10, Batch: 75, Train Loss: 0.0078, Train Acc: 0.9979
# Epoch: 10, Batch: 76, Train Loss: 0.0077, Train Acc: 0.9979
# Epoch: 10, Batch: 77, Train Loss: 0.0078, Train Acc: 0.9979
# Epoch: 10, Batch: 78, Train Loss: 0.0077, Train Acc: 0.9979
# Epoch: 10, Batch: 79, Train Loss: 0.0077, Train Acc: 0.9979
# Epoch: 11, Batch: 1, Train Loss: 0.0156, Train Acc: 0.9844
# Epoch: 11, Batch: 2, Train Loss: 0.0094, Train Acc: 0.9922
# Epoch: 11, Batch: 3, Train Loss: 0.0063, Train Acc: 0.9948
# Epoch: 11, Batch: 4, Train Loss: 0.0049, Train Acc: 0.9961
# Epoch: 11, Batch: 5, Train Loss: 0.0096, Train Acc: 0.9953
# Epoch: 11, Batch: 6, Train Loss: 0.0094, Train Acc: 0.9948
# Epoch: 11, Batch: 7, Train Loss: 0.0083, Train Acc: 0.9955
# Epoch: 11, Batch: 8, Train Loss: 0.0076, Train Acc: 0.9961
# Epoch: 11, Batch: 9, Train Loss: 0.0076, Train Acc: 0.9965
# Epoch: 11, Batch: 10, Train Loss: 0.0069, Train Acc: 0.9969
# Epoch: 11, Batch: 11, Train Loss: 0.0067, Train Acc: 0.9972
# Epoch: 11, Batch: 12, Train Loss: 0.0070, Train Acc: 0.9974
# Epoch: 11, Batch: 13, Train Loss: 0.0087, Train Acc: 0.9970
# Epoch: 11, Batch: 14, Train Loss: 0.0081, Train Acc: 0.9972
# Epoch: 11, Batch: 15, Train Loss: 0.0098, Train Acc: 0.9964
# Epoch: 11, Batch: 16, Train Loss: 0.0093, Train Acc: 0.9966
# Epoch: 11, Batch: 17, Train Loss: 0.0089, Train Acc: 0.9968
# Epoch: 11, Batch: 18, Train Loss: 0.0086, Train Acc: 0.9970
# Epoch: 11, Batch: 19, Train Loss: 0.0082, Train Acc: 0.9971
# Epoch: 11, Batch: 20, Train Loss: 0.0079, Train Acc: 0.9973
# Epoch: 11, Batch: 21, Train Loss: 0.0079, Train Acc: 0.9970
# Epoch: 11, Batch: 22, Train Loss: 0.0077, Train Acc: 0.9972
# Epoch: 11, Batch: 23, Train Loss: 0.0074, Train Acc: 0.9973
# ...
# Epoch: 17, Batch: 51, Train Loss: 0.0275, Train Acc: 0.9916
# Epoch: 17, Batch: 52, Train Loss: 0.0271, Train Acc: 0.9917
# Epoch: 17, Batch: 53, Train Loss: 0.0267, Train Acc: 0.9919
# Epoch: 17, Batch: 54, Train Loss: 0.0268, Train Acc: 0.9919
# Epoch: 17, Batch: 55, Train Loss: 0.0268, Train Acc: 0.9919
# Epoch: 17, Batch: 56, Train Loss: 0.0270, Train Acc: 0.9919
# Epoch: 17, Batch: 57, Train Loss: 0.0268, Train Acc: 0.9919
# Epoch: 17, Batch: 58, Train Loss: 0.0266, Train Acc: 0.9919
# Epoch: 17, Batch: 59, Train Loss: 0.0268, Train Acc: 0.9918
# Epoch: 17, Batch: 60, Train Loss: 0.0264, Train Acc: 0.9919
# Epoch: 17, Batch: 61, Train Loss: 0.0263, Train Acc: 0.9919
# Epoch: 17, Batch: 62, Train Loss: 0.0261, Train Acc: 0.9921
# Epoch: 17, Batch: 63, Train Loss: 0.0257, Train Acc: 0.9922
# Epoch: 17, Batch: 64, Train Loss: 0.0262, Train Acc: 0.9921
# Epoch: 17, Batch: 65, Train Loss: 0.0263, Train Acc: 0.9919
# Epoch: 17, Batch: 66, Train Loss: 0.0262, Train Acc: 0.9920
# Epoch: 17, Batch: 67, Train Loss: 0.0258, Train Acc: 0.9921
# Epoch: 17, Batch: 68, Train Loss: 0.0255, Train Acc: 0.9922
# Epoch: 17, Batch: 69, Train Loss: 0.0256, Train Acc: 0.9922
# Epoch: 17, Batch: 70, Train Loss: 0.0253, Train Acc: 0.9923
# Epoch: 17, Batch: 71, Train Loss: 0.0251, Train Acc: 0.9923
# Epoch: 17, Batch: 72, Train Loss: 0.0251, Train Acc: 0.9923
# Epoch: 17, Batch: 73, Train Loss: 0.0251, Train Acc: 0.9923
# Epoch: 17, Batch: 74, Train Loss: 0.0250, Train Acc: 0.9922
# Epoch: 17, Batch: 75, Train Loss: 0.0247, Train Acc: 0.9923
# Epoch: 17, Batch: 76, Train Loss: 0.0245, Train Acc: 0.9923
# Epoch: 17, Batch: 77, Train Loss: 0.0242, Train Acc: 0.9924
# Epoch: 17, Batch: 78, Train Loss: 0.0246, Train Acc: 0.9923
# Epoch: 17, Batch: 79, Train Loss: 0.0246, Train Acc: 0.9923
# Epoch: 18, Batch: 1, Train Loss: 0.0009, Train Acc: 1.0000
# Epoch: 18, Batch: 2, Train Loss: 0.0006, Train Acc: 1.0000
# Epoch: 18, Batch: 3, Train Loss: 0.0008, Train Acc: 1.0000
# Epoch: 18, Batch: 4, Train Loss: 0.0071, Train Acc: 0.9980
# Epoch: 18, Batch: 5, Train Loss: 0.0162, Train Acc: 0.9953
# Epoch: 18, Batch: 6, Train Loss: 0.0139, Train Acc: 0.9961
# Epoch: 18, Batch: 7, Train Loss: 0.0182, Train Acc: 0.9955
# Epoch: 18, Batch: 8, Train Loss: 0.0173, Train Acc: 0.9961
# Epoch: 18, Batch: 9, Train Loss: 0.0168, Train Acc: 0.9957
# Epoch: 18, Batch: 10, Train Loss: 0.0157, Train Acc: 0.9961
# Epoch: 18, Batch: 11, Train Loss: 0.0146, Train Acc: 0.9964
# Epoch: 18, Batch: 12, Train Loss: 0.0137, Train Acc: 0.9967
# Epoch: 18, Batch: 13, Train Loss: 0.0127, Train Acc: 0.9970
# Epoch: 18, Batch: 14, Train Loss: 0.0134, Train Acc: 0.9967
# Epoch: 18, Batch: 15, Train Loss: 0.0127, Train Acc: 0.9969
# Epoch: 18, Batch: 16, Train Loss: 0.0123, Train Acc: 0.9971
# Epoch: 18, Batch: 17, Train Loss: 0.0133, Train Acc: 0.9968
# Epoch: 18, Batch: 18, Train Loss: 0.0126, Train Acc: 0.9970
# Epoch: 18, Batch: 19, Train Loss: 0.0121, Train Acc: 0.9971
# Epoch: 18, Batch: 20, Train Loss: 0.0120, Train Acc: 0.9969
# Epoch: 18, Batch: 21, Train Loss: 0.0145, Train Acc: 0.9963
# Epoch: 18, Batch: 22, Train Loss: 0.0142, Train Acc: 0.9964
# Epoch: 18, Batch: 23, Train Loss: 0.0148, Train Acc: 0.9963
# Epoch: 18, Batch: 24, Train Loss: 0.0148, Train Acc: 0.9961
# Epoch: 18, Batch: 25, Train Loss: 0.0153, Train Acc: 0.9959
# Epoch: 18, Batch: 26, Train Loss: 0.0154, Train Acc: 0.9958
# Epoch: 18, Batch: 27, Train Loss: 0.0149, Train Acc: 0.9959
# Epoch: 18, Batch: 28, Train Loss: 0.0144, Train Acc: 0.9961
# Epoch: 18, Batch: 29, Train Loss: 0.0144, Train Acc: 0.9960
# Epoch: 18, Batch: 30, Train Loss: 0.0156, Train Acc: 0.9953
# Epoch: 18, Batch: 31, Train Loss: 0.0153, Train Acc: 0.9955
# Epoch: 18, Batch: 32, Train Loss: 0.0150, Train Acc: 0.9956
# Epoch: 18, Batch: 33, Train Loss: 0.0158, Train Acc: 0.9953
# Epoch: 18, Batch: 34, Train Loss: 0.0156, Train Acc: 0.9954
# Epoch: 18, Batch: 35, Train Loss: 0.0152, Train Acc: 0.9955
# Epoch: 18, Batch: 36, Train Loss: 0.0151, Train Acc: 0.9954
# Epoch: 18, Batch: 37, Train Loss: 0.0147, Train Acc: 0.9956
# Epoch: 18, Batch: 38, Train Loss: 0.0151, Train Acc: 0.9955
# Epoch: 18, Batch: 39, Train Loss: 0.0147, Train Acc: 0.9956
# Epoch: 18, Batch: 40, Train Loss: 0.0145, Train Acc: 0.9957
# Epoch: 18, Batch: 41, Train Loss: 0.0142, Train Acc: 0.9958
# Epoch: 18, Batch: 42, Train Loss: 0.0140, Train Acc: 0.9959
# Epoch: 18, Batch: 43, Train Loss: 0.0137, Train Acc: 0.9960
# Epoch: 18, Batch: 44, Train Loss: 0.0136, Train Acc: 0.9959
# Epoch: 18, Batch: 45, Train Loss: 0.0134, Train Acc: 0.9960
# Epoch: 18, Batch: 46, Train Loss: 0.0133, Train Acc: 0.9961
# Epoch: 18, Batch: 47, Train Loss: 0.0130, Train Acc: 0.9962
# Epoch: 18, Batch: 48, Train Loss: 0.0127, Train Acc: 0.9963
# Epoch: 18, Batch: 49, Train Loss: 0.0126, Train Acc: 0.9963
# Epoch: 18, Batch: 50, Train Loss: 0.0132, Train Acc: 0.9962
# Epoch: 18, Batch: 51, Train Loss: 0.0132, Train Acc: 0.9962
# Epoch: 18, Batch: 52, Train Loss: 0.0131, Train Acc: 0.9962
# Epoch: 18, Batch: 53, Train Loss: 0.0130, Train Acc: 0.9962
# Epoch: 18, Batch: 54, Train Loss: 0.0130, Train Acc: 0.9961
# Epoch: 18, Batch: 55, Train Loss: 0.0128, Train Acc: 0.9962
# Epoch: 18, Batch: 56, Train Loss: 0.0127, Train Acc: 0.9961
# Epoch: 18, Batch: 57, Train Loss: 0.0125, Train Acc: 0.9962
# Epoch: 18, Batch: 58, Train Loss: 0.0123, Train Acc: 0.9962
# Epoch: 18, Batch: 59, Train Loss: 0.0121, Train Acc: 0.9963
# Epoch: 18, Batch: 60, Train Loss: 0.0119, Train Acc: 0.9964
# Epoch: 18, Batch: 61, Train Loss: 0.0119, Train Acc: 0.9963
# Epoch: 18, Batch: 62, Train Loss: 0.0117, Train Acc: 0.9963
# Epoch: 18, Batch: 63, Train Loss: 0.0115, Train Acc: 0.9964
# Epoch: 18, Batch: 64, Train Loss: 0.0113, Train Acc: 0.9965
# Epoch: 18, Batch: 65, Train Loss: 0.0112, Train Acc: 0.9965
# Epoch: 18, Batch: 66, Train Loss: 0.0111, Train Acc: 0.9966
# Epoch: 18, Batch: 67, Train Loss: 0.0109, Train Acc: 0.9966
# Epoch: 18, Batch: 68, Train Loss: 0.0108, Train Acc: 0.9967
# Epoch: 18, Batch: 69, Train Loss: 0.0107, Train Acc: 0.9967
# Epoch: 18, Batch: 70, Train Loss: 0.0105, Train Acc: 0.9968
# Epoch: 18, Batch: 71, Train Loss: 0.0104, Train Acc: 0.9968
# Epoch: 18, Batch: 72, Train Loss: 0.0103, Train Acc: 0.9969
# Epoch: 18, Batch: 73, Train Loss: 0.0103, Train Acc: 0.9969
# Epoch: 18, Batch: 74, Train Loss: 0.0101, Train Acc: 0.9969
# Epoch: 18, Batch: 75, Train Loss: 0.0100, Train Acc: 0.9970
# Epoch: 18, Batch: 76, Train Loss: 0.0099, Train Acc: 0.9970
# Epoch: 18, Batch: 77, Train Loss: 0.0099, Train Acc: 0.9970
# Epoch: 18, Batch: 78, Train Loss: 0.0100, Train Acc: 0.9969
# Epoch: 18, Batch: 79, Train Loss: 0.0100, Train Acc: 0.9969
# Epoch: 19, Batch: 1, Train Loss: 0.0042, Train Acc: 1.0000
# Epoch: 19, Batch: 2, Train Loss: 0.0055, Train Acc: 0.9961
# Epoch: 19, Batch: 3, Train Loss: 0.0208, Train Acc: 0.9948
# Epoch: 19, Batch: 4, Train Loss: 0.0159, Train Acc: 0.9961
# Epoch: 19, Batch: 5, Train Loss: 0.0127, Train Acc: 0.9969
# Epoch: 19, Batch: 6, Train Loss: 0.0106, Train Acc: 0.9974
# Epoch: 19, Batch: 7, Train Loss: 0.0099, Train Acc: 0.9978
# Epoch: 19, Batch: 8, Train Loss: 0.0087, Train Acc: 0.9980
# Epoch: 19, Batch: 9, Train Loss: 0.0078, Train Acc: 0.9983
# Epoch: 19, Batch: 10, Train Loss: 0.0072, Train Acc: 0.9984
# Epoch: 19, Batch: 11, Train Loss: 0.0066, Train Acc: 0.9986
# Epoch: 19, Batch: 12, Train Loss: 0.0061, Train Acc: 0.9987
# Epoch: 19, Batch: 13, Train Loss: 0.0056, Train Acc: 0.9988
# Epoch: 19, Batch: 14, Train Loss: 0.0055, Train Acc: 0.9989
# Epoch: 19, Batch: 15, Train Loss: 0.0053, Train Acc: 0.9990
# Epoch: 19, Batch: 16, Train Loss: 0.0050, Train Acc: 0.9990
# Epoch: 19, Batch: 17, Train Loss: 0.0049, Train Acc: 0.9991
# Epoch: 19, Batch: 18, Train Loss: 0.0046, Train Acc: 0.9991
# Epoch: 19, Batch: 19, Train Loss: 0.0044, Train Acc: 0.9992
# Epoch: 19, Batch: 20, Train Loss: 0.0054, Train Acc: 0.9988
# Epoch: 19, Batch: 21, Train Loss: 0.0055, Train Acc: 0.9985
# Epoch: 19, Batch: 22, Train Loss: 0.0053, Train Acc: 0.9986
# Epoch: 19, Batch: 23, Train Loss: 0.0051, Train Acc: 0.9986
# Epoch: 19, Batch: 24, Train Loss: 0.0051, Train Acc: 0.9987
# Epoch: 19, Batch: 25, Train Loss: 0.0068, Train Acc: 0.9984
# Epoch: 19, Batch: 26, Train Loss: 0.0066, Train Acc: 0.9985
# Epoch: 19, Batch: 27, Train Loss: 0.0064, Train Acc: 0.9986
# Epoch: 19, Batch: 28, Train Loss: 0.0100, Train Acc: 0.9983
# Epoch: 19, Batch: 29, Train Loss: 0.0096, Train Acc: 0.9984
# Epoch: 19, Batch: 30, Train Loss: 0.0103, Train Acc: 0.9979
# Epoch: 19, Batch: 31, Train Loss: 0.0099, Train Acc: 0.9980
# Epoch: 19, Batch: 32, Train Loss: 0.0115, Train Acc: 0.9978
# Epoch: 19, Batch: 33, Train Loss: 0.0112, Train Acc: 0.9979
# Epoch: 19, Batch: 34, Train Loss: 0.0109, Train Acc: 0.9979
# Epoch: 19, Batch: 35, Train Loss: 0.0106, Train Acc: 0.9980
# Epoch: 19, Batch: 36, Train Loss: 0.0104, Train Acc: 0.9980
# Epoch: 19, Batch: 37, Train Loss: 0.0102, Train Acc: 0.9981
# Epoch: 19, Batch: 38, Train Loss: 0.0100, Train Acc: 0.9981
# Epoch: 19, Batch: 39, Train Loss: 0.0098, Train Acc: 0.9982
# Epoch: 19, Batch: 40, Train Loss: 0.0099, Train Acc: 0.9980
# Epoch: 19, Batch: 41, Train Loss: 0.0100, Train Acc: 0.9979
# Epoch: 19, Batch: 42, Train Loss: 0.0100, Train Acc: 0.9978
# Epoch: 19, Batch: 43, Train Loss: 0.0111, Train Acc: 0.9973
# Epoch: 19, Batch: 44, Train Loss: 0.0110, Train Acc: 0.9972
# Epoch: 19, Batch: 45, Train Loss: 0.0108, Train Acc: 0.9972
# Epoch: 19, Batch: 46, Train Loss: 0.0107, Train Acc: 0.9971
# Epoch: 19, Batch: 47, Train Loss: 0.0106, Train Acc: 0.9972
# Epoch: 19, Batch: 48, Train Loss: 0.0103, Train Acc: 0.9972
# Epoch: 19, Batch: 49, Train Loss: 0.0101, Train Acc: 0.9973
# Epoch: 19, Batch: 50, Train Loss: 0.0099, Train Acc: 0.9973
# Epoch: 19, Batch: 51, Train Loss: 0.0098, Train Acc: 0.9974
# Epoch: 19, Batch: 52, Train Loss: 0.0113, Train Acc: 0.9970
# Epoch: 19, Batch: 53, Train Loss: 0.0111, Train Acc: 0.9971
# Epoch: 19, Batch: 54, Train Loss: 0.0118, Train Acc: 0.9970
# Epoch: 19, Batch: 55, Train Loss: 0.0116, Train Acc: 0.9970
# Epoch: 19, Batch: 56, Train Loss: 0.0118, Train Acc: 0.9969
# Epoch: 19, Batch: 57, Train Loss: 0.0117, Train Acc: 0.9970
# Epoch: 19, Batch: 58, Train Loss: 0.0122, Train Acc: 0.9968
# Epoch: 19, Batch: 59, Train Loss: 0.0123, Train Acc: 0.9967
# Epoch: 19, Batch: 60, Train Loss: 0.0121, Train Acc: 0.9967
# Epoch: 19, Batch: 61, Train Loss: 0.0119, Train Acc: 0.9968
# Epoch: 19, Batch: 62, Train Loss: 0.0117, Train Acc: 0.9968
# Epoch: 19, Batch: 63, Train Loss: 0.0130, Train Acc: 0.9967
# Epoch: 19, Batch: 64, Train Loss: 0.0132, Train Acc: 0.9966
# Epoch: 19, Batch: 65, Train Loss: 0.0145, Train Acc: 0.9964
# Epoch: 19, Batch: 66, Train Loss: 0.0152, Train Acc: 0.9963
# Epoch: 19, Batch: 67, Train Loss: 0.0150, Train Acc: 0.9964
# Epoch: 19, Batch: 68, Train Loss: 0.0148, Train Acc: 0.9964
# Epoch: 19, Batch: 69, Train Loss: 0.0149, Train Acc: 0.9964
# Epoch: 19, Batch: 70, Train Loss: 0.0149, Train Acc: 0.9963
# Epoch: 19, Batch: 71, Train Loss: 0.0149, Train Acc: 0.9963
# Epoch: 19, Batch: 72, Train Loss: 0.0148, Train Acc: 0.9962
# Epoch: 19, Batch: 73, Train Loss: 0.0148, Train Acc: 0.9961
# Epoch: 19, Batch: 74, Train Loss: 0.0147, Train Acc: 0.9962
# Epoch: 19, Batch: 75, Train Loss: 0.0145, Train Acc: 0.9962
# Epoch: 19, Batch: 76, Train Loss: 0.0150, Train Acc: 0.9962
# Epoch: 19, Batch: 77, Train Loss: 0.0148, Train Acc: 0.9962
# Epoch: 19, Batch: 78, Train Loss: 0.0149, Train Acc: 0.9961
# Epoch: 19, Batch: 79, Train Loss: 0.0149, Train Acc: 0.9961
# Epoch: 20, Batch: 1, Train Loss: 0.1003, Train Acc: 0.9922
# Epoch: 20, Batch: 2, Train Loss: 0.0580, Train Acc: 0.9922
# Epoch: 20, Batch: 3, Train Loss: 0.0461, Train Acc: 0.9922
# Epoch: 20, Batch: 4, Train Loss: 0.0395, Train Acc: 0.9922
# Epoch: 20, Batch: 5, Train Loss: 0.0331, Train Acc: 0.9938
# Epoch: 20, Batch: 6, Train Loss: 0.0294, Train Acc: 0.9935
# Epoch: 20, Batch: 7, Train Loss: 0.0268, Train Acc: 0.9933
# Epoch: 20, Batch: 8, Train Loss: 0.0235, Train Acc: 0.9941
# Epoch: 20, Batch: 9, Train Loss: 0.0220, Train Acc: 0.9939
# Epoch: 20, Batch: 10, Train Loss: 0.0206, Train Acc: 0.9938
# Epoch: 20, Batch: 11, Train Loss: 0.0189, Train Acc: 0.9943
# Epoch: 20, Batch: 12, Train Loss: 0.0174, Train Acc: 0.9948
# Epoch: 20, Batch: 13, Train Loss: 0.0198, Train Acc: 0.9940
# Epoch: 20, Batch: 14, Train Loss: 0.0193, Train Acc: 0.9939
# Epoch: 20, Batch: 15, Train Loss: 0.0185, Train Acc: 0.9943
# Epoch: 20, Batch: 16, Train Loss: 0.0174, Train Acc: 0.9946
# Epoch: 20, Batch: 17, Train Loss: 0.0166, Train Acc: 0.9949
# Epoch: 20, Batch: 18, Train Loss: 0.0162, Train Acc: 0.9952
# Epoch: 20, Batch: 19, Train Loss: 0.0154, Train Acc: 0.9955
# Epoch: 20, Batch: 20, Train Loss: 0.0151, Train Acc: 0.9953
# Epoch: 20, Batch: 21, Train Loss: 0.0145, Train Acc: 0.9955
# Epoch: 20, Batch: 22, Train Loss: 0.0140, Train Acc: 0.9957
# Epoch: 20, Batch: 23, Train Loss: 0.0135, Train Acc: 0.9959
# Epoch: 20, Batch: 24, Train Loss: 0.0130, Train Acc: 0.9961
# Epoch: 20, Batch: 25, Train Loss: 0.0144, Train Acc: 0.9959
# Epoch: 20, Batch: 26, Train Loss: 0.0139, Train Acc: 0.9961
# Epoch: 20, Batch: 27, Train Loss: 0.0135, Train Acc: 0.9962
# Epoch: 20, Batch: 28, Train Loss: 0.0132, Train Acc: 0.9964
# Epoch: 20, Batch: 29, Train Loss: 0.0128, Train Acc: 0.9965
# Epoch: 20, Batch: 30, Train Loss: 0.0128, Train Acc: 0.9964
# Epoch: 20, Batch: 31, Train Loss: 0.0125, Train Acc: 0.9965
# Epoch: 20, Batch: 32, Train Loss: 0.0122, Train Acc: 0.9966
# Epoch: 20, Batch: 33, Train Loss: 0.0119, Train Acc: 0.9967
# Epoch: 20, Batch: 34, Train Loss: 0.0118, Train Acc: 0.9966
# Epoch: 20, Batch: 35, Train Loss: 0.0114, Train Acc: 0.9967
# Epoch: 20, Batch: 36, Train Loss: 0.0113, Train Acc: 0.9965
# Epoch: 20, Batch: 37, Train Loss: 0.0110, Train Acc: 0.9966
# Epoch: 20, Batch: 38, Train Loss: 0.0108, Train Acc: 0.9967
# Epoch: 20, Batch: 39, Train Loss: 0.0105, Train Acc: 0.9968
# Epoch: 20, Batch: 40, Train Loss: 0.0104, Train Acc: 0.9969
# Epoch: 20, Batch: 41, Train Loss: 0.0102, Train Acc: 0.9970
# Epoch: 20, Batch: 42, Train Loss: 0.0100, Train Acc: 0.9970
# Epoch: 20, Batch: 43, Train Loss: 0.0098, Train Acc: 0.9971
# Epoch: 20, Batch: 44, Train Loss: 0.0100, Train Acc: 0.9970
# Epoch: 20, Batch: 45, Train Loss: 0.0103, Train Acc: 0.9969
# Epoch: 20, Batch: 46, Train Loss: 0.0102, Train Acc: 0.9968
# Epoch: 20, Batch: 47, Train Loss: 0.0101, Train Acc: 0.9968
# Epoch: 20, Batch: 48, Train Loss: 0.0100, Train Acc: 0.9969
# Epoch: 20, Batch: 49, Train Loss: 0.0098, Train Acc: 0.9970
# Epoch: 20, Batch: 50, Train Loss: 0.0097, Train Acc: 0.9969
# Epoch: 20, Batch: 51, Train Loss: 0.0095, Train Acc: 0.9969
# Epoch: 20, Batch: 52, Train Loss: 0.0094, Train Acc: 0.9970
# Epoch: 20, Batch: 53, Train Loss: 0.0093, Train Acc: 0.9969
# Epoch: 20, Batch: 54, Train Loss: 0.0092, Train Acc: 0.9970
# Epoch: 20, Batch: 55, Train Loss: 0.0093, Train Acc: 0.9969
# Epoch: 20, Batch: 56, Train Loss: 0.0091, Train Acc: 0.9969
# Epoch: 20, Batch: 57, Train Loss: 0.0091, Train Acc: 0.9968
# Epoch: 20, Batch: 58, Train Loss: 0.0090, Train Acc: 0.9969
# Epoch: 20, Batch: 59, Train Loss: 0.0092, Train Acc: 0.9967
# Epoch: 20, Batch: 60, Train Loss: 0.0090, Train Acc: 0.9967
# Epoch: 20, Batch: 61, Train Loss: 0.0090, Train Acc: 0.9967
# Epoch: 20, Batch: 62, Train Loss: 0.0089, Train Acc: 0.9967
# Epoch: 20, Batch: 63, Train Loss: 0.0089, Train Acc: 0.9968
# Epoch: 20, Batch: 64, Train Loss: 0.0087, Train Acc: 0.9968
# Epoch: 20, Batch: 65, Train Loss: 0.0086, Train Acc: 0.9969
# Epoch: 20, Batch: 66, Train Loss: 0.0085, Train Acc: 0.9969
# Epoch: 20, Batch: 67, Train Loss: 0.0086, Train Acc: 0.9969
# Epoch: 20, Batch: 68, Train Loss: 0.0084, Train Acc: 0.9969
# Epoch: 20, Batch: 69, Train Loss: 0.0083, Train Acc: 0.9969
# Epoch: 20, Batch: 70, Train Loss: 0.0083, Train Acc: 0.9970
# Epoch: 20, Batch: 71, Train Loss: 0.0082, Train Acc: 0.9970
# Epoch: 20, Batch: 72, Train Loss: 0.0081, Train Acc: 0.9971
# Epoch: 20, Batch: 73, Train Loss: 0.0082, Train Acc: 0.9970
# Epoch: 20, Batch: 74, Train Loss: 0.0081, Train Acc: 0.9970
# Epoch: 20, Batch: 75, Train Loss: 0.0080, Train Acc: 0.9971
# Epoch: 20, Batch: 76, Train Loss: 0.0079, Train Acc: 0.9971
# Epoch: 20, Batch: 77, Train Loss: 0.0093, Train Acc: 0.9971
# Epoch: 20, Batch: 78, Train Loss: 0.0092, Train Acc: 0.9971
# Epoch: 20, Batch: 79, Train Loss: 0.0093, Train Acc: 0.9970
# train loss 0.009, train acc 0.997, test acc 0.994

# %% [markdown]
# # transform不一样

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter

class Bottleneck(nn.Module):
    def __init__(self, in_channels, channels, stride=1, use_1x1conv=False):
        super(Bottleneck,self).__init__()
        self.conv1 = nn.Conv2d(in_channels, channels, kernel_size=1, stride=1, bias=False)
        self.bn1 = nn.BatchNorm2d(channels)
        self.conv2 = nn.Conv2d(channels, channels, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(channels)
        self.conv3 = nn.Conv2d(channels, channels*4, kernel_size=1, stride=1, bias=False)
        self.bn3 = nn.BatchNorm2d(channels*4)

        if use_1x1conv:
            self.conv4 = nn.Conv2d(
                in_channels, channels*4, kernel_size=1, stride=stride
            )
        else:
            self.conv4 = None

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))

        if  self.conv4 == None:
            identity = x
        else:
            identity = self.conv4(x)

        out += identity
        return F.relu(out)

def bottleneck_block(in_channels, channels, num_bottlenecks, stride=1):
    blk = []
    for i in range(num_bottlenecks):
        if i == 0:
            blk.append(Bottleneck(in_channels, channels, stride=stride, use_1x1conv=True))
        else:
            blk.append(Bottleneck(channels*4, channels))
    return blk

def ResNet(block, layers, num_classes=10):
   
    b1 = nn.Sequential(nn.Conv2d(1, 64, kernel_size=7, stride=2, padding=3),
                       nn.BatchNorm2d(64), nn.ReLU(),
                       nn.MaxPool2d(kernel_size=3, stride=2, padding=1))

    b2 = nn.Sequential(*bottleneck_block(64, 64, layers[0], stride=1))
    b3 = nn.Sequential(*bottleneck_block(64*4, 128, layers[1], stride=2))
    b4 = nn.Sequential(*bottleneck_block(128*4, 256, layers[2], stride=2))
    b5 = nn.Sequential(*bottleneck_block(256*4, 512, layers[3], stride=2))

    resnet = nn.Sequential(
        b1, b2, b3, b4, b5,
        nn.AdaptiveAvgPool2d((1,1)),
        nn.Flatten(),
        nn.Linear(512*4, num_classes)
    )
    return resnet

def resnet50():
    return ResNet(Bottleneck, [3, 4, 6, 3])

def resnet101():
    return ResNet(Bottleneck, [3, 4, 23, 3])



def train_loss(net, train_iter, test_iter, epochs, loss, device, lr):
    net.to(device)
    writer = SummaryWriter()  # 创建 TensorBoard writer
    def init_weights(m):
        if type(m) == nn.Linear or type(m) == nn.Conv2d:
            # nn.init.xavier_uniform(m.weight)
            nn.init.kaiming_normal_(m.weight)
    net.apply(init_weights)
    trainer = torch.optim.Adam(net.parameters(), lr=lr)
    for epoch in range(epochs):
        # 训练损失之和，训练准确率之和，样本数
        metric = d2l.Accumulator(3)
        net.train()
        timer, num_batches = d2l.Timer(), len(train_iter)
        for i, (X, y) in enumerate(train_iter):
            trainer.zero_grad()
            X, y = X.to(device), y.to(device)
            y_hat = net(X)
            l = loss(y_hat, y)
            l.backward()
            trainer.step()
            with torch.no_grad():
                metric.add(l * X.shape[0], d2l.accuracy(y_hat, y), X.shape[0])

            train_loss = metric[0] / metric[2]
            train_acc = metric[1] / metric[2]

            # 将训练损失和准确率写入 TensorBoard
            writer.add_scalar('Train/Loss', train_loss, epoch * num_batches + i)
            writer.add_scalar('Train/Accuracy', train_acc, epoch * num_batches + i)

            # 打印训练过程
            print(f'Epoch: {epoch+1}, Batch: {i+1}, Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}')

        test_acc = d2l.evaluate_accuracy_gpu(net, test_iter)
        writer.add_scalar('Test/Accuracy', test_acc, epoch)  # 将测试准确率写入 TensorBoard

        test_acc = d2l.evaluate_accuracy_gpu(net, test_iter)
        writer.add_scalar('Test/Accuracy', test_acc, epoch)  # 将测试准确率写入 TensorBoard

    print(f'train loss {train_loss:.3f}, train acc {train_acc:.3f}, test acc {test_acc:.3f}')
    torch.save(net.state_dict(), f".\\model\\ResNet-50_Dict_FashionMNIST-10_Epoch{epochs}_Accuracy{test_acc*100:.2f}%.pth")
    torch.save(net, f".\\model\\ResNet-50_FashionMNIST-10_Epoch{epochs}_Accuracy{test_acc*100:.2f}%.pth")
    writer.close()  # 关闭 TensorBoard writer
    
    
# 加载MNIST
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])




train_dataset = datasets.MNIST(
    root=r'./', train=True, transform=trans24, download=True)
test_dataset = datasets.MNIST(
    root=r'./', train=False, transform=trans24, download=True)

# 配置数据加载器
batch_size = 4096
train_loader64 = DataLoader(dataset=train_dataset,
                          batch_size=batch_size, shuffle=True)
test_loader64 = DataLoader(dataset=test_dataset,
                         batch_size=batch_size, shuffle=True)

# 开始训练
#epochs,lr = 20, 0.001
epochs, lr = 20, 0.001
device = torch.device("cuda:0")
loss = nn.CrossEntropyLoss()
resnet101 = resnet101()
train_loss(resnet101, test_loader64, test_loader64, epochs, loss, device, lr)
# tensorboard 运行
# (mytorch) PS F:\DeepLearn\resnet\runs> tensorboard --logdir=Apr10_17-45-21_NikeLee
# 其中 'Apr10_17-45-21_NikeLee'是文件夹名称
# Out:
# Epoch: 1, Batch: 1, Train Loss: 8.8769, Train Acc: 0.0935
# Epoch: 1, Batch: 2, Train Loss: 23.2924, Train Acc: 0.1036
# Epoch: 1, Batch: 3, Train Loss: 27.4031, Train Acc: 0.1396
# Epoch: 2, Batch: 1, Train Loss: 46.1325, Train Acc: 0.3682
# Epoch: 2, Batch: 2, Train Loss: 38.9593, Train Acc: 0.3694
# Epoch: 2, Batch: 3, Train Loss: 34.4975, Train Acc: 0.3877
# Epoch: 3, Batch: 1, Train Loss: 6.7529, Train Acc: 0.4521
# Epoch: 3, Batch: 2, Train Loss: 4.3963, Train Acc: 0.5599
# Epoch: 3, Batch: 3, Train Loss: 3.9440, Train Acc: 0.5803
# Epoch: 4, Batch: 1, Train Loss: 0.8972, Train Acc: 0.7622
# Epoch: 4, Batch: 2, Train Loss: 0.8061, Train Acc: 0.7819
# Epoch: 4, Batch: 3, Train Loss: 0.7590, Train Acc: 0.7928
# Epoch: 5, Batch: 1, Train Loss: 0.4295, Train Acc: 0.8740
# Epoch: 5, Batch: 2, Train Loss: 0.3979, Train Acc: 0.8820
# Epoch: 5, Batch: 3, Train Loss: 0.3834, Train Acc: 0.8853
# Epoch: 6, Batch: 1, Train Loss: 0.2877, Train Acc: 0.9092
# Epoch: 6, Batch: 2, Train Loss: 0.2658, Train Acc: 0.9143
# Epoch: 6, Batch: 3, Train Loss: 0.2585, Train Acc: 0.9171
# Epoch: 7, Batch: 1, Train Loss: 0.2101, Train Acc: 0.9312
# Epoch: 7, Batch: 2, Train Loss: 0.2000, Train Acc: 0.9347
# Epoch: 7, Batch: 3, Train Loss: 0.1937, Train Acc: 0.9362
# Epoch: 8, Batch: 1, Train Loss: 0.1691, Train Acc: 0.9470
# Epoch: 8, Batch: 2, Train Loss: 0.1565, Train Acc: 0.9517
# Epoch: 8, Batch: 3, Train Loss: 0.1519, Train Acc: 0.9533
# Epoch: 9, Batch: 1, Train Loss: 0.1394, Train Acc: 0.9546
# Epoch: 9, Batch: 2, Train Loss: 0.1215, Train Acc: 0.9614
# Epoch: 9, Batch: 3, Train Loss: 0.1177, Train Acc: 0.9628
# Epoch: 10, Batch: 1, Train Loss: 0.0940, Train Acc: 0.9680
# Epoch: 10, Batch: 2, Train Loss: 0.0873, Train Acc: 0.9718
# Epoch: 10, Batch: 3, Train Loss: 0.0861, Train Acc: 0.9723
# Epoch: 11, Batch: 1, Train Loss: 0.0606, Train Acc: 0.9822
# Epoch: 11, Batch: 2, Train Loss: 0.0595, Train Acc: 0.9816
# Epoch: 11, Batch: 3, Train Loss: 0.0597, Train Acc: 0.9811
# Epoch: 12, Batch: 1, Train Loss: 0.0397, Train Acc: 0.9912
# Epoch: 12, Batch: 2, Train Loss: 0.0402, Train Acc: 0.9900
# Epoch: 12, Batch: 3, Train Loss: 0.0393, Train Acc: 0.9900
# Epoch: 13, Batch: 1, Train Loss: 0.0284, Train Acc: 0.9932
# Epoch: 13, Batch: 2, Train Loss: 0.0261, Train Acc: 0.9944
# Epoch: 13, Batch: 3, Train Loss: 0.0263, Train Acc: 0.9941
# Epoch: 14, Batch: 1, Train Loss: 0.0153, Train Acc: 0.9971
# Epoch: 14, Batch: 2, Train Loss: 0.0159, Train Acc: 0.9967
# Epoch: 14, Batch: 3, Train Loss: 0.0159, Train Acc: 0.9966
# Epoch: 15, Batch: 1, Train Loss: 0.0112, Train Acc: 0.9985
# Epoch: 15, Batch: 2, Train Loss: 0.0102, Train Acc: 0.9990
# Epoch: 15, Batch: 3, Train Loss: 0.0099, Train Acc: 0.9990
# Epoch: 16, Batch: 1, Train Loss: 0.0063, Train Acc: 0.9995
# Epoch: 16, Batch: 2, Train Loss: 0.0061, Train Acc: 0.9998
# Epoch: 16, Batch: 3, Train Loss: 0.0062, Train Acc: 0.9997
# Epoch: 17, Batch: 1, Train Loss: 0.0042, Train Acc: 1.0000
# Epoch: 17, Batch: 2, Train Loss: 0.0038, Train Acc: 1.0000
# Epoch: 17, Batch: 3, Train Loss: 0.0039, Train Acc: 1.0000
# Epoch: 18, Batch: 1, Train Loss: 0.0021, Train Acc: 1.0000
# Epoch: 18, Batch: 2, Train Loss: 0.0023, Train Acc: 1.0000
# Epoch: 18, Batch: 3, Train Loss: 0.0022, Train Acc: 1.0000
# Epoch: 19, Batch: 1, Train Loss: 0.0018, Train Acc: 1.0000
# Epoch: 19, Batch: 2, Train Loss: 0.0017, Train Acc: 1.0000
# Epoch: 19, Batch: 3, Train Loss: 0.0016, Train Acc: 1.0000
# Epoch: 20, Batch: 1, Train Loss: 0.0012, Train Acc: 1.0000
# Epoch: 20, Batch: 2, Train Loss: 0.0011, Train Acc: 1.0000
# Epoch: 20, Batch: 3, Train Loss: 0.0011, Train Acc: 1.0000
# train loss 0.001, train acc 1.000, test acc 1.000

# %%
def count_layers(model):
    total_layers = sum(1 for _ in model.named_parameters())
    return total_layers
resnet50 = resnet101()
# 假设已经生成了 ResNet-50 模型，保存在变量 model 中
num_layers = count_layers(resnet101)
print("模型层数:", num_layers)
# Out:
# 模型层数: 311

# %%
def count_layers(model):
    total_layers = sum(1 for _ in model.named_parameters())
    return total_layers
resnet50 = resnet50()
# 假设已经生成了 ResNet-50 模型，保存在变量 model 中
num_layers = count_layers(resnet50)
print("模型层数:", num_layers)
# Out:
# 模型层数: 158

# %%
def count_residual_blocks(model):
    residual_blocks = []
    for name, module in model.named_modules():
        if isinstance(module, Bottleneck):
            residual_blocks.append(module)
    
    num_blocks = [sum(1 for _ in rb.children()) for rb in residual_blocks]
    return num_blocks
print(count_residual_blocks(resnet50))
# 假设已经生成了 ResNet-50 模型，保存在变量 model 中
len(count_residual_blocks(resnet50)),len(count_residual_blocks(resnet101))
# Out:
# [7, 6, 6, 7, 6, 6, 6, 7, 6, 6, 6, 6, 6, 7, 6, 6]
# (16, 33)

# %% [markdown]
# # CIFAR-10

# %%
from torch import optim


# 导入必要的库
def unpickle(file):
    import pickle
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict
import torch
import matplotlib.pyplot as plt
import numpy as np
from torch import nn
from torch.nn import functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from d2l import torch as d2l
from torchvision import  transforms



# 1x1 conv -> 3x3 conv -> 1x1 conv
class Bottleneck(nn.Module):
    def __init__(self, in_channels, channels, stride=1, use_1x1conv=False):
        super(Bottleneck,self).__init__()
        self.conv1 = nn.Conv2d(in_channels, channels, kernel_size=1, stride=1, bias=False)
        self.bn1 = nn.BatchNorm2d(channels)
        self.conv2 = nn.Conv2d(channels, channels, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(channels)
        self.conv3 = nn.Conv2d(channels, channels*4, kernel_size=1, stride=1, bias=False)
        self.bn3 = nn.BatchNorm2d(channels*4)

        if use_1x1conv:
            self.conv4 = nn.Conv2d(
                in_channels, channels*4, kernel_size=1, stride=stride
            )
        else:
            self.conv4 = None

    def forward(self, x):
        # 1x1 conv 通道数：in_channels -> channels
        out = F.relu(self.bn1(self.conv1(x)))
        # 3x3 conv 通道数：channels -> channels
        out = F.relu(self.bn2(self.conv2(out)))
        # 1x1 conv 通道数: channels -> 4*channels
        out = self.bn3(self.conv3(out))

        # 恒等映射 or 1x1 conv
        if  self.conv4 == None:
            identity = x
        else:
            identity = self.conv4(x)


        out += identity
        return F.relu(out)
def bottleneck_block(in_channels, channels, num_bottlenecks, not_FirstBlock = True):
    # 第一个neck使用1x1conv，剩余的neck不使用1x1conv
    # 第一个block的stride=1，后面的block的stride=2
    blk = []
    for i in range(num_bottlenecks):
        if i == 0:
            blk.append(
                Bottleneck(in_channels, channels, stride=not_FirstBlock+1, use_1x1conv=True)
            )
        else:
            blk.append(
                Bottleneck(channels*4, channels)
            )
    return blk
b1 = nn.Sequential(nn.Conv2d(3, 64, kernel_size=7, stride=2, padding=3),# 第一个参数是图片通道数 3是有色图片
                   nn.BatchNorm2d(64), nn.ReLU(),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))

b2 = nn.Sequential(*bottleneck_block(64, 64, 3, not_FirstBlock=False))
b3 = nn.Sequential(*bottleneck_block(64*4, 128, 3))
b4 = nn.Sequential(*bottleneck_block(128*4, 256, 3))
b5 = nn.Sequential(*bottleneck_block(256*4, 512, 3))
resnet18 = nn.Sequential(
    b1, b2, b3, b4, b5,
    nn.AdaptiveAvgPool2d((1,1)),
    nn.Flatten(),
    nn.Linear(2048, 10)
)

# 定义训练
from torch.utils.tensorboard import SummaryWriter
import tensorboard
def train_loss(net, train_iter, test_iter, epochs, loss, device, lr):
    # 参数初始化kaiming_uniform_
    def init_weights(m):
        if type(m) == nn.Linear or type(m) == nn.Conv2d:
            # nn.init.xavier_uniform(m.weight)
            nn.init.kaiming_normal_(m.weight)
    net.apply(init_weights)
    

    net.to(device)
    writer = SummaryWriter()  # 创建 TensorBoard writer

    trainer = torch.optim.Adam(net.parameters(), lr=lr)
    # trainer = optim.SGD(net.parameters(), lr=lr, momentum=0.9)
    for epoch in range(epochs):
        # 训练损失之和，训练准确率之和，样本数
        metric = d2l.Accumulator(3)
        net.train()
        timer, num_batches = d2l.Timer(), len(train_iter)
        for i, (X, y) in enumerate(train_iter):
            trainer.zero_grad()
            X, y = X.to(device), y.to(device)
            y_hat = net(X)
            l = loss(y_hat, y)
            l.backward()
            trainer.step()
            with torch.no_grad():
                metric.add(l * X.shape[0], d2l.accuracy(y_hat, y), X.shape[0])

            train_loss = metric[0] / metric[2]
            train_acc = metric[1] / metric[2]

            # 将训练损失和准确率写入 TensorBoard
            writer.add_scalar('Train/Loss', train_loss, epoch * num_batches + i)
            writer.add_scalar('Train/Accuracy', train_acc, epoch * num_batches + i)

            # 打印训练过程
            print(f'Epoch: {epoch+1}, Batch: {i+1}, Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}')

        test_acc = d2l.evaluate_accuracy_gpu(net, test_iter)
        writer.add_scalar('Test/Accuracy', test_acc, epoch)  # 将测试准确率写入 TensorBoard

    print(f'train loss {train_loss:.3f}, train acc {train_acc:.3f}, test acc {test_acc:.3f}')
    torch.save(net.state_dict(), f".\\model\\ResNet-50_Dict_FashionMNIST-10_Epoch{epochs}_Accuracy{test_acc*100:.2f}%.pth")
    torch.save(net, f".\\model\\ResNet-50_FashionMNIST-10_Epoch{epochs}_Accuracy{test_acc*100:.2f}%.pth")
    writer.close()  # 关闭 TensorBoard writer
    
# 加载FashionMNIST
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# 加载CIFAR-10训练数据集
train_dataset = datasets.CIFAR10(
    root='./data', 
    train=True,
    download=True,
    transform=transform
)

# 加载CIFAR-10测试数据集
test_dataset = datasets.CIFAR10(
    root='./data',
    train=False, 
    download=True,
    transform=transform
)

            # nn.init.kaiming_normal_(m.weight)
# batch_size = 4096:train loss 0.011, train acc 0.999, test acc 0.992 Adma优化器 lr =0.001
# batch_size = 4096 train loss 2.303, train acc 0.100, test acc 0.100 Adma优化器 lr =0.1
# batch_size = 4096 train loss 1.286, train acc 0.556, test acc 0.503 sgd优化器 lr =0.1
# batch_size = 4096 train loss 0.315, train acc 0.960, test acc 0.860 sgd优化器 lr =0.001

            # nn.init.xavier_uniform(m.weight)
#  batch_size = 4096 ,train loss 1.131, train acc 0.669, test acc 0.607  sgd优化器 lr =0.001  nn.init.xavier_uniform(m.weight)
# 配置数据加载器
batch_size = 4096 #
# batch_size = 128 # 
train_loader64 = DataLoader(dataset=train_dataset,
                          batch_size=batch_size, shuffle=True)
test_loader64 = DataLoader(dataset=test_dataset,
                         batch_size=batch_size, shuffle=False)

# 开始训练
epochs, lr = 20, 0.001#epochs,lr = 20, 0.001
device = torch.device("cuda:0")
loss = nn.CrossEntropyLoss()
# train_loss(net, train_iter, test_iter, num_epochs, loss, trainer, device, lr

train_loss(resnet18, test_loader64, test_loader64, epochs, loss, device, lr)

# tensorboard 运行
# (mytorch) PS F:\DeepLearn\resnet\runs> tensorboard --logdir=Apr10_17-45-21_NikeLee
# 其中 'Apr10_17-45-21_NikeLee'是文件夹名称
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch: 1, Batch: 1, Train Loss: 5.2135, Train Acc: 0.1067
# Epoch: 1, Batch: 2, Train Loss: 12.8641, Train Acc: 0.1455
# Epoch: 1, Batch: 3, Train Loss: 13.5099, Train Acc: 0.1407
# Epoch: 2, Batch: 1, Train Loss: 10.2949, Train Acc: 0.1848
# Epoch: 2, Batch: 2, Train Loss: 8.3082, Train Acc: 0.1991
# Epoch: 2, Batch: 3, Train Loss: 7.5315, Train Acc: 0.1989
# Epoch: 3, Batch: 1, Train Loss: 3.1154, Train Acc: 0.2427
# Epoch: 3, Batch: 2, Train Loss: 2.9448, Train Acc: 0.2670
# Epoch: 3, Batch: 3, Train Loss: 2.8826, Train Acc: 0.2682
# Epoch: 4, Batch: 1, Train Loss: 2.1189, Train Acc: 0.3157
# Epoch: 4, Batch: 2, Train Loss: 2.0579, Train Acc: 0.3307
# Epoch: 4, Batch: 3, Train Loss: 2.0515, Train Acc: 0.3309
# Epoch: 5, Batch: 1, Train Loss: 1.7847, Train Acc: 0.4084
# Epoch: 5, Batch: 2, Train Loss: 1.7403, Train Acc: 0.4119
# Epoch: 5, Batch: 3, Train Loss: 1.7188, Train Acc: 0.4147
# Epoch: 6, Batch: 1, Train Loss: 1.4733, Train Acc: 0.4800
# Epoch: 6, Batch: 2, Train Loss: 1.4468, Train Acc: 0.4800
# Epoch: 6, Batch: 3, Train Loss: 1.4497, Train Acc: 0.4824
# Epoch: 7, Batch: 1, Train Loss: 1.2230, Train Acc: 0.5764
# Epoch: 7, Batch: 2, Train Loss: 1.2203, Train Acc: 0.5764
# Epoch: 7, Batch: 3, Train Loss: 1.2097, Train Acc: 0.5817
# Epoch: 8, Batch: 1, Train Loss: 0.9955, Train Acc: 0.6675
# Epoch: 8, Batch: 2, Train Loss: 0.9944, Train Acc: 0.6597
# Epoch: 8, Batch: 3, Train Loss: 0.9872, Train Acc: 0.6627
# Epoch: 9, Batch: 1, Train Loss: 0.7733, Train Acc: 0.7588
# Epoch: 9, Batch: 2, Train Loss: 0.7406, Train Acc: 0.7686
# Epoch: 9, Batch: 3, Train Loss: 0.7343, Train Acc: 0.7700
# Epoch: 10, Batch: 1, Train Loss: 0.5247, Train Acc: 0.8557
# Epoch: 10, Batch: 2, Train Loss: 0.5015, Train Acc: 0.8621
# Epoch: 10, Batch: 3, Train Loss: 0.4947, Train Acc: 0.8633
# Epoch: 11, Batch: 1, Train Loss: 0.3104, Train Acc: 0.9287
# Epoch: 11, Batch: 2, Train Loss: 0.2859, Train Acc: 0.9359
# Epoch: 11, Batch: 3, Train Loss: 0.2808, Train Acc: 0.9356
# Epoch: 12, Batch: 1, Train Loss: 0.1555, Train Acc: 0.9766
# Epoch: 12, Batch: 2, Train Loss: 0.1459, Train Acc: 0.9764
# Epoch: 12, Batch: 3, Train Loss: 0.1437, Train Acc: 0.9756
# Epoch: 13, Batch: 1, Train Loss: 0.0718, Train Acc: 0.9924
# Epoch: 13, Batch: 2, Train Loss: 0.0675, Train Acc: 0.9929
# Epoch: 13, Batch: 3, Train Loss: 0.0657, Train Acc: 0.9926
# Epoch: 14, Batch: 1, Train Loss: 0.0296, Train Acc: 0.9993
# Epoch: 14, Batch: 2, Train Loss: 0.0294, Train Acc: 0.9985
# Epoch: 14, Batch: 3, Train Loss: 0.0290, Train Acc: 0.9984
# Epoch: 15, Batch: 1, Train Loss: 0.0170, Train Acc: 0.9993
# Epoch: 15, Batch: 2, Train Loss: 0.0153, Train Acc: 0.9995
# Epoch: 15, Batch: 3, Train Loss: 0.0145, Train Acc: 0.9996
# Epoch: 16, Batch: 1, Train Loss: 0.0093, Train Acc: 0.9995
# Epoch: 16, Batch: 2, Train Loss: 0.0083, Train Acc: 0.9995
# Epoch: 16, Batch: 3, Train Loss: 0.0080, Train Acc: 0.9996
# Epoch: 17, Batch: 1, Train Loss: 0.0053, Train Acc: 0.9998
# Epoch: 17, Batch: 2, Train Loss: 0.0053, Train Acc: 0.9994
# Epoch: 17, Batch: 3, Train Loss: 0.0057, Train Acc: 0.9994
# Epoch: 18, Batch: 1, Train Loss: 0.0026, Train Acc: 1.0000
# Epoch: 18, Batch: 2, Train Loss: 0.0025, Train Acc: 1.0000
# Epoch: 18, Batch: 3, Train Loss: 0.0029, Train Acc: 0.9999
# Epoch: 19, Batch: 1, Train Loss: 0.0022, Train Acc: 1.0000
# Epoch: 19, Batch: 2, Train Loss: 0.0021, Train Acc: 1.0000
# Epoch: 19, Batch: 3, Train Loss: 0.0021, Train Acc: 1.0000
# Epoch: 20, Batch: 1, Train Loss: 0.0017, Train Acc: 1.0000
# Epoch: 20, Batch: 2, Train Loss: 0.0015, Train Acc: 1.0000
# Epoch: 20, Batch: 3, Train Loss: 0.0017, Train Acc: 0.9999
# train loss 0.002, train acc 1.000, test acc 1.000

# %% [markdown]
# ## Ret50 分类 MNIST数据集

# %%
# 导入必要的库
def unpickle(file):
    import pickle
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict
import torch
import matplotlib.pyplot as plt
import numpy as np
from torch import nn
from torch.nn import functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from d2l import torch as d2l
from torchvision import  transforms


# data = unpickle('./CIFAR10/cifar-10-batches-py/test_batch')
#
# data[b'data'][0] # array([158, 159, 165, ..., 124, 129, 110], dtype=uint8)

# 定义 Ret50
# 1x1 conv -> 3x3 conv -> 1x1 conv
class Bottleneck(nn.Module):
    def __init__(self, in_channels, channels, stride=1, use_1x1conv=False):
        super(Bottleneck,self).__init__()
        self.conv1 = nn.Conv2d(in_channels, channels, kernel_size=1, stride=1, bias=False)
        self.bn1 = nn.BatchNorm2d(channels)
        self.conv2 = nn.Conv2d(channels, channels, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(channels)
        self.conv3 = nn.Conv2d(channels, channels*4, kernel_size=1, stride=1, bias=False)
        self.bn3 = nn.BatchNorm2d(channels*4)

        if use_1x1conv:
            self.conv4 = nn.Conv2d(
                in_channels, channels*4, kernel_size=1, stride=stride
            )
        else:
            self.conv4 = None

    def forward(self, x):
        # 1x1 conv 通道数：in_channels -> channels
        out = F.relu(self.bn1(self.conv1(x)))
        # 3x3 conv 通道数：channels -> channels
        out = F.relu(self.bn2(self.conv2(out)))
        # 1x1 conv 通道数: channels -> 4*channels
        out = self.bn3(self.conv3(out))

        # 恒等映射 or 1x1 conv
        if  self.conv4 == None:
            identity = x
        else:
            identity = self.conv4(x)


        out += identity
        return F.relu(out)
def bottleneck_block(in_channels, channels, num_bottlenecks, not_FirstBlock = True):
    # 第一个neck使用1x1conv，剩余的neck不使用1x1conv
    # 第一个block的stride=1，后面的block的stride=2
    blk = []
    for i in range(num_bottlenecks):
        if i == 0:
            blk.append(
                Bottleneck(in_channels, channels, stride=not_FirstBlock+1, use_1x1conv=True)
            )
        else:
            blk.append(
                Bottleneck(channels*4, channels)
            )
    return blk
b1 = nn.Sequential(nn.Conv2d(1, 64, kernel_size=7, stride=2, padding=3),
                   nn.BatchNorm2d(64), nn.ReLU(),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))

b2 = nn.Sequential(*bottleneck_block(64, 64, 3, not_FirstBlock=False))
b3 = nn.Sequential(*bottleneck_block(64*4, 128, 3))
b4 = nn.Sequential(*bottleneck_block(128*4, 256, 3))
b5 = nn.Sequential(*bottleneck_block(256*4, 512, 3))
ret50 = nn.Sequential(
    b1, b2, b3, b4, b5,
    nn.AdaptiveAvgPool2d((1,1)),
    nn.Flatten(),
    nn.Linear(2048, 10)
)

# 定义训练
from torch.utils.tensorboard import SummaryWriter
import tensorboard
def train_loss(net, train_iter, test_iter, epochs, loss, device, lr):
    # 参数初始化
    def init_weights(m):
        if type(m) == nn.Linear or type(m) == nn.Conv2d:
            nn.init.kaiming_uniform_(m.weight)
    net.apply(init_weights)

    net.to(device)
    writer = SummaryWriter()  # 创建 TensorBoard writer

    trainer = torch.optim.Adam(net.parameters(), lr=lr)

    for epoch in range(epochs):
        # 训练损失之和，训练准确率之和，样本数
        metric = d2l.Accumulator(3)
        net.train()
        timer, num_batches = d2l.Timer(), len(train_iter)
        for i, (X, y) in enumerate(train_iter):
            trainer.zero_grad()
            X, y = X.to(device), y.to(device)
            y_hat = net(X)
            l = loss(y_hat, y)
            l.backward()
            trainer.step()
            with torch.no_grad():
                metric.add(l * X.shape[0], d2l.accuracy(y_hat, y), X.shape[0])

            train_loss = metric[0] / metric[2]
            train_acc = metric[1] / metric[2]

            # 将训练损失和准确率写入 TensorBoard
            writer.add_scalar('Train/Loss', train_loss, epoch * num_batches + i)
            writer.add_scalar('Train/Accuracy', train_acc, epoch * num_batches + i)

            # 打印训练过程
            print(f'Epoch: {epoch+1}, Batch: {i+1}, Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}')

        test_acc = d2l.evaluate_accuracy_gpu(net, test_iter)
        writer.add_scalar('Test/Accuracy', test_acc, epoch)  # 将测试准确率写入 TensorBoard

    print(f'train loss {train_loss:.3f}, train acc {train_acc:.3f}, test acc {test_acc:.3f}')
    torch.save(net.state_dict(), f".\\model\\ResNet-50_Dict_MNIST-10_Epoch{epochs}_Accuracy{test_acc*100:.2f}%.pth")
    torch.save(net, f".\\model\\ResNet-50_MNIST-10_Epoch{epochs}_Accuracy{test_acc*100:.2f}%.pth")
    writer.close()  # 关闭 TensorBoard writer
    
# 加载FashionMNIST
trans24 = transforms.Compose(
    [transforms.ToTensor()])#28*28
train_dataset = datasets.MNIST(
    root=r'./', train=True, transform=trans24, download=True)
test_dataset = datasets.MNIST(
    root=r'./', train=False, transform=trans24, download=True)

# 配置数据加载器
batch_size = 4096
train_loader64 = DataLoader(dataset=train_dataset,
                          batch_size=batch_size, shuffle=True)
test_loader64 = DataLoader(dataset=test_dataset,
                         batch_size=batch_size, shuffle=True)

# 开始训练
epochs, lr = 20, 0.001#epochs,lr = 20, 0.001
device = torch.device("cuda:0")
loss = nn.CrossEntropyLoss()
# train_loss(net, train_iter, test_iter, num_epochs, loss, trainer, device, lr
train_loss_LAMB(ret50, test_loader64, test_loader64, epochs, loss, device, lr)

# tensorboard 运行
# (mytorch) PS F:\DeepLearn\resnet\runs> tensorboard --logdir=Apr10_17-45-21_NikeLee
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 155
#     153 loss = nn.CrossEntropyLoss()
#     154 # train_loss(net, train_iter, test_iter, num_epochs, loss, trainer, device, lr
# --> 155 train_loss_LAMB(ret50, test_loader64, test_loader64, epochs, loss, device, lr)
#
# Cell In[6], line 15, in train_loss_LAMB(net, train_iter, test_iter, epochs, loss, device, lr)
#      12 net.to(device)
#      13 writer = SummaryWriter()  # 创建 TensorBoard writer
# ---> 15 trainer = FusedLAMB(net.parameters(), lr=lr)  # 使用 LAMB 优化器
#      16 # trainer = torch.optim.Adam(net.parameters(), lr=lr)
#      17 for epoch in range(epochs):
#      18     # 训练损失之和，训练准确率之和，样本数
#
# File C:\ProgramData\anaconda3\envs\mytorch\lib\site-packages\apex-0.1-py3.8.egg\apex\optimizers\fused_lamb.py:82, in FusedLAMB.__init__(self, params, lr, bias_correction, betas, eps, weight_decay, amsgrad, adam_w_mode, grad_averaging, set_grad_none, max_grad_norm, use_nvlamb)
#      80     self.multi_tensor_lamb = amp_C.multi_tensor_lamb
#      81 else:
# ---> 82     raise RuntimeError('apex.optimizers.FusedLAMB requires cuda extensions')
#      84 self.adam_w_mode = 1 if adam_w_mode else 0
#      85 self.set_grad_none = set_grad_none
#
# RuntimeError: apex.optimizers.FusedLAMB requires cuda extensions

# %% [markdown]
# ## 可视化展示

# %%
from torch import nn
import torch
import matplotlib.pyplot as plt
import numpy as np
from torch import nn
from torch.nn import functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from d2l import torch as d2l
from torchvision import  transforms

text_labels = ['t-shirt', 'trouser', 'pullover', 'dress', 'coat',
               'sandal', 'shirt', 'sneaker', 'bag', 'ankle boot']
loss_func = nn.CrossEntropyLoss()
model = torch.load("F:\\DeepLearn\\resnet\model\\ResNet-50_FashionMNIST-10_Epoch20_Accuracy100.00%.pth")

# 优化器
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

costs = []

# 测试网络
def test():
    correct = 0
    total = 0
    with torch.no_grad():
        for data in test_loader64:
            inputs, labels = data
            if torch.cuda.is_available():
                inputs = inputs.cuda()
                labels = labels.cuda()
            output = model(inputs)
            _, predicted = torch.max(output, dim=1)
            total += labels.size(0)
            correct += (predicted == labels).sum()
    print(f'测试集上的准确率为:{correct / total * 100:.3f}%')


for epoch in range(epochs):
    test()
    # 绘制图片:此时的costs里面的数据是tensor类型,如果是gpu上跑的就是cuda,需要将他转换成array
    print(costs)
if torch.cuda.is_available():
    costs = [cost.cpu().detach().numpy() for cost in costs]
    print(costs)
    plt.plot(costs)
    plt.xlabel('number of iteration')
    plt.ylabel('loss')
    plt.title('Inception Net')
    plt.show()
else:
    costs = [cost.numpy() for cost in costs]
    print(costs)
    plt.plot(costs)
    plt.xlabel('number of iteration')
    plt.ylabel('loss')
    plt.title('Inception Net')
    plt.show()
# Out:
# 测试集上的准确率为:11.780%
# []
# 测试集上的准确率为:11.780%
# []
# 测试集上的准确率为:11.780%
# []
# 测试集上的准确率为:11.780%
# []
# 测试集上的准确率为:11.780%
# []
# 测试集上的准确率为:11.780%
# []
# 测试集上的准确率为:11.780%
# []
# 测试集上的准确率为:11.780%
# []
# 测试集上的准确率为:11.780%
# []
# 测试集上的准确率为:11.780%
# []
# 测试集上的准确率为:11.780%
# []
# 测试集上的准确率为:11.780%
# []
# 测试集上的准确率为:11.780%
# []
# 测试集上的准确率为:11.780%
# []
# 测试集上的准确率为:11.780%
# []
# 测试集上的准确率为:11.780%
# []
# 测试集上的准确率为:11.780%
# []
# 测试集上的准确率为:11.780%
# []
# 测试集上的准确率为:11.780%
# []
# 测试集上的准确率为:11.780%
# []
# []

# %%
# 清理内存
import torch
 

 
# ... 模型训练代码 ...
 
# 清理模型和优化器占用的内存
del ret50

 
# 清理PyTorch缓存
torch.cuda.empty_cache()

# %%
# 重启Jupyter内核
# %reset -f

# %% [markdown]
# ## 定义 ResNet-18 网络结构

# %%
class Residual(nn.Module):
    # 残差块
    def __init__(self, input_channels, num_channels,
                 use_1x1conv=False, strides=1):
        super().__init__()
        self.conv1 = nn.Conv2d(input_channels, num_channels,
                               kernel_size=3, padding=1, stride=strides)
        self.conv2 = nn.Conv2d(num_channels, num_channels,
                               kernel_size=3, padding=1)
        if use_1x1conv:
            self.conv3 = nn.Conv2d(input_channels, num_channels,
                                   kernel_size=1, stride=strides)
        else:
            self.conv3 = None
        self.bn1 = nn.BatchNorm2d(num_channels)
        self.bn2 = nn.BatchNorm2d(num_channels)

    def forward(self, X):
        Y = F.relu(self.bn1(self.conv1(X)))
        Y = self.bn2(self.conv2(Y))
        if self.conv3:
            X = self.conv3(X)
        Y += X
        return F.relu(Y)


# ResNet-18
b1 = nn.Sequential(nn.Conv2d(1, 64, kernel_size=7, stride=2, padding=3),
                   nn.BatchNorm2d(64), nn.ReLU(),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))


def resnet_block(input_channels, num_channels, num_residuals,
                 first_block=False):
    blk = []
    for i in range(num_residuals):
        if i == 0 and not first_block:
            blk.append(Residual(input_channels, num_channels,
                                use_1x1conv=True, strides=2))
        else:
            blk.append(Residual(num_channels, num_channels))
    return blk


b2 = nn.Sequential(*resnet_block(64, 64, 2, first_block=True))
b3 = nn.Sequential(*resnet_block(64, 128, 2))
b4 = nn.Sequential(*resnet_block(128, 256, 2))
b5 = nn.Sequential(*resnet_block(256, 512, 2))

net = nn.Sequential(b1, b2, b3, b4, b5,                     #Squential是个有序的容器，网络层将按照传入该容器的顺序依次加入，用[]来访问任意一层
                    nn.AdaptiveAvgPool2d((1, 1)),
                    nn.Flatten(), nn.Linear(512, 10))

# %%
# 下载并配置数据集
trans64 = transforms.Compose(
    [transforms.Resize((224,224)), transforms.ToTensor()])#和d2l不同 重塑为224
train_dataset64 = datasets.MNIST(
    root=r'./', train=True, transform=trans64, download=True)
test_dataset64 = datasets.MNIST(
    root=r'./', train=False, transform=trans64, download=True)

# 配置数据加载器
batch_size = 4096
train_loader64 = DataLoader(dataset=train_dataset64,
                          batch_size=batch_size, shuffle=True)
test_loader64 = DataLoader(dataset=test_dataset64,
                         batch_size=batch_size, shuffle=True)

# %% [markdown]
# ## 使用28*28像素 进行训练分类

# %%
trans24 = transforms.Compose(
    [transforms.ToTensor()])#28*28
train_dataset = datasets.FashionMNIST(
    root=r'./', train=True, transform=trans24, download=True)
test_dataset = datasets.MNIST(
    root=r'./', train=False, transform=trans24, download=True)

# 配置数据加载器
batch_size = 4096
train_loader4096 = DataLoader(dataset=train_dataset,
                          batch_size=batch_size, shuffle=True)
test_loader4096 = DataLoader(dataset=test_dataset,
                         batch_size=batch_size, shuffle=True)

# %% [markdown]
# ## 训练完成后会保存模型，可以修改模型的保存路径。
#
# # 保存和加载整个模型
# torch.save(net, 'net.pth')
# model = torch.load('net.pth')
#
# # 将my_resnet模型储存为my_resnet.pth
# torch.save(net.state_dict(), "net_parameter.pth")
# # 加载resnet，模型存放在my_resnet.pth
# net.load_state_dict(torch.load("net_parameter.pth"))

# %%
test_dataset
# Out:
# Dataset MNIST
#     Number of datapoints: 10000
#     Root location: ./
#     Split: Test
#     StandardTransform
# Transform: Compose(
#                Resize(size=(224, 224), interpolation=bilinear, max_size=None, antialias=True)
#                ToTensor()
#            )

# %%
from torch.utils.tensorboard import SummaryWriter
import tensorboard
def train_loss(net, train_iter, test_iter, epochs, loss, device, lr):
    # 参数初始化
    def init_weights(m):
        if type(m) == nn.Linear or type(m) == nn.Conv2d:
            nn.init.kaiming_uniform_(m.weight)
    net.apply(init_weights)

    net.to(device)
    writer = SummaryWriter()  # 创建 TensorBoard writer

    trainer = torch.optim.Adam(net.parameters(), lr=lr)

    for epoch in range(epochs):
        # 训练损失之和，训练准确率之和，样本数
        metric = d2l.Accumulator(3)
        net.train()
        timer, num_batches = d2l.Timer(), len(train_iter)
        for i, (X, y) in enumerate(train_iter):
            trainer.zero_grad()
            X, y = X.to(device), y.to(device)
            y_hat = net(X)
            l = loss(y_hat, y)
            l.backward()
            trainer.step()
            with torch.no_grad():
                metric.add(l * X.shape[0], d2l.accuracy(y_hat, y), X.shape[0])

            train_loss = metric[0] / metric[2]
            train_acc = metric[1] / metric[2]

            # 将训练损失和准确率写入 TensorBoard
            writer.add_scalar('Train/Loss', train_loss, epoch * num_batches + i)
            writer.add_scalar('Train/Accuracy', train_acc, epoch * num_batches + i)

            # 打印训练过程
            print(f'Epoch: {epoch+1}, Batch: {i+1}, Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}')

        test_acc = d2l.evaluate_accuracy_gpu(net, test_iter)
        writer.add_scalar('Test/Accuracy', test_acc, epoch)  # 将测试准确率写入 TensorBoard

    print(f'train loss {train_loss:.3f}, train acc {train_acc:.3f}, test acc {test_acc:.3f}')
    torch.save(net.state_dict(), f".\\model\\ResNet-18_CIFAR-10_Epoch{epochs}_Accuracy{test_acc*100:.2f}%.pth")
    torch.save(net, f".\\model\\net_CIFAR-10_Epoch{epochs}_Accuracy{test_acc*100:.2f}%.pth")
    writer.close()  # 关闭 TensorBoard writer

# %% [markdown]
# # 使用LAMB 优化器:

# %%
from torch.utils.tensorboard import SummaryWriter
import tensorboard
from apex.optimizers import FusedLAMB

def train_loss_LAMB(net, train_iter, test_iter, epochs, loss, device, lr):
    # 参数初始化
    def init_weights(m):
        if type(m) == nn.Linear or type(m) == nn.Conv2d:
            nn.init.kaiming_uniform_(m.weight)
    net.apply(init_weights)

    net.to(device)
    writer = SummaryWriter()  # 创建 TensorBoard writer

    trainer = FusedLAMB(net.parameters(), lr=lr)  # 使用 LAMB 优化器
    # trainer = torch.optim.Adam(net.parameters(), lr=lr)
    for epoch in range(epochs):
        # 训练损失之和，训练准确率之和，样本数
        metric = d2l.Accumulator(3)
        net.train()
        timer, num_batches = d2l.Timer(), len(train_iter)
        for i, (X, y) in enumerate(train_iter):
            trainer.zero_grad()
            X, y = X.to(device), y.to(device)
            y_hat = net(X)
            l = loss(y_hat, y)
            l.backward()
            trainer.step()
            with torch.no_grad():
                metric.add(l * X.shape[0], d2l.accuracy(y_hat, y), X.shape[0])

            train_loss = metric[0] / metric[2]
            train_acc = metric[1] / metric[2]

            # 将训练损失和准确率写入 TensorBoard
            writer.add_scalar('Train/Loss', train_loss, epoch * num_batches + i)
            writer.add_scalar('Train/Accuracy', train_acc, epoch * num_batches + i)

            # 打印训练过程
            print(f'Epoch: {epoch+1}, Batch: {i+1}, Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}')

        test_acc = d2l.evaluate_accuracy_gpu(net, test_iter)
        writer.add_scalar('Test/Accuracy', test_acc, epoch)  # 将测试准确率写入 TensorBoard

    print(f'train loss {train_loss:.3f}, train acc {train_acc:.3f}, test acc {test_acc:.3f}')
    torch.save(net.state_dict(), f".\\model\\ResNet-18_CIFAR-10_Epoch{epochs}_Accuracy{test_acc*100:.2f}%.pth")
    torch.save(net, f".\\model\\net_CIFAR-10_Epoch{epochs}_Accuracy{test_acc*100:.2f}%.pth")
    writer.close()  # 关闭 TensorBoard writer

# %%
# # def train(net, train_iter, test_iter, epochs,scheduler=None, device):
# lr = 0.0001
# 
# # device = d2l.try_gpu()
# 
# def train_loss(net, train_iter, test_iter, epochs, loss,  device, lr):
# # 参数初始化1
#     def init_weights(m):
#         if type(m) == nn.Linear or type(m) == nn.Conv2d:
#             # nn.init.xavier_uniform_(m.weight )#80.87%
#             nn.init.kaiming_uniform_(m.weight)
#     net.apply(init_weights)
# 
#     # net.load_state_dict(torch.load("./resnet18-f37072fd.pth"),strict=False)
# 
# 
#     net.to(device)#.to(device) 可以指定CPU 或者GPU
#     animator = d2l.Animator(xlabel='epoch', xlim=[0, epochs],#画出loos新添加画图工具
#                             legend=['train loss', 'train acc', 'test acc'])
# 
#     trainer = torch.optim.Adam(net.parameters(), lr=lr)
# 
# 
#     for epoch in range(epochs):
#         # 训练损失之和，训练准确率之和，样本数
#         metric = d2l.Accumulator(3)
#         net.train()#在使用 pytorch 构建神经网络的时候，训练过程中会在程序上方添加一句model.train()，作用是 启用 batch normalization 和 dropout 。
#         timer, num_batches = d2l.Timer(), len(train_iter)
#         for i, (X, y) in enumerate(train_iter):
# 
#             trainer.zero_grad()
#             X, y = X.to(device), y.to(device)
#             y_hat = net(X)
#             l = loss(y_hat, y)
#             l.backward()
#             trainer.step()
#             with torch.no_grad():
#                 metric.add(l * X.shape[0], d2l.accuracy(y_hat, y), X.shape[0])
# 
#             train_loss = metric[0] / metric[2]
#             train_acc = metric[1] / metric[2]
#             # 画出loos新添加
#             if (i + 1) % 50 == 0:
#                 animator.add(epoch + i / len(train_iter),
#                              (train_loss, train_acc, None))
# 
#             if (i + 1) % (num_batches // 30) == 0 or i == num_batches - 1:
#                 print(f'Epoch: {epoch+1}, Step: {i+1}, Loss: {train_loss:.4f}')
# 
#         test_acc = d2l.evaluate_accuracy_gpu(net, test_iter)
#         animator.add(epoch+1, (None, None, test_acc))#画出loos新添加
# 
#         #新添加 学习率调度器 多因子调度器
# 
# 
#     print(f'train loss {train_loss:.3f}, train acc {train_acc:.3f}, '
#           f'test acc {test_acc:.3f}')
#     torch.save(net.state_dict(),
#                f".\\model\\ResNet-18_CIFAR-10_Epoch{epochs}_Accuracy{test_acc*100:.2f}%.pth")
#     torch.save(net,f".\\model\\net_CIFAR-10_Epoch{epochs}_Accuracy{test_acc*100:.2f}%.pth")

# %%
def train(net, train_iter, test_iter, epochs, lr, device):
    def init_weights(m):
        if type(m) == nn.Linear or type(m) == nn.Conv2d:
            # nn.init.xavier_uniform_(m.weight )#80.87%d2l使用的
            nn.init.kaiming_uniform_(m.weight)
    net.apply(init_weights)

    print(f'Training on:[{device}]')
    net.to(device)#.to(device) 可以指定CPU 或者GPU
    optimizer = torch.optim.Adam(net.parameters(), lr=lr)
    loss = nn.CrossEntropyLoss()
    timer, num_batches = d2l.Timer(), len(train_iter)


    for epoch in range(epochs):
        # 训练损失之和，训练准确率之和，样本数
        metric = d2l.Accumulator(3)
        net.train()#在使用 pytorch 构建神经网络的时候，训练过程中会在程序上方添加一句model.train()，作用是 启用 batch normalization 和 dropout 。
        for i, (X, y) in enumerate(train_iter):
            timer.start()
            optimizer.zero_grad()
            X, y = X.to(device), y.to(device)
            y_hat = net(X)
            l = loss(y_hat, y)
            l.backward()
            optimizer.step()
            with torch.no_grad():
                metric.add(l * X.shape[0], d2l.accuracy(y_hat, y), X.shape[0])
            timer.stop()
            train_l = metric[0] / metric[2]
            train_acc = metric[1] / metric[2]
          
           

            if (i + 1) % (num_batches // 30) == 0 or i == num_batches - 1:
                print(f'Epoch: {epoch+1}, Step: {i+1}, Loss: {train_l:.4f}')
        test_acc = d2l.evaluate_accuracy_gpu(net, test_iter)
        print(            f'Train Accuracy: {train_acc*100:.2f}%, Test Accuracy: {test_acc*100:.2f}%')
    print(f'{metric[2] * epochs / timer.sum():.1f} examples/sec '
          f'on: [{str(device)}]')

# %% [markdown]
# 训练模型（或加载模型）
# 如果环境正确配置了 CUDA，则会由 GPU 进行训练。
# 加载模型需要根据自身情况修改路径

# %% [markdown]
# ## 在Pytorch中构建好一个模型后，一般需要进行预训练权重中加载。torch.load_state_dict()函数就是用于将预训练的参数权重加载到新的模型之中，操作方式如下所示：
# # sd_net = torchvision.models.resnte50(pretrained=False)
# # sd_net.load_state_dict(torch.load('*.pth'), strict=True)
# 在本博文中重点关注的是 属性 strict; 当strict=True,要求预训练权重层数的键值与新构建的模型中的权重层数名称完全吻合；如果新构建的模型在层数上进行了部分微调，则上述代码就会报错：说key对应不上。
#
# 此时，如果我们采用strict=False 就能够完美的解决这个问题。也即，与训练权重中与新构建网络中匹配层的键值就进行使用，没有的就默认初始化。

# %% [markdown]
# ### train_loader64是MNISTtrain_loader4096 是FashionMnist数据集

# %% [markdown]
# ret18

# %%
epochs, lr = 10, 0.001#epochs,lr = 20, 0.001
device = torch.device("cuda:0")
train(net, train_loader64, test_loader64, epochs, lr, device)
# Out:
# Training on:[cuda:0]
# Epoch: 1, Step: 31, Loss: 1.0478
# Epoch: 1, Step: 62, Loss: 0.6605
# Epoch: 1, Step: 93, Loss: 0.5033
# Epoch: 1, Step: 124, Loss: 0.4132
# Epoch: 1, Step: 155, Loss: 0.3553
# Epoch: 1, Step: 186, Loss: 0.3153
# Epoch: 1, Step: 217, Loss: 0.2841
# Epoch: 1, Step: 248, Loss: 0.2612
# Epoch: 1, Step: 279, Loss: 0.2413
# Epoch: 1, Step: 310, Loss: 0.2263
# Epoch: 1, Step: 341, Loss: 0.2143
# Epoch: 1, Step: 372, Loss: 0.2038
# Epoch: 1, Step: 403, Loss: 0.1931
# Epoch: 1, Step: 434, Loss: 0.1848
# Epoch: 1, Step: 465, Loss: 0.1769
# Epoch: 1, Step: 496, Loss: 0.1715
# Epoch: 1, Step: 527, Loss: 0.1670
# Epoch: 1, Step: 558, Loss: 0.1614
# Epoch: 1, Step: 589, Loss: 0.1565
# Epoch: 1, Step: 620, Loss: 0.1510
# Epoch: 1, Step: 651, Loss: 0.1451
# Epoch: 1, Step: 682, Loss: 0.1414
# Epoch: 1, Step: 713, Loss: 0.1381
# Epoch: 1, Step: 744, Loss: 0.1348
# Epoch: 1, Step: 775, Loss: 0.1312
# Epoch: 1, Step: 806, Loss: 0.1283
# Epoch: 1, Step: 837, Loss: 0.1254
# Epoch: 1, Step: 868, Loss: 0.1231
# Epoch: 1, Step: 899, Loss: 0.1208
# Epoch: 1, Step: 930, Loss: 0.1187
# Epoch: 1, Step: 938, Loss: 0.1181
# Train Accuracy: 96.42%, Test Accuracy: 98.20%
# Epoch: 2, Step: 31, Loss: 0.0533
# Epoch: 2, Step: 62, Loss: 0.0428
# Epoch: 2, Step: 93, Loss: 0.0415
# Epoch: 2, Step: 124, Loss: 0.0407
# Epoch: 2, Step: 155, Loss: 0.0392
# Epoch: 2, Step: 186, Loss: 0.0379
# Epoch: 2, Step: 217, Loss: 0.0387
# Epoch: 2, Step: 248, Loss: 0.0390
# Epoch: 2, Step: 279, Loss: 0.0421
# Epoch: 2, Step: 310, Loss: 0.0410
# Epoch: 2, Step: 341, Loss: 0.0406
# Epoch: 2, Step: 372, Loss: 0.0409
# Epoch: 2, Step: 403, Loss: 0.0407
# Epoch: 2, Step: 434, Loss: 0.0407
# Epoch: 2, Step: 465, Loss: 0.0409
# Epoch: 2, Step: 496, Loss: 0.0411
# Epoch: 2, Step: 527, Loss: 0.0412
# Epoch: 2, Step: 558, Loss: 0.0402
# Epoch: 2, Step: 589, Loss: 0.0411
# Epoch: 2, Step: 620, Loss: 0.0414
# Epoch: 2, Step: 651, Loss: 0.0409
# Epoch: 2, Step: 682, Loss: 0.0410
# Epoch: 2, Step: 713, Loss: 0.0407
# Epoch: 2, Step: 744, Loss: 0.0403
# Epoch: 2, Step: 775, Loss: 0.0401
# Epoch: 2, Step: 806, Loss: 0.0408
# Epoch: 2, Step: 837, Loss: 0.0404
# Epoch: 2, Step: 868, Loss: 0.0403
# Epoch: 2, Step: 899, Loss: 0.0404
# Epoch: 2, Step: 930, Loss: 0.0401
# Epoch: 2, Step: 938, Loss: 0.0400
# Train Accuracy: 98.73%, Test Accuracy: 99.12%
# Epoch: 3, Step: 31, Loss: 0.0293
# Epoch: 3, Step: 62, Loss: 0.0268
# Epoch: 3, Step: 93, Loss: 0.0348
# Epoch: 3, Step: 124, Loss: 0.0324
# Epoch: 3, Step: 155, Loss: 0.0297
# Epoch: 3, Step: 186, Loss: 0.0287
# Epoch: 3, Step: 217, Loss: 0.0281
# Epoch: 3, Step: 248, Loss: 0.0292
# Epoch: 3, Step: 279, Loss: 0.0305
# Epoch: 3, Step: 310, Loss: 0.0313
# Epoch: 3, Step: 341, Loss: 0.0311
# Epoch: 3, Step: 372, Loss: 0.0312
# Epoch: 3, Step: 403, Loss: 0.0310
# Epoch: 3, Step: 434, Loss: 0.0314
# Epoch: 3, Step: 465, Loss: 0.0316
# Epoch: 3, Step: 496, Loss: 0.0325
# Epoch: 3, Step: 527, Loss: 0.0321
# Epoch: 3, Step: 558, Loss: 0.0322
# Epoch: 3, Step: 589, Loss: 0.0314
# Epoch: 3, Step: 620, Loss: 0.0314
# Epoch: 3, Step: 651, Loss: 0.0317
# Epoch: 3, Step: 682, Loss: 0.0315
# Epoch: 3, Step: 713, Loss: 0.0316
# Epoch: 3, Step: 744, Loss: 0.0321
# Epoch: 3, Step: 775, Loss: 0.0319
# Epoch: 3, Step: 806, Loss: 0.0319
# Epoch: 3, Step: 837, Loss: 0.0317
# Epoch: 3, Step: 868, Loss: 0.0320
# Epoch: 3, Step: 899, Loss: 0.0316
# Epoch: 3, Step: 930, Loss: 0.0319
# Epoch: 3, Step: 938, Loss: 0.0318
# Train Accuracy: 99.02%, Test Accuracy: 98.11%
# Epoch: 4, Step: 31, Loss: 0.0262
# Epoch: 4, Step: 62, Loss: 0.0223
# Epoch: 4, Step: 93, Loss: 0.0208
# Epoch: 4, Step: 124, Loss: 0.0212
# Epoch: 4, Step: 155, Loss: 0.0210
# Epoch: 4, Step: 186, Loss: 0.0209
# Epoch: 4, Step: 217, Loss: 0.0202
# Epoch: 4, Step: 248, Loss: 0.0209
# Epoch: 4, Step: 279, Loss: 0.0220
# Epoch: 4, Step: 310, Loss: 0.0227
# Epoch: 4, Step: 341, Loss: 0.0229
# Epoch: 4, Step: 372, Loss: 0.0224
# Epoch: 4, Step: 403, Loss: 0.0227
# Epoch: 4, Step: 434, Loss: 0.0223
# Epoch: 4, Step: 465, Loss: 0.0216
# Epoch: 4, Step: 496, Loss: 0.0219
# Epoch: 4, Step: 527, Loss: 0.0219
# Epoch: 4, Step: 558, Loss: 0.0226
# Epoch: 4, Step: 589, Loss: 0.0233
# Epoch: 4, Step: 620, Loss: 0.0236
# Epoch: 4, Step: 651, Loss: 0.0238
# Epoch: 4, Step: 682, Loss: 0.0243
# Epoch: 4, Step: 713, Loss: 0.0244
# Epoch: 4, Step: 744, Loss: 0.0242
# Epoch: 4, Step: 775, Loss: 0.0241
# Epoch: 4, Step: 806, Loss: 0.0241
# Epoch: 4, Step: 837, Loss: 0.0244
# Epoch: 4, Step: 868, Loss: 0.0244
# Epoch: 4, Step: 899, Loss: 0.0245
# Epoch: 4, Step: 930, Loss: 0.0247
# Epoch: 4, Step: 938, Loss: 0.0249
# Train Accuracy: 99.25%, Test Accuracy: 99.11%
# Epoch: 5, Step: 31, Loss: 0.0283
# Epoch: 5, Step: 62, Loss: 0.0248
# Epoch: 5, Step: 93, Loss: 0.0251
# Epoch: 5, Step: 124, Loss: 0.0260
# Epoch: 5, Step: 155, Loss: 0.0254
# Epoch: 5, Step: 186, Loss: 0.0238
# Epoch: 5, Step: 217, Loss: 0.0246
# Epoch: 5, Step: 248, Loss: 0.0233
# Epoch: 5, Step: 279, Loss: 0.0237
# Epoch: 5, Step: 310, Loss: 0.0232
# Epoch: 5, Step: 341, Loss: 0.0228
# Epoch: 5, Step: 372, Loss: 0.0228
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 3
#       1 epochs, lr = 10, 0.001#epochs,lr = 20, 0.001
#       2 device = torch.device("cuda:0")
# ----> 3 train(net, train_loader, test_loader, epochs, lr, device)
#
# Cell In[24], line 31, in train(net, train_iter, test_iter, epochs, lr, device)
#      29 optimizer.step()
#      30 with torch.no_grad():
# ---> 31     metric.add(l * X.shape[0], d2l.accuracy(y_hat, y), X.shape[0])
#      32 timer.stop()
#      33 train_l = metric[0] / metric[2]
#
# File C:\ProgramData\anaconda3\envs\mytorch\Lib\site-packages\d2l\torch.py:3195, in accuracy(y_hat, y)
#    3193     y_hat = d2l.argmax(y_hat, axis=1)
#    3194 cmp = d2l.astype(y_hat, y.dtype) == y
# -> 3195 return float(d2l.reduce_sum(d2l.astype(cmp, y.dtype)))
#
# KeyboardInterrupt:

# %% [markdown]
# ret50

# %%
epochs, lr = 10, 0.001#epochs,lr = 20, 0.001
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
train(ret50, train_loader, test_loader, epochs, lr, device)
# Out:
# Training on:[cuda]
# Epoch: 1, Step: 31, Loss: 4.4236
# Epoch: 1, Step: 62, Loss: 2.3907
# Epoch: 1, Step: 93, Loss: 1.6924
# Epoch: 1, Step: 124, Loss: 1.3206
# Epoch: 1, Step: 155, Loss: 1.0931
# Epoch: 1, Step: 186, Loss: 0.9404
# Epoch: 1, Step: 217, Loss: 0.8225
# Epoch: 1, Step: 248, Loss: 0.7367
# Epoch: 1, Step: 279, Loss: 0.6706
# Epoch: 1, Step: 310, Loss: 0.6135
# Epoch: 1, Step: 341, Loss: 0.5677
# Epoch: 1, Step: 372, Loss: 0.5307
# Epoch: 1, Step: 403, Loss: 0.4970
# Epoch: 1, Step: 434, Loss: 0.4678
# Epoch: 1, Step: 465, Loss: 0.4433
# Epoch: 1, Step: 496, Loss: 0.4200
# Epoch: 1, Step: 527, Loss: 0.3990
# Epoch: 1, Step: 558, Loss: 0.3808
# Epoch: 1, Step: 589, Loss: 0.3657
# Epoch: 1, Step: 620, Loss: 0.3508
# Epoch: 1, Step: 651, Loss: 0.3369
# Epoch: 1, Step: 682, Loss: 0.3246
# Epoch: 1, Step: 713, Loss: 0.3134
# Epoch: 1, Step: 744, Loss: 0.3034
# Epoch: 1, Step: 775, Loss: 0.2956
# Epoch: 1, Step: 806, Loss: 0.2877
# Epoch: 1, Step: 837, Loss: 0.2797
# Epoch: 1, Step: 868, Loss: 0.2721
# Epoch: 1, Step: 899, Loss: 0.2645
# Epoch: 1, Step: 930, Loss: 0.2578
# Epoch: 1, Step: 938, Loss: 0.2563
# Train Accuracy: 94.98%, Test Accuracy: 98.31%
# Epoch: 2, Step: 31, Loss: 0.0821
# Epoch: 2, Step: 62, Loss: 0.0722
# Epoch: 2, Step: 93, Loss: 0.0683
# Epoch: 2, Step: 124, Loss: 0.0621
# Epoch: 2, Step: 155, Loss: 0.0597
# Epoch: 2, Step: 186, Loss: 0.0587
# Epoch: 2, Step: 217, Loss: 0.0571
# Epoch: 2, Step: 248, Loss: 0.0590
# Epoch: 2, Step: 279, Loss: 0.0576
# Epoch: 2, Step: 310, Loss: 0.0562
# Epoch: 2, Step: 341, Loss: 0.0553
# Epoch: 2, Step: 372, Loss: 0.0539
# Epoch: 2, Step: 403, Loss: 0.0556
# Epoch: 2, Step: 434, Loss: 0.0577
# Epoch: 2, Step: 465, Loss: 0.0578
# Epoch: 2, Step: 496, Loss: 0.0565
# Epoch: 2, Step: 527, Loss: 0.0563
# Epoch: 2, Step: 558, Loss: 0.0552
# Epoch: 2, Step: 589, Loss: 0.0545
# Epoch: 2, Step: 620, Loss: 0.0542
# Epoch: 2, Step: 651, Loss: 0.0548
# Epoch: 2, Step: 682, Loss: 0.0554
# Epoch: 2, Step: 713, Loss: 0.0567
# Epoch: 2, Step: 744, Loss: 0.0568
# Epoch: 2, Step: 775, Loss: 0.0573
# Epoch: 2, Step: 806, Loss: 0.0576
# Epoch: 2, Step: 837, Loss: 0.0579
# Epoch: 2, Step: 868, Loss: 0.0581
# Epoch: 2, Step: 899, Loss: 0.0586
# Epoch: 2, Step: 930, Loss: 0.0589
# Epoch: 2, Step: 938, Loss: 0.0589
# Train Accuracy: 98.22%, Test Accuracy: 98.43%
# Epoch: 3, Step: 31, Loss: 0.0417
# Epoch: 3, Step: 62, Loss: 0.0391
# Epoch: 3, Step: 93, Loss: 0.0400
# Epoch: 3, Step: 124, Loss: 0.0438
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 3
#       1 epochs, lr = 10, 0.001#epochs,lr = 20, 0.001
#       2 device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# ----> 3 train(ret50, train_loader, test_loader, epochs, lr, device)
#
# Cell In[8], line 32, in train(net, train_iter, test_iter, epochs, lr, device)
#      30 optimizer.step()
#      31 with torch.no_grad():
# ---> 32     metric.add(l * X.shape[0], d2l.accuracy(y_hat, y), X.shape[0])
#      33 timer.stop()
#      34 train_l = metric[0] / metric[2]
#
# File C:\ProgramData\anaconda3\envs\mytorch\Lib\site-packages\d2l\torch.py:3195, in accuracy(y_hat, y)
#    3193     y_hat = d2l.argmax(y_hat, axis=1)
#    3194 cmp = d2l.astype(y_hat, y.dtype) == y
# -> 3195 return float(d2l.reduce_sum(d2l.astype(cmp, y.dtype)))
#
# KeyboardInterrupt:

# %% [markdown]
# # ret50_plot_loss

# %%
epochs, lr = 20, 0.001#epochs,lr = 20, 0.001
device = torch.device("cuda:0")
loss = nn.CrossEntropyLoss()
# train_loss(net, train_iter, test_iter, num_epochs, loss, trainer, device, lr
train_loss(ret50, test_loader64, test_loader64, epochs, loss, device, lr)
# Out:
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[6], line 5
#       3 loss = nn.CrossEntropyLoss()
#       4 # train_loss(net, train_iter, test_iter, num_epochs, loss, trainer, device, lr
# ----> 5 train_loss(ret50, test_loader64, test_loader64, epochs, loss, device, lr)
#
# Cell In[5], line 23, in train_loss(net, train_iter, test_iter, epochs, loss, device, lr)
#      21 trainer.zero_grad()
#      22 X, y = X.to(device), y.to(device)
# ---> 23 y_hat = net(X)
#      24 l = loss(y_hat, y)
#      25 l.backward()
#
# File C:\ProgramData\anaconda3\envs\mytorch\lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\envs\mytorch\lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File C:\ProgramData\anaconda3\envs\mytorch\lib\site-packages\torch\nn\modules\container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File C:\ProgramData\anaconda3\envs\mytorch\lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\envs\mytorch\lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File C:\ProgramData\anaconda3\envs\mytorch\lib\site-packages\torch\nn\modules\container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File C:\ProgramData\anaconda3\envs\mytorch\lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\envs\mytorch\lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File C:\ProgramData\anaconda3\envs\mytorch\lib\site-packages\torch\nn\modules\activation.py:101, in ReLU.forward(self, input)
#     100 def forward(self, input: Tensor) -> Tensor:
# --> 101     return F.relu(input, inplace=self.inplace)
#
# File C:\ProgramData\anaconda3\envs\mytorch\lib\site-packages\torch\nn\functional.py:1473, in relu(input, inplace)
#    1471     result = torch.relu_(input)
#    1472 else:
# -> 1473     result = torch.relu(input)
#    1474 return result
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 12.25 GiB. GPU 0 has a total capacity of 22.00 GiB of which 0 bytes is free. Of the allocated memory 25.34 GiB is allocated by PyTorch, and 15.70 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
import torch
 

 
# ... 模型训练代码 ...
 
# 清理模型和优化器占用的内存
del ret50
del trainer
 
# 清理PyTorch缓存
torch.cuda.empty_cache()

# %% [markdown]
# ## 可视化展示

# %%
text_labels = ['t-shirt', 'trouser', 'pullover', 'dress', 'coat',
                   'sandal', 'shirt', 'sneaker', 'bag', 'ankle boot']

# %%
loss_func = nn.CrossEntropyLoss()
model = net
# 优化器
optimizer = torch.optim.Adam(net.parameters(), lr=0.001)

costs = []

# 训练网络
def train(epoch):
    batch_loss = 0
    for step, (data) in enumerate(train_loader):
        inputs, labels = data
        if torch.cuda.is_available():
            inputs = inputs.cuda()
            labels = labels.cuda()
        optimizer.zero_grad()
        output = model(inputs)
        loss = loss_func(output, labels)
        loss.backward()
        optimizer.step()
        costs.append(loss)
        batch_loss += loss.item()

        if step % 300 == 299:
            print(f'epoch:{epoch},step:{step + 1},mini_loss:{batch_loss / 300:.3f}')
            batch_loss = 0


# 测试网络
def test():
    correct = 0
    total = 0
    with torch.no_grad():
        for data in test_loader64:
            inputs, labels = data
            if torch.cuda.is_available():
                inputs = inputs.cuda()
                labels = labels.cuda()
            output = model(inputs)
            _, predicted = torch.max(output, dim=1)
            total += labels.size(0)
            correct += (predicted == labels).sum()
    print(f'测试集上的准确率为:{correct / total * 100:.3f}%')


if __name__ == '__main__':
    for epoch in range(3):
        train(epoch)
        test()
    # 绘制图片:此时的costs里面的数据是tensor类型,如果是gpu上跑的就是cuda,需要将他转换成array
    print(costs)
    if torch.cuda.is_available():
        costs = [cost.cpu().detach().numpy() for cost in costs]
    else:
        costs = [cost.numpy() for cost in costs]
    print(costs)
    plt.plot(costs)
    plt.xlabel('number of iteration')
    plt.ylabel('loss')
    plt.title('Inception Net')
    plt.show()
